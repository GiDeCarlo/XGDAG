# %% [markdown]
# ## Packets

# %%
import random
import numpy as np
import pandas as pd
import seaborn as sn
import networkx as nx
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric
from torch_geometric.nn.conv import GraphConv
from torch_geometric.utils import from_networkx
from torch_geometric.data import InMemoryDataset

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(torch.__version__)
print(torch_geometric.__version__)
print(device)
# Out:
# 1.11.0
# 2.0.4
# cuda

# %% [markdown]
# ## GNNs

# %%
class GNN7L_GraphConv (nn.Module):
    def __init__(self, data):
        super().__init__()
        self.conv1 = GraphConv(data.num_features, 16, aggr='mean')
        self.conv2 = GraphConv(16, 16, aggr='mean')
        self.conv3 = GraphConv(16, 16, aggr='mean')
        self.conv4 = GraphConv(16, 16, aggr='mean')
        self.conv5 = GraphConv(16, 16, aggr='mean')
        self.conv6 = GraphConv(16, 16, aggr='mean')
        self.conv7 = GraphConv(16, int(data.num_classes), aggr='mean')

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        x = F.relu(self.conv4(x, edge_index))
        x = F.relu(self.conv5(x, edge_index))
        x = F.relu(self.conv6(x, edge_index))
        x = F.dropout(x, training=self.training)
        x = self.conv7(x, edge_index)

        return F.log_softmax(x, dim=1)

# %% [markdown]
# ## Dataset loader

# %%
# Dataset class: it allows to translate a vector (Graph, Attributes, Labels)
# into a dataset compatible with the PyTorch models.
# 
# Parameters:
# - G: NetworkX graph
# - Labels: of the nodes used for classification
# - attributes: List of the nodes' attributes

class MyDataset(InMemoryDataset):
  def __init__(self, G, labels, attributes, num_classes=2):
    super(MyDataset, self).__init__('.', None, None, None)

    # import data from the networkx graph with the attributes of the nodes
    data = from_networkx(G, attributes)
      
    y = torch.from_numpy(labels).type(torch.long)

    data.x = data.x.float()
    data.y = y.clone().detach()
    data.num_classes = num_classes

    # Using train_test_split function from sklearn to stratify train/test/val sets
    indices = range(G.number_of_nodes())
    # Stratified split of train/test/val sets. Returned indices are used to create the masks
    X_train, X_test, y_train, y_test, train_idx, test_idx = train_test_split(data.x, data.y, indices, test_size=0.3, stratify=labels, random_state=42)
    # To create validation set, test set is splitted in half
    X_test, X_val, y_test, y_val, test_idx, val_idx = train_test_split(X_test, y_test, test_idx, test_size=0.5, stratify=y_test, random_state=42)

    n_nodes = G.number_of_nodes()
    train_mask  = torch.zeros(n_nodes, dtype=torch.bool)
    test_mask   = torch.zeros(n_nodes, dtype=torch.bool)
    val_mask    = torch.zeros(n_nodes, dtype=torch.bool)
    
    for idx in train_idx:
      train_mask[idx] = True

    for idx in test_idx:
      test_mask[idx] = True
    
    for idx in val_idx:
      val_mask[idx] = True

    data['train_mask']  = train_mask
    data['test_mask']   = test_mask
    data['val_mask']    = val_mask

    self.data, self.slices = self.collate([data])

# %% [markdown]
# ## Training Function

# %%
def train(model, data, epochs = 200, classes = ['0','1'], lr = 0.001, weight_decay=0, cm_title = 'GNN'):
    title = cm_title + '_' + str(epochs) + '_' + str(weight_decay).replace('.', '_')

    model_path  = 'Models/' + title
    image_path  = 'Images/' + title
    report_path = 'Reports/' + title + '.csv'

    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    train_mask  = data['train_mask']
    test_mask   = data['test_mask']
    val_mask    = data['val_mask']

    labels    = data.y
    output = ''

    # list to plot the train accuracy
    train_acc_curve = []
    train_lss_curve = []

    best_train_acc  = 0
    best_val_acc    = 0
    # best_test_acc   = 0
    best_train_lss  = 999

    for e in tqdm(range(epochs+1)):
        model.train()
        optimizer.zero_grad()
        logits      = model(data)
        output      = logits.argmax(1)
        # train_loss  = F.cross_entropy(logits[train_mask], labels[train_mask])
        train_loss  = F.nll_loss(logits[train_mask], labels[train_mask])
        train_acc   = (output[train_mask] == labels[train_mask]).float().mean()
        train_loss.backward()
        optimizer.step()

        # Append train acc. to plot curve later
        train_acc_curve.append(train_acc.item())
        train_lss_curve.append(train_loss.item())

        if train_acc > best_train_acc:
            best_train_acc = train_acc

        # Evaluation and test
        model.eval()
        logits      = model(data)
        output      = logits.argmax(1)
        # val_loss    = F.cross_entropy(logits[val_mask], labels[val_mask])
        val_loss    = F.nll_loss(logits[val_mask], labels[val_mask])
        val_acc     = (output[val_mask] == labels[val_mask]).float().mean()
        # test_acc    = (output[test_mask] == labels[test_mask]).float().mean()

        # Update best test/val acc.
        if val_acc > best_val_acc:
            best_val_acc = val_acc
        
        # if test_acc > best_test_acc:
        #     best_test_acc = test_acc
        
        # Save model with best train loss
        if train_loss < best_train_lss:
            best_train_lss = train_loss
            torch.save(model.state_dict(), model_path)

        if e % 20 == 0 or e == epochs:
            print('[Epoch: {:04d}]'.format(e),
            'train loss: {:.4f},'.format(train_loss.item()),
            'train acc: {:.4f},'.format(train_acc.item()),
            'val loss: {:.4f},'.format(val_loss.item()),
            'val acc: {:.4f} '.format(val_acc.item()),
            '(best train acc: {:.4f},'.format(best_train_acc.item()),
            'best val acc: {:.4f},'.format(best_val_acc.item()),
            'best train loss: {:.4f})'.format(best_train_lss))
    
    # Plot training accuracy curve
    plt.figure(figsize = (12,7))
    plt.plot(train_acc_curve)
    plt.xlabel('Epoch')
    plt.ylabel('Train Accuracy')
    plt.show()

    plt.figure(figsize = (12,7))
    plt.plot(train_lss_curve)
    plt.xlabel('Epoch')
    plt.ylabel('Train Loss')
    plt.show()

    # Load best model
    loaded_model = GNN7L_GraphConv(data).to(device)
    loaded_model.load_state_dict(torch.load(model_path))
    loaded_model.eval()
    logits = loaded_model(data)
    output = logits.argmax(1)

    print(classification_report(labels[test_mask].to('cpu'), output[test_mask].to('cpu')))

    class_report = classification_report(labels[test_mask].to('cpu'), output[test_mask].to('cpu'), output_dict=True)
    classification_report_dataframe = pd.DataFrame(class_report)
    classification_report_dataframe.to_csv(report_path)

    #Confusion Matrix
    norms = [None, "true"]
    for norm in norms:
        cm = confusion_matrix(labels[test_mask].to('cpu'), output[test_mask].to('cpu'), normalize=norm)

        plt.figure(figsize=(7,7))
        
        if norm == "true":
            sn.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'BuPu', xticklabels = classes, yticklabels = classes)
        else:
            sn.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu', xticklabels = classes, yticklabels = classes)
        plt.title(cm_title)
        plt.ylabel('Actual label')
        plt.xlabel('Predicted label')

        if norm == None:
            plt.savefig(image_path + '_notNorm.png')
        else:
            plt.savefig(image_path + '_Norm.png')

    return output

# %% [markdown]
# ## NeDBIT Multiclass

# %%
G = nx.read_gml('Graphs/graph_with_normalized_nedbit.gml')

seed_genes          = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_seed_genes.txt', header=None, sep=' ')
seed_genes.columns  = ["name", "GDA Score"]
seeds_list          = seed_genes["name"].values.tolist()

nedbit_scores = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_features_Score.csv')

# Remove seed genes
nedbit_scores_not_seed = nedbit_scores[~nedbit_scores['name'].isin(seeds_list)]
print(nedbit_scores_not_seed.shape)

# Sort scores for quartile division
nedbit_scores_not_seed = nedbit_scores_not_seed.sort_values(by = "out", ascending = False)
pseudo_labels = pd.qcut(x = nedbit_scores_not_seed["out"], q = 4, labels = ["RN", "LN", "WN", "LP"])

plt.hist(pseudo_labels)
plt.show()
# Out:
# (18736, 2)

# %%
nedbit_scores_not_seed['label'] = pseudo_labels

nedbit_scores_seed = nedbit_scores[nedbit_scores['name'].isin(seeds_list)]
nedbit_scores_seed = nedbit_scores_seed.assign(label = 'P')

# Convert dataframe to dict for searching nodes and their labels
not_seed_labels = dict(zip(nedbit_scores_not_seed['name'], nedbit_scores_not_seed['label']))
seed_labels     = dict(zip(nedbit_scores_seed['name'], nedbit_scores_seed['label']))

labels_dict = {'P':0, 'LP': 1, 'WN': 2, 'LN': 3, 'RN': 4}
labels = []

for node in G:
    if node in not_seed_labels:
        labels.append(labels_dict[not_seed_labels[node]])
    else:
        labels.append(labels_dict[seed_labels[node]])

labels = np.asarray(labels)
len(labels)
# Out:
# 19761

# %%
attributes = ['degree', 'ring', 'NetRank', 'NetShort', 'HeatDiff', 'InfoDiff']

dataset_with_nedbit = MyDataset(G, labels, attributes, num_classes=5)
data_with_nedbit = dataset_with_nedbit[0]

plt.hist(labels)
plt.show()

# %% [markdown]
# ### 7 Layers

# %%
gnn_conv = GNN7L_GraphConv(data_with_nedbit).to(device)
pred = train(gnn_conv, data_with_nedbit.to(device), 40000, cm_title='GraphConv7L_multiclass_16HC_v2', classes=['P', 'LP', 'WN', 'LN', 'RN'], weight_decay=0.0005)
# Out:
#   0%|          | 0/40001 [00:00<?, ?it/s]
# [Epoch: 0000] train loss: 89.1047, train acc: 0.2359, val loss: 74.7600, val acc: 0.2368  (best train acc: 0.2359, best val acc: 0.2368, best train loss: 89.1047)
# [Epoch: 0020] train loss: 5.1212, train acc: 0.2501, val loss: 2.3855, val acc: 0.3818  (best train acc: 0.2693, best val acc: 0.4445, best train loss: 5.1212)
# [Epoch: 0040] train loss: 1.4736, train acc: 0.2976, val loss: 1.2375, val acc: 0.4681  (best train acc: 0.3990, best val acc: 0.5747, best train loss: 1.4736)
# [Epoch: 0060] train loss: 1.3117, train acc: 0.4592, val loss: 1.1191, val acc: 0.6725  (best train acc: 0.4592, best val acc: 0.6725, best train loss: 1.3117)
# [Epoch: 0080] train loss: 1.2965, train acc: 0.4680, val loss: 1.0616, val acc: 0.6793  (best train acc: 0.4727, best val acc: 0.6793, best train loss: 1.2876)
# [Epoch: 0100] train loss: 1.2605, train acc: 0.4824, val loss: 1.0053, val acc: 0.7184  (best train acc: 0.4862, best val acc: 0.7184, best train loss: 1.2581)
# [Epoch: 0120] train loss: 1.2424, train acc: 0.4853, val loss: 0.9755, val acc: 0.7612  (best train acc: 0.4920, best val acc: 0.7612, best train loss: 1.2422)
# [Epoch: 0140] train loss: 1.2256, train acc: 0.4933, val loss: 0.9546, val acc: 0.7727  (best train acc: 0.4993, best val acc: 0.7727, best train loss: 1.2228)
# [Epoch: 0160] train loss: 1.2207, train acc: 0.4910, val loss: 0.9416, val acc: 0.7804  (best train acc: 0.5017, best val acc: 0.7821, best train loss: 1.2051)
# [Epoch: 0180] train loss: 1.1996, train acc: 0.5045, val loss: 0.9263, val acc: 0.7902  (best train acc: 0.5074, best val acc: 0.7902, best train loss: 1.1926)
# [Epoch: 0200] train loss: 1.1858, train acc: 0.5106, val loss: 0.8983, val acc: 0.7956  (best train acc: 0.5193, best val acc: 0.7963, best train loss: 1.1735)
# [Epoch: 0220] train loss: 1.1690, train acc: 0.5275, val loss: 0.8893, val acc: 0.8037  (best train acc: 0.5275, best val acc: 0.8054, best train loss: 1.1690)
# [Epoch: 0240] train loss: 1.1563, train acc: 0.5219, val loss: 0.8763, val acc: 0.7953  (best train acc: 0.5312, best val acc: 0.8078, best train loss: 1.1561)
# [Epoch: 0260] train loss: 1.1483, train acc: 0.5281, val loss: 0.8549, val acc: 0.8115  (best train acc: 0.5343, best val acc: 0.8135, best train loss: 1.1426)
# [Epoch: 0280] train loss: 1.1340, train acc: 0.5294, val loss: 0.8439, val acc: 0.8142  (best train acc: 0.5351, best val acc: 0.8142, best train loss: 1.1259)
# [Epoch: 0300] train loss: 1.1190, train acc: 0.5408, val loss: 0.8259, val acc: 0.8202  (best train acc: 0.5414, best val acc: 0.8202, best train loss: 1.1140)
# [Epoch: 0320] train loss: 1.1031, train acc: 0.5417, val loss: 0.8013, val acc: 0.8277  (best train acc: 0.5484, best val acc: 0.8293, best train loss: 1.0978)
# [Epoch: 0340] train loss: 1.0986, train acc: 0.5441, val loss: 0.7938, val acc: 0.8307  (best train acc: 0.5599, best val acc: 0.8354, best train loss: 1.0755)
# [Epoch: 0360] train loss: 1.0795, train acc: 0.5496, val loss: 0.7606, val acc: 0.8381  (best train acc: 0.5599, best val acc: 0.8384, best train loss: 1.0755)
# [Epoch: 0380] train loss: 1.0740, train acc: 0.5550, val loss: 0.7713, val acc: 0.8422  (best train acc: 0.5599, best val acc: 0.8442, best train loss: 1.0648)
# [Epoch: 0400] train loss: 1.0580, train acc: 0.5630, val loss: 0.7284, val acc: 0.8506  (best train acc: 0.5672, best val acc: 0.8513, best train loss: 1.0529)
# [Epoch: 0420] train loss: 1.0354, train acc: 0.5737, val loss: 0.7234, val acc: 0.8604  (best train acc: 0.5810, best val acc: 0.8604, best train loss: 1.0292)
# [Epoch: 0440] train loss: 1.0150, train acc: 0.5895, val loss: 0.6972, val acc: 0.8631  (best train acc: 0.5895, best val acc: 0.8631, best train loss: 1.0150)
# [Epoch: 0460] train loss: 1.0120, train acc: 0.6035, val loss: 0.6940, val acc: 0.8648  (best train acc: 0.6044, best val acc: 0.8651, best train loss: 1.0027)
# [Epoch: 0480] train loss: 0.9942, train acc: 0.6130, val loss: 0.6778, val acc: 0.8648  (best train acc: 0.6130, best val acc: 0.8685, best train loss: 0.9942)
# [Epoch: 0500] train loss: 0.9846, train acc: 0.6185, val loss: 0.6659, val acc: 0.8749  (best train acc: 0.6185, best val acc: 0.8749, best train loss: 0.9802)
# [Epoch: 0520] train loss: 1.0011, train acc: 0.6052, val loss: 0.6501, val acc: 0.8759  (best train acc: 0.6245, best val acc: 0.8769, best train loss: 0.9678)
# [Epoch: 0540] train loss: 0.9666, train acc: 0.6235, val loss: 0.6427, val acc: 0.8782  (best train acc: 0.6247, best val acc: 0.8799, best train loss: 0.9640)
# [Epoch: 0560] train loss: 0.9681, train acc: 0.6155, val loss: 0.6354, val acc: 0.8786  (best train acc: 0.6247, best val acc: 0.8823, best train loss: 0.9617)
# [Epoch: 0580] train loss: 0.9649, train acc: 0.6150, val loss: 0.6268, val acc: 0.8772  (best train acc: 0.6277, best val acc: 0.8833, best train loss: 0.9493)
# [Epoch: 0600] train loss: 0.9592, train acc: 0.6163, val loss: 0.6294, val acc: 0.8779  (best train acc: 0.6277, best val acc: 0.8836, best train loss: 0.9471)
# [Epoch: 0620] train loss: 0.9571, train acc: 0.6186, val loss: 0.6216, val acc: 0.8806  (best train acc: 0.6296, best val acc: 0.8843, best train loss: 0.9417)
# [Epoch: 0640] train loss: 0.9533, train acc: 0.6174, val loss: 0.6030, val acc: 0.8840  (best train acc: 0.6296, best val acc: 0.8850, best train loss: 0.9417)
# [Epoch: 0660] train loss: 0.9392, train acc: 0.6212, val loss: 0.6031, val acc: 0.8793  (best train acc: 0.6296, best val acc: 0.8860, best train loss: 0.9307)
# [Epoch: 0680] train loss: 0.9411, train acc: 0.6182, val loss: 0.5964, val acc: 0.8850  (best train acc: 0.6296, best val acc: 0.8867, best train loss: 0.9252)
# [Epoch: 0700] train loss: 0.9501, train acc: 0.6109, val loss: 0.6068, val acc: 0.8789  (best train acc: 0.6296, best val acc: 0.8867, best train loss: 0.9252)
# [Epoch: 0720] train loss: 0.9388, train acc: 0.6231, val loss: 0.5915, val acc: 0.8826  (best train acc: 0.6296, best val acc: 0.8870, best train loss: 0.9220)
# [Epoch: 0740] train loss: 0.9338, train acc: 0.6194, val loss: 0.5817, val acc: 0.8857  (best train acc: 0.6300, best val acc: 0.8877, best train loss: 0.9155)
# [Epoch: 0760] train loss: 0.9257, train acc: 0.6285, val loss: 0.5733, val acc: 0.8901  (best train acc: 0.6300, best val acc: 0.8907, best train loss: 0.9155)
# [Epoch: 0780] train loss: 0.9167, train acc: 0.6244, val loss: 0.5748, val acc: 0.8850  (best train acc: 0.6341, best val acc: 0.8914, best train loss: 0.9110)
# [Epoch: 0800] train loss: 0.9153, train acc: 0.6249, val loss: 0.5666, val acc: 0.8877  (best train acc: 0.6341, best val acc: 0.8914, best train loss: 0.9044)
# [Epoch: 0820] train loss: 0.9229, train acc: 0.6159, val loss: 0.5825, val acc: 0.8735  (best train acc: 0.6341, best val acc: 0.8914, best train loss: 0.9044)
# [Epoch: 0840] train loss: 0.9180, train acc: 0.6219, val loss: 0.5574, val acc: 0.8897  (best train acc: 0.6341, best val acc: 0.8914, best train loss: 0.9044)
# [Epoch: 0860] train loss: 0.8997, train acc: 0.6313, val loss: 0.5486, val acc: 0.8917  (best train acc: 0.6341, best val acc: 0.8921, best train loss: 0.8981)
# [Epoch: 0880] train loss: 0.8969, train acc: 0.6291, val loss: 0.5562, val acc: 0.8894  (best train acc: 0.6341, best val acc: 0.8944, best train loss: 0.8969)
# [Epoch: 0900] train loss: 0.9129, train acc: 0.6237, val loss: 0.5556, val acc: 0.8874  (best train acc: 0.6341, best val acc: 0.8944, best train loss: 0.8969)
# [Epoch: 0920] train loss: 0.9182, train acc: 0.6194, val loss: 0.5497, val acc: 0.8921  (best train acc: 0.6341, best val acc: 0.8944, best train loss: 0.8870)
# [Epoch: 0940] train loss: 0.8956, train acc: 0.6283, val loss: 0.5403, val acc: 0.8880  (best train acc: 0.6341, best val acc: 0.8944, best train loss: 0.8870)
# [Epoch: 0960] train loss: 0.9112, train acc: 0.6110, val loss: 0.5503, val acc: 0.8786  (best train acc: 0.6341, best val acc: 0.8944, best train loss: 0.8870)
# [Epoch: 0980] train loss: 0.8980, train acc: 0.6245, val loss: 0.5640, val acc: 0.8830  (best train acc: 0.6341, best val acc: 0.8944, best train loss: 0.8870)
# [Epoch: 1000] train loss: 0.8789, train acc: 0.6205, val loss: 0.5037, val acc: 0.8897  (best train acc: 0.6341, best val acc: 0.8944, best train loss: 0.8635)
# [Epoch: 1020] train loss: 0.8588, train acc: 0.6293, val loss: 0.4967, val acc: 0.8917  (best train acc: 0.6381, best val acc: 0.8954, best train loss: 0.8517)
# [Epoch: 1040] train loss: 0.8382, train acc: 0.6461, val loss: 0.5047, val acc: 0.8809  (best train acc: 0.6461, best val acc: 0.8954, best train loss: 0.8382)
# [Epoch: 1060] train loss: 0.8652, train acc: 0.6273, val loss: 0.4793, val acc: 0.8924  (best train acc: 0.6546, best val acc: 0.8954, best train loss: 0.8382)
# [Epoch: 1080] train loss: 0.8358, train acc: 0.6438, val loss: 0.4768, val acc: 0.8907  (best train acc: 0.6546, best val acc: 0.8954, best train loss: 0.8358)
# [Epoch: 1100] train loss: 0.8538, train acc: 0.6326, val loss: 0.4715, val acc: 0.8927  (best train acc: 0.6546, best val acc: 0.8975, best train loss: 0.8304)
# [Epoch: 1120] train loss: 0.8614, train acc: 0.6238, val loss: 0.4693, val acc: 0.8853  (best train acc: 0.6620, best val acc: 0.8975, best train loss: 0.8142)
# [Epoch: 1140] train loss: 0.8416, train acc: 0.6546, val loss: 0.4653, val acc: 0.8897  (best train acc: 0.6629, best val acc: 0.8975, best train loss: 0.8142)
# [Epoch: 1160] train loss: 0.8439, train acc: 0.6437, val loss: 0.4638, val acc: 0.8931  (best train acc: 0.6685, best val acc: 0.8975, best train loss: 0.8142)
# [Epoch: 1180] train loss: 0.8172, train acc: 0.6607, val loss: 0.4555, val acc: 0.8830  (best train acc: 0.6721, best val acc: 0.8975, best train loss: 0.8140)
# [Epoch: 1200] train loss: 0.8196, train acc: 0.6679, val loss: 0.4496, val acc: 0.8921  (best train acc: 0.6816, best val acc: 0.8975, best train loss: 0.8063)
# [Epoch: 1220] train loss: 0.8220, train acc: 0.6572, val loss: 0.4538, val acc: 0.8924  (best train acc: 0.6816, best val acc: 0.8975, best train loss: 0.8010)
# [Epoch: 1240] train loss: 0.8112, train acc: 0.6706, val loss: 0.4496, val acc: 0.8901  (best train acc: 0.6930, best val acc: 0.8975, best train loss: 0.8010)
# [Epoch: 1260] train loss: 0.8025, train acc: 0.6849, val loss: 0.4493, val acc: 0.8904  (best train acc: 0.6930, best val acc: 0.8975, best train loss: 0.7951)
# [Epoch: 1280] train loss: 0.8099, train acc: 0.6885, val loss: 0.4528, val acc: 0.8887  (best train acc: 0.6956, best val acc: 0.8975, best train loss: 0.7951)
# [Epoch: 1300] train loss: 0.8101, train acc: 0.6841, val loss: 0.4605, val acc: 0.8823  (best train acc: 0.6956, best val acc: 0.8975, best train loss: 0.7951)
# [Epoch: 1320] train loss: 0.7525, train acc: 0.7222, val loss: 0.4594, val acc: 0.8816  (best train acc: 0.7222, best val acc: 0.8981, best train loss: 0.7525)
# [Epoch: 1340] train loss: 0.7453, train acc: 0.7125, val loss: 0.4257, val acc: 0.8901  (best train acc: 0.7222, best val acc: 0.8981, best train loss: 0.7394)
# [Epoch: 1360] train loss: 0.7564, train acc: 0.7093, val loss: 0.4167, val acc: 0.8985  (best train acc: 0.7253, best val acc: 0.8998, best train loss: 0.7130)
# [Epoch: 1380] train loss: 0.7461, train acc: 0.7115, val loss: 0.4120, val acc: 0.8995  (best train acc: 0.7334, best val acc: 0.9005, best train loss: 0.7130)
# [Epoch: 1400] train loss: 0.7423, train acc: 0.7159, val loss: 0.4055, val acc: 0.8995  (best train acc: 0.7334, best val acc: 0.9008, best train loss: 0.7092)
# [Epoch: 1420] train loss: 0.7466, train acc: 0.7119, val loss: 0.3982, val acc: 0.8995  (best train acc: 0.7334, best val acc: 0.9012, best train loss: 0.7092)
# [Epoch: 1440] train loss: 0.7390, train acc: 0.7045, val loss: 0.3993, val acc: 0.8992  (best train acc: 0.7363, best val acc: 0.9019, best train loss: 0.7070)
# [Epoch: 1460] train loss: 0.7197, train acc: 0.7228, val loss: 0.3998, val acc: 0.9008  (best train acc: 0.7397, best val acc: 0.9019, best train loss: 0.7006)
# [Epoch: 1480] train loss: 0.7200, train acc: 0.7320, val loss: 0.3984, val acc: 0.9005  (best train acc: 0.7397, best val acc: 0.9019, best train loss: 0.7006)
# [Epoch: 1500] train loss: 0.7252, train acc: 0.7232, val loss: 0.4026, val acc: 0.9005  (best train acc: 0.7412, best val acc: 0.9025, best train loss: 0.6966)
# [Epoch: 1520] train loss: 0.7112, train acc: 0.7285, val loss: 0.3969, val acc: 0.9012  (best train acc: 0.7412, best val acc: 0.9025, best train loss: 0.6966)
# [Epoch: 1540] train loss: 0.7173, train acc: 0.7300, val loss: 0.3936, val acc: 0.9008  (best train acc: 0.7433, best val acc: 0.9025, best train loss: 0.6920)
# [Epoch: 1560] train loss: 0.7372, train acc: 0.7117, val loss: 0.3954, val acc: 0.9008  (best train acc: 0.7433, best val acc: 0.9032, best train loss: 0.6920)
# [Epoch: 1580] train loss: 0.7157, train acc: 0.7331, val loss: 0.4035, val acc: 0.9008  (best train acc: 0.7516, best val acc: 0.9032, best train loss: 0.6856)
# [Epoch: 1600] train loss: 0.7581, train acc: 0.6968, val loss: 0.4091, val acc: 0.8917  (best train acc: 0.7516, best val acc: 0.9032, best train loss: 0.6856)
# [Epoch: 1620] train loss: 0.7103, train acc: 0.7329, val loss: 0.3881, val acc: 0.9025  (best train acc: 0.7516, best val acc: 0.9039, best train loss: 0.6856)
# [Epoch: 1640] train loss: 0.7284, train acc: 0.7118, val loss: 0.3786, val acc: 0.9022  (best train acc: 0.7516, best val acc: 0.9042, best train loss: 0.6856)
# [Epoch: 1660] train loss: 0.7380, train acc: 0.7101, val loss: 0.4044, val acc: 0.8887  (best train acc: 0.7525, best val acc: 0.9042, best train loss: 0.6856)
# [Epoch: 1680] train loss: 0.7095, train acc: 0.7379, val loss: 0.3872, val acc: 0.9005  (best train acc: 0.7525, best val acc: 0.9042, best train loss: 0.6856)
# [Epoch: 1700] train loss: 0.7222, train acc: 0.7146, val loss: 0.3960, val acc: 0.8948  (best train acc: 0.7581, best val acc: 0.9042, best train loss: 0.6703)
# [Epoch: 1720] train loss: 0.7392, train acc: 0.7302, val loss: 0.4195, val acc: 0.8769  (best train acc: 0.7581, best val acc: 0.9042, best train loss: 0.6703)
# [Epoch: 1740] train loss: 0.6717, train acc: 0.7567, val loss: 0.4076, val acc: 0.8978  (best train acc: 0.7581, best val acc: 0.9042, best train loss: 0.6703)
# [Epoch: 1760] train loss: 0.6790, train acc: 0.7489, val loss: 0.3859, val acc: 0.9039  (best train acc: 0.7602, best val acc: 0.9042, best train loss: 0.6703)
# [Epoch: 1780] train loss: 0.6987, train acc: 0.7507, val loss: 0.3971, val acc: 0.8995  (best train acc: 0.7623, best val acc: 0.9042, best train loss: 0.6703)
# [Epoch: 1800] train loss: 0.7084, train acc: 0.7347, val loss: 0.3754, val acc: 0.9019  (best train acc: 0.7623, best val acc: 0.9042, best train loss: 0.6703)
# [Epoch: 1820] train loss: 0.6933, train acc: 0.7398, val loss: 0.3747, val acc: 0.9032  (best train acc: 0.7623, best val acc: 0.9042, best train loss: 0.6606)
# [Epoch: 1840] train loss: 0.7237, train acc: 0.7140, val loss: 0.3801, val acc: 0.9022  (best train acc: 0.7623, best val acc: 0.9046, best train loss: 0.6606)
# [Epoch: 1860] train loss: 0.6862, train acc: 0.7425, val loss: 0.3784, val acc: 0.9022  (best train acc: 0.7623, best val acc: 0.9046, best train loss: 0.6606)
# [Epoch: 1880] train loss: 0.6991, train acc: 0.7272, val loss: 0.3807, val acc: 0.8941  (best train acc: 0.7627, best val acc: 0.9052, best train loss: 0.6606)
# [Epoch: 1900] train loss: 0.6930, train acc: 0.7446, val loss: 0.3735, val acc: 0.9005  (best train acc: 0.7629, best val acc: 0.9052, best train loss: 0.6606)
# [Epoch: 1920] train loss: 0.6911, train acc: 0.7439, val loss: 0.3662, val acc: 0.9056  (best train acc: 0.7629, best val acc: 0.9059, best train loss: 0.6593)
# [Epoch: 1940] train loss: 0.6875, train acc: 0.7488, val loss: 0.4145, val acc: 0.8927  (best train acc: 0.7629, best val acc: 0.9062, best train loss: 0.6593)
# [Epoch: 1960] train loss: 0.6986, train acc: 0.7305, val loss: 0.3697, val acc: 0.9049  (best train acc: 0.7629, best val acc: 0.9062, best train loss: 0.6593)
# [Epoch: 1980] train loss: 0.6966, train acc: 0.7428, val loss: 0.3773, val acc: 0.8944  (best train acc: 0.7629, best val acc: 0.9062, best train loss: 0.6593)
# [Epoch: 2000] train loss: 0.7087, train acc: 0.7274, val loss: 0.3692, val acc: 0.9032  (best train acc: 0.7629, best val acc: 0.9062, best train loss: 0.6549)
# [Epoch: 2020] train loss: 0.6970, train acc: 0.7428, val loss: 0.3819, val acc: 0.8971  (best train acc: 0.7637, best val acc: 0.9062, best train loss: 0.6549)
# [Epoch: 2040] train loss: 0.6979, train acc: 0.7325, val loss: 0.3716, val acc: 0.9015  (best train acc: 0.7649, best val acc: 0.9062, best train loss: 0.6549)
# [Epoch: 2060] train loss: 0.7131, train acc: 0.7222, val loss: 0.4026, val acc: 0.8971  (best train acc: 0.7649, best val acc: 0.9062, best train loss: 0.6549)
# [Epoch: 2080] train loss: 0.6898, train acc: 0.7381, val loss: 0.3953, val acc: 0.9029  (best train acc: 0.7649, best val acc: 0.9062, best train loss: 0.6510)
# [Epoch: 2100] train loss: 0.6833, train acc: 0.7438, val loss: 0.3768, val acc: 0.9069  (best train acc: 0.7672, best val acc: 0.9069, best train loss: 0.6510)
# [Epoch: 2120] train loss: 0.6564, train acc: 0.7647, val loss: 0.3892, val acc: 0.9029  (best train acc: 0.7672, best val acc: 0.9069, best train loss: 0.6510)
# [Epoch: 2140] train loss: 0.6851, train acc: 0.7535, val loss: 0.3823, val acc: 0.9039  (best train acc: 0.7672, best val acc: 0.9069, best train loss: 0.6510)
# [Epoch: 2160] train loss: 0.6385, train acc: 0.7708, val loss: 0.4180, val acc: 0.8944  (best train acc: 0.7708, best val acc: 0.9069, best train loss: 0.6385)
# [Epoch: 2180] train loss: 0.7296, train acc: 0.7037, val loss: 0.3911, val acc: 0.8890  (best train acc: 0.7708, best val acc: 0.9069, best train loss: 0.6385)
# [Epoch: 2200] train loss: 0.7004, train acc: 0.7256, val loss: 0.3693, val acc: 0.9059  (best train acc: 0.7708, best val acc: 0.9069, best train loss: 0.6385)
# [Epoch: 2220] train loss: 0.6719, train acc: 0.7546, val loss: 0.3914, val acc: 0.9029  (best train acc: 0.7708, best val acc: 0.9069, best train loss: 0.6385)
# [Epoch: 2240] train loss: 0.6622, train acc: 0.7588, val loss: 0.3888, val acc: 0.9022  (best train acc: 0.7708, best val acc: 0.9069, best train loss: 0.6385)
# [Epoch: 2260] train loss: 0.6529, train acc: 0.7671, val loss: 0.3848, val acc: 0.9035  (best train acc: 0.7708, best val acc: 0.9069, best train loss: 0.6385)
# [Epoch: 2280] train loss: 0.6776, train acc: 0.7528, val loss: 0.3808, val acc: 0.9022  (best train acc: 0.7708, best val acc: 0.9069, best train loss: 0.6385)
# [Epoch: 2300] train loss: 0.6936, train acc: 0.7348, val loss: 0.3574, val acc: 0.9039  (best train acc: 0.7708, best val acc: 0.9069, best train loss: 0.6299)
# [Epoch: 2320] train loss: 0.6782, train acc: 0.7439, val loss: 0.3695, val acc: 0.8978  (best train acc: 0.7708, best val acc: 0.9069, best train loss: 0.6299)
# [Epoch: 2340] train loss: 0.6703, train acc: 0.7485, val loss: 0.3743, val acc: 0.8981  (best train acc: 0.7720, best val acc: 0.9069, best train loss: 0.6284)
# [Epoch: 2360] train loss: 0.6600, train acc: 0.7591, val loss: 0.3588, val acc: 0.9022  (best train acc: 0.7745, best val acc: 0.9069, best train loss: 0.6284)
# [Epoch: 2380] train loss: 0.6583, train acc: 0.7587, val loss: 0.3689, val acc: 0.9002  (best train acc: 0.7745, best val acc: 0.9069, best train loss: 0.6284)
# [Epoch: 2400] train loss: 0.7087, train acc: 0.7333, val loss: 0.3706, val acc: 0.8985  (best train acc: 0.7745, best val acc: 0.9069, best train loss: 0.6284)
# [Epoch: 2420] train loss: 0.6711, train acc: 0.7537, val loss: 0.3736, val acc: 0.9039  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6283)
# [Epoch: 2440] train loss: 0.6538, train acc: 0.7604, val loss: 0.3804, val acc: 0.9029  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6283)
# [Epoch: 2460] train loss: 0.6973, train acc: 0.7326, val loss: 0.3697, val acc: 0.9022  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6283)
# [Epoch: 2480] train loss: 0.6734, train acc: 0.7397, val loss: 0.3581, val acc: 0.8948  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6283)
# [Epoch: 2500] train loss: 0.6503, train acc: 0.7578, val loss: 0.3545, val acc: 0.9039  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6283)
# [Epoch: 2520] train loss: 0.6320, train acc: 0.7676, val loss: 0.3868, val acc: 0.9015  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6283)
# [Epoch: 2540] train loss: 0.6604, train acc: 0.7501, val loss: 0.3735, val acc: 0.8978  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6283)
# [Epoch: 2560] train loss: 0.6953, train acc: 0.7290, val loss: 0.4203, val acc: 0.8634  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6283)
# [Epoch: 2580] train loss: 0.6774, train acc: 0.7460, val loss: 0.3595, val acc: 0.9059  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6283)
# [Epoch: 2600] train loss: 0.6519, train acc: 0.7485, val loss: 0.3811, val acc: 0.9005  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6283)
# [Epoch: 2620] train loss: 0.6729, train acc: 0.7471, val loss: 0.3634, val acc: 0.9029  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6153)
# [Epoch: 2640] train loss: 0.6735, train acc: 0.7351, val loss: 0.3501, val acc: 0.9039  (best train acc: 0.7745, best val acc: 0.9086, best train loss: 0.6153)
# [Epoch: 2660] train loss: 0.6196, train acc: 0.7781, val loss: 0.3584, val acc: 0.9062  (best train acc: 0.7781, best val acc: 0.9086, best train loss: 0.6153)
# [Epoch: 2680] train loss: 0.6558, train acc: 0.7483, val loss: 0.3599, val acc: 0.9062  (best train acc: 0.7781, best val acc: 0.9086, best train loss: 0.6153)
# [Epoch: 2700] train loss: 0.6503, train acc: 0.7501, val loss: 0.3794, val acc: 0.8951  (best train acc: 0.7820, best val acc: 0.9093, best train loss: 0.6052)
# [Epoch: 2720] train loss: 0.6165, train acc: 0.7762, val loss: 0.3770, val acc: 0.8944  (best train acc: 0.7820, best val acc: 0.9093, best train loss: 0.6052)
# [Epoch: 2740] train loss: 0.6638, train acc: 0.7359, val loss: 0.3600, val acc: 0.9015  (best train acc: 0.7820, best val acc: 0.9093, best train loss: 0.6052)
# [Epoch: 2760] train loss: 0.6637, train acc: 0.7371, val loss: 0.3482, val acc: 0.9008  (best train acc: 0.7820, best val acc: 0.9093, best train loss: 0.6052)
# [Epoch: 2780] train loss: 0.6433, train acc: 0.7454, val loss: 0.3477, val acc: 0.9032  (best train acc: 0.7820, best val acc: 0.9093, best train loss: 0.6052)
# [Epoch: 2800] train loss: 0.6592, train acc: 0.7523, val loss: 0.3633, val acc: 0.9025  (best train acc: 0.7820, best val acc: 0.9093, best train loss: 0.6029)
# [Epoch: 2820] train loss: 0.6299, train acc: 0.7691, val loss: 0.3719, val acc: 0.9019  (best train acc: 0.7820, best val acc: 0.9093, best train loss: 0.6029)
# [Epoch: 2840] train loss: 0.6256, train acc: 0.7670, val loss: 0.3692, val acc: 0.9022  (best train acc: 0.7864, best val acc: 0.9093, best train loss: 0.6019)
# [Epoch: 2860] train loss: 0.6281, train acc: 0.7627, val loss: 0.3604, val acc: 0.9019  (best train acc: 0.7871, best val acc: 0.9093, best train loss: 0.5857)
# [Epoch: 2880] train loss: 0.6362, train acc: 0.7614, val loss: 0.3513, val acc: 0.9035  (best train acc: 0.7892, best val acc: 0.9093, best train loss: 0.5857)
# [Epoch: 2900] train loss: 0.5985, train acc: 0.7879, val loss: 0.3663, val acc: 0.9066  (best train acc: 0.7911, best val acc: 0.9093, best train loss: 0.5717)
# [Epoch: 2920] train loss: 0.6434, train acc: 0.7501, val loss: 0.3626, val acc: 0.9002  (best train acc: 0.7923, best val acc: 0.9093, best train loss: 0.5717)
# [Epoch: 2940] train loss: 0.6228, train acc: 0.7680, val loss: 0.3527, val acc: 0.9073  (best train acc: 0.7923, best val acc: 0.9093, best train loss: 0.5717)
# [Epoch: 2960] train loss: 0.6301, train acc: 0.7724, val loss: 0.3660, val acc: 0.8867  (best train acc: 0.7923, best val acc: 0.9099, best train loss: 0.5717)
# [Epoch: 2980] train loss: 0.5874, train acc: 0.7968, val loss: 0.3379, val acc: 0.9022  (best train acc: 0.7968, best val acc: 0.9099, best train loss: 0.5717)
# [Epoch: 3000] train loss: 0.5928, train acc: 0.7822, val loss: 0.3511, val acc: 0.9032  (best train acc: 0.7968, best val acc: 0.9099, best train loss: 0.5717)
# [Epoch: 3020] train loss: 0.6316, train acc: 0.7565, val loss: 0.3442, val acc: 0.9035  (best train acc: 0.7968, best val acc: 0.9099, best train loss: 0.5717)
# [Epoch: 3040] train loss: 0.6003, train acc: 0.7693, val loss: 0.3540, val acc: 0.9042  (best train acc: 0.7968, best val acc: 0.9099, best train loss: 0.5717)
# [Epoch: 3060] train loss: 0.6060, train acc: 0.7705, val loss: 0.3455, val acc: 0.9046  (best train acc: 0.7968, best val acc: 0.9099, best train loss: 0.5717)
# [Epoch: 3080] train loss: 0.5916, train acc: 0.7872, val loss: 0.3677, val acc: 0.9046  (best train acc: 0.7985, best val acc: 0.9099, best train loss: 0.5717)
# [Epoch: 3100] train loss: 0.6018, train acc: 0.7723, val loss: 0.3467, val acc: 0.9062  (best train acc: 0.7985, best val acc: 0.9099, best train loss: 0.5660)
# [Epoch: 3120] train loss: 0.6272, train acc: 0.7482, val loss: 0.3402, val acc: 0.9096  (best train acc: 0.7985, best val acc: 0.9099, best train loss: 0.5660)
# [Epoch: 3140] train loss: 0.6331, train acc: 0.7508, val loss: 0.3345, val acc: 0.9093  (best train acc: 0.7985, best val acc: 0.9099, best train loss: 0.5660)
# [Epoch: 3160] train loss: 0.6040, train acc: 0.7760, val loss: 0.3277, val acc: 0.9079  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3180] train loss: 0.6149, train acc: 0.7646, val loss: 0.3509, val acc: 0.8978  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3200] train loss: 0.6147, train acc: 0.7556, val loss: 0.3397, val acc: 0.9052  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3220] train loss: 0.5988, train acc: 0.7823, val loss: 0.3338, val acc: 0.9086  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3240] train loss: 0.6183, train acc: 0.7657, val loss: 0.3256, val acc: 0.9093  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3260] train loss: 0.6094, train acc: 0.7587, val loss: 0.3347, val acc: 0.9066  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3280] train loss: 0.6111, train acc: 0.7592, val loss: 0.3370, val acc: 0.9066  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3300] train loss: 0.6206, train acc: 0.7580, val loss: 0.3357, val acc: 0.9056  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3320] train loss: 0.6163, train acc: 0.7684, val loss: 0.3440, val acc: 0.9086  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3340] train loss: 0.6460, train acc: 0.7300, val loss: 0.3438, val acc: 0.9015  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3360] train loss: 0.6042, train acc: 0.7628, val loss: 0.3464, val acc: 0.8985  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3380] train loss: 0.6080, train acc: 0.7824, val loss: 0.3516, val acc: 0.9012  (best train acc: 0.7985, best val acc: 0.9103, best train loss: 0.5660)
# [Epoch: 3400] train loss: 0.5619, train acc: 0.7987, val loss: 0.3537, val acc: 0.9012  (best train acc: 0.7987, best val acc: 0.9103, best train loss: 0.5619)
# [Epoch: 3420] train loss: 0.6634, train acc: 0.7175, val loss: 0.3432, val acc: 0.9025  (best train acc: 0.7987, best val acc: 0.9103, best train loss: 0.5619)
# [Epoch: 3440] train loss: 0.6148, train acc: 0.7706, val loss: 0.3398, val acc: 0.8948  (best train acc: 0.8027, best val acc: 0.9103, best train loss: 0.5564)
# [Epoch: 3460] train loss: 0.6089, train acc: 0.7576, val loss: 0.3181, val acc: 0.9079  (best train acc: 0.8027, best val acc: 0.9103, best train loss: 0.5564)
# [Epoch: 3480] train loss: 0.5874, train acc: 0.7830, val loss: 0.3281, val acc: 0.9093  (best train acc: 0.8027, best val acc: 0.9103, best train loss: 0.5564)
# [Epoch: 3500] train loss: 0.5844, train acc: 0.7861, val loss: 0.3324, val acc: 0.9046  (best train acc: 0.8027, best val acc: 0.9110, best train loss: 0.5564)
# [Epoch: 3520] train loss: 0.6667, train acc: 0.7426, val loss: 0.3579, val acc: 0.9062  (best train acc: 0.8027, best val acc: 0.9110, best train loss: 0.5564)
# [Epoch: 3540] train loss: 0.6226, train acc: 0.7490, val loss: 0.3223, val acc: 0.9096  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3560] train loss: 0.6076, train acc: 0.7725, val loss: 0.3357, val acc: 0.9089  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3580] train loss: 0.5800, train acc: 0.7848, val loss: 0.3509, val acc: 0.8867  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3600] train loss: 0.5772, train acc: 0.7908, val loss: 0.3330, val acc: 0.9059  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3620] train loss: 0.6071, train acc: 0.7516, val loss: 0.3289, val acc: 0.9049  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3640] train loss: 0.6008, train acc: 0.7657, val loss: 0.3397, val acc: 0.9062  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3660] train loss: 0.5933, train acc: 0.7714, val loss: 0.3292, val acc: 0.9066  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3680] train loss: 0.6220, train acc: 0.7489, val loss: 0.3225, val acc: 0.9022  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3700] train loss: 0.6320, train acc: 0.7348, val loss: 0.3251, val acc: 0.9066  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3720] train loss: 0.6377, train acc: 0.7416, val loss: 0.3337, val acc: 0.8897  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3740] train loss: 0.5937, train acc: 0.7667, val loss: 0.3259, val acc: 0.9022  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3760] train loss: 0.5756, train acc: 0.7895, val loss: 0.3371, val acc: 0.9022  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3780] train loss: 0.5704, train acc: 0.7840, val loss: 0.3479, val acc: 0.8988  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5564)
# [Epoch: 3800] train loss: 0.5777, train acc: 0.7879, val loss: 0.3227, val acc: 0.9062  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5501)
# [Epoch: 3820] train loss: 0.5896, train acc: 0.7796, val loss: 0.3232, val acc: 0.9083  (best train acc: 0.8027, best val acc: 0.9116, best train loss: 0.5501)
# [Epoch: 3840] train loss: 0.6634, train acc: 0.7119, val loss: 0.3185, val acc: 0.9083  (best train acc: 0.8027, best val acc: 0.9120, best train loss: 0.5501)
# [Epoch: 3860] train loss: 0.6176, train acc: 0.7639, val loss: 0.3132, val acc: 0.9103  (best train acc: 0.8027, best val acc: 0.9120, best train loss: 0.5501)
# [Epoch: 3880] train loss: 0.6306, train acc: 0.7355, val loss: 0.3129, val acc: 0.9083  (best train acc: 0.8027, best val acc: 0.9120, best train loss: 0.5501)
# [Epoch: 3900] train loss: 0.6084, train acc: 0.7605, val loss: 0.3401, val acc: 0.8931  (best train acc: 0.8027, best val acc: 0.9120, best train loss: 0.5501)
# [Epoch: 3920] train loss: 0.5787, train acc: 0.7799, val loss: 0.3379, val acc: 0.8988  (best train acc: 0.8027, best val acc: 0.9120, best train loss: 0.5501)
# [Epoch: 3940] train loss: 0.5672, train acc: 0.7822, val loss: 0.3360, val acc: 0.8874  (best train acc: 0.8027, best val acc: 0.9120, best train loss: 0.5501)
# [Epoch: 3960] train loss: 0.5727, train acc: 0.7731, val loss: 0.3081, val acc: 0.9110  (best train acc: 0.8027, best val acc: 0.9120, best train loss: 0.5501)
# [Epoch: 3980] train loss: 0.5732, train acc: 0.7820, val loss: 0.3251, val acc: 0.9079  (best train acc: 0.8027, best val acc: 0.9120, best train loss: 0.5465)
# [Epoch: 4000] train loss: 0.5768, train acc: 0.7776, val loss: 0.3276, val acc: 0.9096  (best train acc: 0.8124, best val acc: 0.9120, best train loss: 0.5268)
# [Epoch: 4020] train loss: 0.5573, train acc: 0.7950, val loss: 0.3268, val acc: 0.9046  (best train acc: 0.8124, best val acc: 0.9120, best train loss: 0.5268)
# [Epoch: 4040] train loss: 0.5561, train acc: 0.7918, val loss: 0.3242, val acc: 0.9073  (best train acc: 0.8124, best val acc: 0.9123, best train loss: 0.5268)
# [Epoch: 4060] train loss: 0.5263, train acc: 0.8083, val loss: 0.3214, val acc: 0.9076  (best train acc: 0.8124, best val acc: 0.9123, best train loss: 0.5263)
# [Epoch: 4080] train loss: 0.5450, train acc: 0.7957, val loss: 0.3283, val acc: 0.9022  (best train acc: 0.8124, best val acc: 0.9123, best train loss: 0.5263)
# [Epoch: 4100] train loss: 0.5426, train acc: 0.8022, val loss: 0.3165, val acc: 0.9069  (best train acc: 0.8145, best val acc: 0.9123, best train loss: 0.5260)
# [Epoch: 4120] train loss: 0.5457, train acc: 0.7989, val loss: 0.3186, val acc: 0.9022  (best train acc: 0.8145, best val acc: 0.9123, best train loss: 0.5245)
# [Epoch: 4140] train loss: 0.5501, train acc: 0.7880, val loss: 0.3246, val acc: 0.9079  (best train acc: 0.8147, best val acc: 0.9123, best train loss: 0.5182)
# [Epoch: 4160] train loss: 0.5509, train acc: 0.7914, val loss: 0.3296, val acc: 0.8954  (best train acc: 0.8147, best val acc: 0.9123, best train loss: 0.5182)
# [Epoch: 4180] train loss: 0.5319, train acc: 0.8084, val loss: 0.3160, val acc: 0.9032  (best train acc: 0.8147, best val acc: 0.9123, best train loss: 0.5182)
# [Epoch: 4200] train loss: 0.5709, train acc: 0.7846, val loss: 0.3223, val acc: 0.9093  (best train acc: 0.8147, best val acc: 0.9123, best train loss: 0.5182)
# [Epoch: 4220] train loss: 0.5640, train acc: 0.7838, val loss: 0.3212, val acc: 0.9089  (best train acc: 0.8172, best val acc: 0.9123, best train loss: 0.5160)
# [Epoch: 4240] train loss: 0.5487, train acc: 0.7921, val loss: 0.3043, val acc: 0.9110  (best train acc: 0.8172, best val acc: 0.9123, best train loss: 0.5159)
# [Epoch: 4260] train loss: 0.6014, train acc: 0.7598, val loss: 0.3142, val acc: 0.9110  (best train acc: 0.8178, best val acc: 0.9123, best train loss: 0.5132)
# [Epoch: 4280] train loss: 0.5316, train acc: 0.8034, val loss: 0.3334, val acc: 0.9025  (best train acc: 0.8178, best val acc: 0.9123, best train loss: 0.5132)
# [Epoch: 4300] train loss: 0.5540, train acc: 0.7835, val loss: 0.3203, val acc: 0.9056  (best train acc: 0.8178, best val acc: 0.9123, best train loss: 0.5132)
# [Epoch: 4320] train loss: 0.5185, train acc: 0.8039, val loss: 0.3096, val acc: 0.9059  (best train acc: 0.8178, best val acc: 0.9123, best train loss: 0.5072)
# [Epoch: 4340] train loss: 0.5505, train acc: 0.7921, val loss: 0.3125, val acc: 0.9052  (best train acc: 0.8178, best val acc: 0.9123, best train loss: 0.5072)
# [Epoch: 4360] train loss: 0.5182, train acc: 0.8081, val loss: 0.3361, val acc: 0.8961  (best train acc: 0.8178, best val acc: 0.9123, best train loss: 0.5072)
# [Epoch: 4380] train loss: 0.5503, train acc: 0.7919, val loss: 0.3162, val acc: 0.9086  (best train acc: 0.8178, best val acc: 0.9123, best train loss: 0.5072)
# [Epoch: 4400] train loss: 0.5496, train acc: 0.7950, val loss: 0.3146, val acc: 0.9076  (best train acc: 0.8183, best val acc: 0.9123, best train loss: 0.5067)
# [Epoch: 4420] train loss: 0.5256, train acc: 0.7936, val loss: 0.3161, val acc: 0.9046  (best train acc: 0.8183, best val acc: 0.9123, best train loss: 0.5067)
# [Epoch: 4440] train loss: 0.5201, train acc: 0.8100, val loss: 0.3135, val acc: 0.9059  (best train acc: 0.8183, best val acc: 0.9123, best train loss: 0.5044)
# [Epoch: 4460] train loss: 0.5344, train acc: 0.7910, val loss: 0.3120, val acc: 0.9079  (best train acc: 0.8183, best val acc: 0.9123, best train loss: 0.5044)
# [Epoch: 4480] train loss: 0.5176, train acc: 0.8095, val loss: 0.3203, val acc: 0.8975  (best train acc: 0.8183, best val acc: 0.9123, best train loss: 0.5022)
# [Epoch: 4500] train loss: 0.5550, train acc: 0.7736, val loss: 0.3122, val acc: 0.9089  (best train acc: 0.8183, best val acc: 0.9123, best train loss: 0.5000)
# [Epoch: 4520] train loss: 0.5211, train acc: 0.8029, val loss: 0.3191, val acc: 0.8951  (best train acc: 0.8185, best val acc: 0.9123, best train loss: 0.5000)
# [Epoch: 4540] train loss: 0.5070, train acc: 0.8039, val loss: 0.3068, val acc: 0.9046  (best train acc: 0.8185, best val acc: 0.9123, best train loss: 0.5000)
# [Epoch: 4560] train loss: 0.5303, train acc: 0.7959, val loss: 0.3165, val acc: 0.9025  (best train acc: 0.8202, best val acc: 0.9123, best train loss: 0.4942)
# [Epoch: 4580] train loss: 0.5446, train acc: 0.7820, val loss: 0.3098, val acc: 0.9076  (best train acc: 0.8202, best val acc: 0.9123, best train loss: 0.4942)
# [Epoch: 4600] train loss: 0.5116, train acc: 0.8096, val loss: 0.3148, val acc: 0.9049  (best train acc: 0.8222, best val acc: 0.9123, best train loss: 0.4941)
# [Epoch: 4620] train loss: 0.5250, train acc: 0.8031, val loss: 0.3241, val acc: 0.9015  (best train acc: 0.8258, best val acc: 0.9123, best train loss: 0.4882)
# [Epoch: 4640] train loss: 0.4959, train acc: 0.8132, val loss: 0.3038, val acc: 0.9096  (best train acc: 0.8258, best val acc: 0.9123, best train loss: 0.4882)
# [Epoch: 4660] train loss: 0.5066, train acc: 0.8047, val loss: 0.3038, val acc: 0.9103  (best train acc: 0.8258, best val acc: 0.9123, best train loss: 0.4882)
# [Epoch: 4680] train loss: 0.4793, train acc: 0.8283, val loss: 0.3252, val acc: 0.8978  (best train acc: 0.8283, best val acc: 0.9123, best train loss: 0.4793)
# [Epoch: 4700] train loss: 0.5341, train acc: 0.7926, val loss: 0.3186, val acc: 0.9005  (best train acc: 0.8283, best val acc: 0.9123, best train loss: 0.4793)
# [Epoch: 4720] train loss: 0.4992, train acc: 0.8159, val loss: 0.3036, val acc: 0.9089  (best train acc: 0.8283, best val acc: 0.9130, best train loss: 0.4793)
# [Epoch: 4740] train loss: 0.5025, train acc: 0.8062, val loss: 0.2985, val acc: 0.9120  (best train acc: 0.8283, best val acc: 0.9130, best train loss: 0.4793)
# [Epoch: 4760] train loss: 0.5010, train acc: 0.8128, val loss: 0.3107, val acc: 0.8998  (best train acc: 0.8283, best val acc: 0.9140, best train loss: 0.4793)
# [Epoch: 4780] train loss: 0.4995, train acc: 0.8151, val loss: 0.2999, val acc: 0.9120  (best train acc: 0.8283, best val acc: 0.9140, best train loss: 0.4793)
# [Epoch: 4800] train loss: 0.5450, train acc: 0.7827, val loss: 0.3000, val acc: 0.9076  (best train acc: 0.8283, best val acc: 0.9140, best train loss: 0.4793)
# [Epoch: 4820] train loss: 0.5065, train acc: 0.8133, val loss: 0.3093, val acc: 0.9086  (best train acc: 0.8283, best val acc: 0.9140, best train loss: 0.4793)
# [Epoch: 4840] train loss: 0.5017, train acc: 0.8206, val loss: 0.3051, val acc: 0.9039  (best train acc: 0.8283, best val acc: 0.9140, best train loss: 0.4793)
# [Epoch: 4860] train loss: 0.5372, train acc: 0.7882, val loss: 0.3166, val acc: 0.8921  (best train acc: 0.8283, best val acc: 0.9140, best train loss: 0.4793)
# [Epoch: 4880] train loss: 0.5161, train acc: 0.8044, val loss: 0.3242, val acc: 0.8853  (best train acc: 0.8283, best val acc: 0.9140, best train loss: 0.4793)
# [Epoch: 4900] train loss: 0.5129, train acc: 0.8007, val loss: 0.3035, val acc: 0.9099  (best train acc: 0.8283, best val acc: 0.9140, best train loss: 0.4793)
# [Epoch: 4920] train loss: 0.5084, train acc: 0.7992, val loss: 0.2986, val acc: 0.9066  (best train acc: 0.8291, best val acc: 0.9140, best train loss: 0.4793)
# [Epoch: 4940] train loss: 0.5208, train acc: 0.7973, val loss: 0.3243, val acc: 0.8887  (best train acc: 0.8291, best val acc: 0.9140, best train loss: 0.4793)
# [Epoch: 4960] train loss: 0.5010, train acc: 0.8088, val loss: 0.2955, val acc: 0.9106  (best train acc: 0.8291, best val acc: 0.9140, best train loss: 0.4793)
# [Epoch: 4980] train loss: 0.5284, train acc: 0.7926, val loss: 0.3140, val acc: 0.9032  (best train acc: 0.8325, best val acc: 0.9140, best train loss: 0.4787)
# [Epoch: 5000] train loss: 0.5043, train acc: 0.8044, val loss: 0.3189, val acc: 0.8860  (best train acc: 0.8325, best val acc: 0.9140, best train loss: 0.4787)
# [Epoch: 5020] train loss: 0.5329, train acc: 0.7887, val loss: 0.3027, val acc: 0.9046  (best train acc: 0.8325, best val acc: 0.9140, best train loss: 0.4787)
# [Epoch: 5040] train loss: 0.5358, train acc: 0.7949, val loss: 0.3042, val acc: 0.9113  (best train acc: 0.8325, best val acc: 0.9140, best train loss: 0.4787)
# [Epoch: 5060] train loss: 0.5123, train acc: 0.8055, val loss: 0.3032, val acc: 0.9069  (best train acc: 0.8325, best val acc: 0.9140, best train loss: 0.4787)
# [Epoch: 5080] train loss: 0.5217, train acc: 0.7919, val loss: 0.3004, val acc: 0.9083  (best train acc: 0.8325, best val acc: 0.9140, best train loss: 0.4787)
# [Epoch: 5100] train loss: 0.4947, train acc: 0.8142, val loss: 0.2968, val acc: 0.9113  (best train acc: 0.8325, best val acc: 0.9140, best train loss: 0.4787)
# [Epoch: 5120] train loss: 0.4980, train acc: 0.8025, val loss: 0.2949, val acc: 0.9113  (best train acc: 0.8325, best val acc: 0.9140, best train loss: 0.4787)
# [Epoch: 5140] train loss: 0.4932, train acc: 0.8061, val loss: 0.2995, val acc: 0.9116  (best train acc: 0.8325, best val acc: 0.9140, best train loss: 0.4787)
# [Epoch: 5160] train loss: 0.5422, train acc: 0.7842, val loss: 0.2929, val acc: 0.9123  (best train acc: 0.8325, best val acc: 0.9140, best train loss: 0.4787)
# [Epoch: 5180] train loss: 0.4972, train acc: 0.8098, val loss: 0.2958, val acc: 0.9140  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4787)
# [Epoch: 5200] train loss: 0.5279, train acc: 0.7991, val loss: 0.3113, val acc: 0.9032  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4728)
# [Epoch: 5220] train loss: 0.5055, train acc: 0.8132, val loss: 0.3029, val acc: 0.9073  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4728)
# [Epoch: 5240] train loss: 0.5096, train acc: 0.8138, val loss: 0.2923, val acc: 0.9137  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4722)
# [Epoch: 5260] train loss: 0.4815, train acc: 0.8161, val loss: 0.3056, val acc: 0.8998  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4722)
# [Epoch: 5280] train loss: 0.4957, train acc: 0.8133, val loss: 0.3397, val acc: 0.8786  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4688)
# [Epoch: 5300] train loss: 0.5109, train acc: 0.8026, val loss: 0.3065, val acc: 0.8985  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4688)
# [Epoch: 5320] train loss: 0.5118, train acc: 0.7940, val loss: 0.2964, val acc: 0.9150  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4688)
# [Epoch: 5340] train loss: 0.4787, train acc: 0.8247, val loss: 0.2984, val acc: 0.9106  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4688)
# [Epoch: 5360] train loss: 0.4828, train acc: 0.8150, val loss: 0.2999, val acc: 0.9069  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4688)
# [Epoch: 5380] train loss: 0.5232, train acc: 0.7952, val loss: 0.2915, val acc: 0.9110  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4688)
# [Epoch: 5400] train loss: 0.5026, train acc: 0.8120, val loss: 0.2957, val acc: 0.9079  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4688)
# [Epoch: 5420] train loss: 0.5164, train acc: 0.7948, val loss: 0.3010, val acc: 0.9039  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4688)
# [Epoch: 5440] train loss: 0.5257, train acc: 0.7912, val loss: 0.3005, val acc: 0.9096  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4688)
# [Epoch: 5460] train loss: 0.4879, train acc: 0.8128, val loss: 0.2972, val acc: 0.9093  (best train acc: 0.8325, best val acc: 0.9150, best train loss: 0.4672)
# [Epoch: 5480] train loss: 0.5002, train acc: 0.8079, val loss: 0.2984, val acc: 0.9103  (best train acc: 0.8325, best val acc: 0.9157, best train loss: 0.4672)
# [Epoch: 5500] train loss: 0.4860, train acc: 0.8188, val loss: 0.2885, val acc: 0.9110  (best train acc: 0.8390, best val acc: 0.9157, best train loss: 0.4672)
# [Epoch: 5520] train loss: 0.4942, train acc: 0.8138, val loss: 0.2974, val acc: 0.9130  (best train acc: 0.8390, best val acc: 0.9157, best train loss: 0.4672)
# [Epoch: 5540] train loss: 0.4859, train acc: 0.8207, val loss: 0.3020, val acc: 0.9069  (best train acc: 0.8390, best val acc: 0.9157, best train loss: 0.4672)
# [Epoch: 5560] train loss: 0.4823, train acc: 0.8206, val loss: 0.2990, val acc: 0.9056  (best train acc: 0.8390, best val acc: 0.9157, best train loss: 0.4665)
# [Epoch: 5580] train loss: 0.4817, train acc: 0.8325, val loss: 0.2981, val acc: 0.9093  (best train acc: 0.8390, best val acc: 0.9157, best train loss: 0.4656)
# [Epoch: 5600] train loss: 0.4997, train acc: 0.8088, val loss: 0.2964, val acc: 0.9137  (best train acc: 0.8390, best val acc: 0.9157, best train loss: 0.4656)
# [Epoch: 5620] train loss: 0.4896, train acc: 0.8109, val loss: 0.2969, val acc: 0.9123  (best train acc: 0.8390, best val acc: 0.9157, best train loss: 0.4656)
# [Epoch: 5640] train loss: 0.4874, train acc: 0.8096, val loss: 0.2884, val acc: 0.9130  (best train acc: 0.8390, best val acc: 0.9157, best train loss: 0.4656)
# [Epoch: 5660] train loss: 0.4896, train acc: 0.8081, val loss: 0.2920, val acc: 0.9130  (best train acc: 0.8390, best val acc: 0.9157, best train loss: 0.4656)
# [Epoch: 5680] train loss: 0.4755, train acc: 0.8206, val loss: 0.2975, val acc: 0.9103  (best train acc: 0.8390, best val acc: 0.9157, best train loss: 0.4656)
# [Epoch: 5700] train loss: 0.5107, train acc: 0.7978, val loss: 0.2877, val acc: 0.9120  (best train acc: 0.8435, best val acc: 0.9157, best train loss: 0.4535)
# [Epoch: 5720] train loss: 0.5207, train acc: 0.7861, val loss: 0.3044, val acc: 0.8958  (best train acc: 0.8435, best val acc: 0.9157, best train loss: 0.4535)
# [Epoch: 5740] train loss: 0.4937, train acc: 0.8143, val loss: 0.2993, val acc: 0.9083  (best train acc: 0.8435, best val acc: 0.9160, best train loss: 0.4535)
# [Epoch: 5760] train loss: 0.4964, train acc: 0.8046, val loss: 0.2852, val acc: 0.9153  (best train acc: 0.8435, best val acc: 0.9160, best train loss: 0.4535)
# [Epoch: 5780] train loss: 0.4958, train acc: 0.8079, val loss: 0.2928, val acc: 0.9106  (best train acc: 0.8435, best val acc: 0.9160, best train loss: 0.4535)
# [Epoch: 5800] train loss: 0.5116, train acc: 0.8008, val loss: 0.2947, val acc: 0.9123  (best train acc: 0.8435, best val acc: 0.9160, best train loss: 0.4535)
# [Epoch: 5820] train loss: 0.4713, train acc: 0.8188, val loss: 0.2948, val acc: 0.9103  (best train acc: 0.8435, best val acc: 0.9160, best train loss: 0.4535)
# [Epoch: 5840] train loss: 0.4891, train acc: 0.8200, val loss: 0.2919, val acc: 0.9130  (best train acc: 0.8435, best val acc: 0.9164, best train loss: 0.4525)
# [Epoch: 5860] train loss: 0.5213, train acc: 0.8041, val loss: 0.2900, val acc: 0.9076  (best train acc: 0.8435, best val acc: 0.9164, best train loss: 0.4525)
# [Epoch: 5880] train loss: 0.5122, train acc: 0.7896, val loss: 0.3009, val acc: 0.9076  (best train acc: 0.8435, best val acc: 0.9164, best train loss: 0.4525)
# [Epoch: 5900] train loss: 0.5178, train acc: 0.8043, val loss: 0.2944, val acc: 0.9103  (best train acc: 0.8435, best val acc: 0.9164, best train loss: 0.4525)
# [Epoch: 5920] train loss: 0.5013, train acc: 0.8111, val loss: 0.2899, val acc: 0.9150  (best train acc: 0.8435, best val acc: 0.9164, best train loss: 0.4525)
# [Epoch: 5940] train loss: 0.5148, train acc: 0.8055, val loss: 0.2917, val acc: 0.9110  (best train acc: 0.8435, best val acc: 0.9164, best train loss: 0.4525)
# [Epoch: 5960] train loss: 0.5355, train acc: 0.7983, val loss: 0.3088, val acc: 0.9035  (best train acc: 0.8435, best val acc: 0.9164, best train loss: 0.4525)
# ...
# [Epoch: 38100] train loss: 0.1594, train acc: 0.9398, val loss: 0.3985, val acc: 0.9511  (best train acc: 0.9445, best val acc: 0.9555, best train loss: 0.1552)
# [Epoch: 38120] train loss: 0.1808, train acc: 0.9271, val loss: 0.3795, val acc: 0.9497  (best train acc: 0.9446, best val acc: 0.9555, best train loss: 0.1539)
# [Epoch: 38140] train loss: 0.1877, train acc: 0.9346, val loss: 0.4264, val acc: 0.9319  (best train acc: 0.9446, best val acc: 0.9555, best train loss: 0.1539)
# [Epoch: 38160] train loss: 0.2055, train acc: 0.9179, val loss: 0.3883, val acc: 0.9417  (best train acc: 0.9446, best val acc: 0.9555, best train loss: 0.1539)
# [Epoch: 38180] train loss: 0.1736, train acc: 0.9378, val loss: 0.4511, val acc: 0.9511  (best train acc: 0.9446, best val acc: 0.9555, best train loss: 0.1539)
# [Epoch: 38200] train loss: 0.1555, train acc: 0.9436, val loss: 0.4082, val acc: 0.9521  (best train acc: 0.9446, best val acc: 0.9555, best train loss: 0.1539)
# [Epoch: 38220] train loss: 0.1751, train acc: 0.9360, val loss: 0.4143, val acc: 0.9535  (best train acc: 0.9446, best val acc: 0.9555, best train loss: 0.1539)
# [Epoch: 38240] train loss: 0.1609, train acc: 0.9383, val loss: 0.3855, val acc: 0.9514  (best train acc: 0.9446, best val acc: 0.9562, best train loss: 0.1539)
# [Epoch: 38260] train loss: 0.1578, train acc: 0.9414, val loss: 0.3903, val acc: 0.9484  (best train acc: 0.9446, best val acc: 0.9562, best train loss: 0.1539)
# [Epoch: 38280] train loss: 0.1627, train acc: 0.9400, val loss: 0.3335, val acc: 0.9524  (best train acc: 0.9446, best val acc: 0.9562, best train loss: 0.1535)
# [Epoch: 38300] train loss: 0.1608, train acc: 0.9400, val loss: 0.3405, val acc: 0.9511  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1535)
# [Epoch: 38320] train loss: 0.1620, train acc: 0.9422, val loss: 0.3624, val acc: 0.9514  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1535)
# [Epoch: 38340] train loss: 0.1651, train acc: 0.9366, val loss: 0.3639, val acc: 0.9538  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1535)
# [Epoch: 38360] train loss: 0.1715, train acc: 0.9370, val loss: 0.3598, val acc: 0.9501  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1535)
# [Epoch: 38380] train loss: 0.1633, train acc: 0.9366, val loss: 0.3385, val acc: 0.9521  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38400] train loss: 0.1570, train acc: 0.9404, val loss: 0.3686, val acc: 0.9518  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38420] train loss: 0.1748, train acc: 0.9333, val loss: 0.3300, val acc: 0.9508  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38440] train loss: 0.1629, train acc: 0.9388, val loss: 0.3830, val acc: 0.9491  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38460] train loss: 0.1684, train acc: 0.9385, val loss: 0.3664, val acc: 0.9504  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38480] train loss: 0.1685, train acc: 0.9332, val loss: 0.3824, val acc: 0.9504  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38500] train loss: 0.1569, train acc: 0.9425, val loss: 0.3592, val acc: 0.9514  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38520] train loss: 0.1638, train acc: 0.9406, val loss: 0.3767, val acc: 0.9514  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38540] train loss: 0.1666, train acc: 0.9382, val loss: 0.3342, val acc: 0.9491  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38560] train loss: 0.1721, train acc: 0.9356, val loss: 0.3944, val acc: 0.9481  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38580] train loss: 0.1713, train acc: 0.9358, val loss: 0.3382, val acc: 0.9437  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38600] train loss: 0.1670, train acc: 0.9387, val loss: 0.3392, val acc: 0.9497  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38620] train loss: 0.1643, train acc: 0.9388, val loss: 0.3580, val acc: 0.9514  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38640] train loss: 0.1696, train acc: 0.9388, val loss: 0.3561, val acc: 0.9541  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38660] train loss: 0.1684, train acc: 0.9362, val loss: 0.3424, val acc: 0.9494  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38680] train loss: 0.1576, train acc: 0.9431, val loss: 0.3728, val acc: 0.9487  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38700] train loss: 0.1608, train acc: 0.9409, val loss: 0.3892, val acc: 0.9511  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38720] train loss: 0.1580, train acc: 0.9414, val loss: 0.3861, val acc: 0.9504  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38740] train loss: 0.1875, train acc: 0.9297, val loss: 0.4059, val acc: 0.9477  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38760] train loss: 0.1545, train acc: 0.9399, val loss: 0.3502, val acc: 0.9521  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38780] train loss: 0.1753, train acc: 0.9351, val loss: 0.4029, val acc: 0.9497  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38800] train loss: 0.1807, train acc: 0.9297, val loss: 0.3427, val acc: 0.9508  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38820] train loss: 0.1686, train acc: 0.9373, val loss: 0.3594, val acc: 0.9535  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38840] train loss: 0.1680, train acc: 0.9393, val loss: 0.3519, val acc: 0.9504  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38860] train loss: 0.1650, train acc: 0.9364, val loss: 0.3565, val acc: 0.9484  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38880] train loss: 0.1732, train acc: 0.9357, val loss: 0.3685, val acc: 0.9535  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38900] train loss: 0.1664, train acc: 0.9392, val loss: 0.3405, val acc: 0.9528  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38920] train loss: 0.1729, train acc: 0.9370, val loss: 0.3644, val acc: 0.9528  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38940] train loss: 0.1633, train acc: 0.9396, val loss: 0.3522, val acc: 0.9474  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38960] train loss: 0.1551, train acc: 0.9419, val loss: 0.3307, val acc: 0.9524  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 38980] train loss: 0.1561, train acc: 0.9422, val loss: 0.3588, val acc: 0.9521  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1529)
# [Epoch: 39000] train loss: 0.1616, train acc: 0.9377, val loss: 0.3589, val acc: 0.9511  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39020] train loss: 0.1793, train acc: 0.9341, val loss: 0.3407, val acc: 0.9491  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39040] train loss: 0.1732, train acc: 0.9356, val loss: 0.3308, val acc: 0.9508  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39060] train loss: 0.1623, train acc: 0.9388, val loss: 0.3559, val acc: 0.9497  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39080] train loss: 0.1693, train acc: 0.9372, val loss: 0.3603, val acc: 0.9531  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39100] train loss: 0.1631, train acc: 0.9369, val loss: 0.3577, val acc: 0.9511  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39120] train loss: 0.1643, train acc: 0.9391, val loss: 0.3596, val acc: 0.9410  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39140] train loss: 0.1686, train acc: 0.9379, val loss: 0.3614, val acc: 0.9511  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39160] train loss: 0.2115, train acc: 0.9198, val loss: 0.3246, val acc: 0.9497  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39180] train loss: 0.1564, train acc: 0.9422, val loss: 0.4016, val acc: 0.9518  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39200] train loss: 0.1611, train acc: 0.9393, val loss: 0.4122, val acc: 0.9524  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39220] train loss: 0.1633, train acc: 0.9385, val loss: 0.3869, val acc: 0.9497  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1516)
# [Epoch: 39240] train loss: 0.1578, train acc: 0.9421, val loss: 0.4085, val acc: 0.9545  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1514)
# [Epoch: 39260] train loss: 0.1735, train acc: 0.9335, val loss: 0.3793, val acc: 0.9511  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1514)
# [Epoch: 39280] train loss: 0.1620, train acc: 0.9403, val loss: 0.3825, val acc: 0.9535  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1514)
# [Epoch: 39300] train loss: 0.1564, train acc: 0.9417, val loss: 0.3777, val acc: 0.9504  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39320] train loss: 0.1623, train acc: 0.9402, val loss: 0.3537, val acc: 0.9494  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39340] train loss: 0.1627, train acc: 0.9374, val loss: 0.3414, val acc: 0.9528  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39360] train loss: 0.1819, train acc: 0.9299, val loss: 0.3581, val acc: 0.9545  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39380] train loss: 0.1560, train acc: 0.9432, val loss: 0.3650, val acc: 0.9430  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39400] train loss: 0.1721, train acc: 0.9340, val loss: 0.3382, val acc: 0.9406  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39420] train loss: 0.1743, train acc: 0.9367, val loss: 0.3257, val acc: 0.9511  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39440] train loss: 0.1596, train acc: 0.9389, val loss: 0.3534, val acc: 0.9444  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39460] train loss: 0.1613, train acc: 0.9401, val loss: 0.3738, val acc: 0.9521  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39480] train loss: 0.1623, train acc: 0.9389, val loss: 0.3744, val acc: 0.9524  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39500] train loss: 0.1727, train acc: 0.9376, val loss: 0.3600, val acc: 0.9514  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39520] train loss: 0.1747, train acc: 0.9338, val loss: 0.3172, val acc: 0.9521  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39540] train loss: 0.1729, train acc: 0.9388, val loss: 0.3773, val acc: 0.9396  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39560] train loss: 0.1609, train acc: 0.9412, val loss: 0.3395, val acc: 0.9497  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39580] train loss: 0.1583, train acc: 0.9398, val loss: 0.3611, val acc: 0.9541  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39600] train loss: 0.1678, train acc: 0.9376, val loss: 0.3746, val acc: 0.9524  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39620] train loss: 0.1633, train acc: 0.9362, val loss: 0.3837, val acc: 0.9501  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39640] train loss: 0.1665, train acc: 0.9372, val loss: 0.3598, val acc: 0.9545  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1512)
# [Epoch: 39660] train loss: 0.1705, train acc: 0.9358, val loss: 0.3986, val acc: 0.9511  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1503)
# [Epoch: 39680] train loss: 0.1775, train acc: 0.9342, val loss: 0.3799, val acc: 0.9501  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39700] train loss: 0.1853, train acc: 0.9347, val loss: 0.3923, val acc: 0.9460  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39720] train loss: 0.1801, train acc: 0.9352, val loss: 0.3379, val acc: 0.9528  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39740] train loss: 0.1675, train acc: 0.9372, val loss: 0.3430, val acc: 0.9524  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39760] train loss: 0.1609, train acc: 0.9406, val loss: 0.3303, val acc: 0.9524  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39780] train loss: 0.1600, train acc: 0.9406, val loss: 0.3454, val acc: 0.9538  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39800] train loss: 0.1599, train acc: 0.9396, val loss: 0.3292, val acc: 0.9504  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39820] train loss: 0.1551, train acc: 0.9412, val loss: 0.3594, val acc: 0.9535  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39840] train loss: 0.1559, train acc: 0.9423, val loss: 0.3769, val acc: 0.9531  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39860] train loss: 0.1641, train acc: 0.9374, val loss: 0.3747, val acc: 0.9524  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39880] train loss: 0.1596, train acc: 0.9427, val loss: 0.3598, val acc: 0.9494  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39900] train loss: 0.1638, train acc: 0.9369, val loss: 0.3911, val acc: 0.9531  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39920] train loss: 0.1645, train acc: 0.9362, val loss: 0.3095, val acc: 0.9524  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39940] train loss: 0.1681, train acc: 0.9365, val loss: 0.3211, val acc: 0.9521  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39960] train loss: 0.1698, train acc: 0.9385, val loss: 0.3641, val acc: 0.9535  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 39980] train loss: 0.1626, train acc: 0.9396, val loss: 0.3760, val acc: 0.9528  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
# [Epoch: 40000] train loss: 0.1618, train acc: 0.9375, val loss: 0.3643, val acc: 0.9528  (best train acc: 0.9456, best val acc: 0.9562, best train loss: 0.1488)
#               precision    recall  f1-score   support
#
#            0       0.89      0.77      0.83       154
#            1       0.96      0.98      0.97       703
#            2       0.91      0.93      0.92       702
#            3       0.94      0.92      0.93       703
#            4       0.99      1.00      0.99       702
#
#     accuracy                           0.95      2964
#    macro avg       0.94      0.92      0.93      2964
# weighted avg       0.95      0.95      0.95      2964

# %% [markdown]
# ## Packets

# %%
import random
import numpy as np
import pandas as pd
import seaborn as sn
import networkx as nx
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric
from torch_geometric.nn.conv import GraphConv
from torch_geometric.utils import from_networkx
from torch_geometric.data import InMemoryDataset

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(torch.__version__)
print(torch_geometric.__version__)
print(device)
# Out:
# 1.11.0
# 2.0.4
# cuda

# %% [markdown]
# ## GNNs

# %%
class GNN7L_GraphConv (nn.Module):
    def __init__(self, data):
        super().__init__()
        self.conv1 = GraphConv(data.num_features, 16, aggr='mean')
        self.conv2 = GraphConv(16, 16, aggr='mean')
        self.conv3 = GraphConv(16, 16, aggr='mean')
        self.conv4 = GraphConv(16, 16, aggr='mean')
        self.conv5 = GraphConv(16, 16, aggr='mean')
        self.conv6 = GraphConv(16, 16, aggr='mean')
        self.conv7 = GraphConv(16, int(data.num_classes), aggr='mean')

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        x = F.relu(self.conv4(x, edge_index))
        x = F.relu(self.conv5(x, edge_index))
        x = F.relu(self.conv6(x, edge_index))
        x = F.dropout(x, training=self.training)
        x = self.conv7(x, edge_index)

        return F.log_softmax(x, dim=1)

# %% [markdown]
# ## Dataset loader

# %%
# Dataset class: it allows to translate a vector (Graph, Attributes, Labels)
# into a dataset compatible with the PyTorch models.
# 
# Parameters:
# - G: NetworkX graph
# - Labels: of the nodes used for classification
# - attributes: List of the nodes' attributes

class MyDataset(InMemoryDataset):
  def __init__(self, G, labels, attributes, num_classes=2):
    super(MyDataset, self).__init__('.', None, None, None)

    # import data from the networkx graph with the attributes of the nodes
    data = from_networkx(G, attributes)
      
    y = torch.from_numpy(labels).type(torch.long)

    data.x = data.x.float()
    data.y = y.clone().detach()
    data.num_classes = num_classes

    # Using train_test_split function from sklearn to stratify train/test/val sets
    indices = range(G.number_of_nodes())
    # Stratified split of train/test/val sets. Returned indices are used to create the masks
    X_train, X_test, y_train, y_test, train_idx, test_idx = train_test_split(data.x, data.y, indices, test_size=0.3, stratify=labels, random_state=42)
    # To create validation set, test set is splitted in half
    X_test, X_val, y_test, y_val, test_idx, val_idx = train_test_split(X_test, y_test, test_idx, test_size=0.5, stratify=y_test, random_state=42)

    n_nodes = G.number_of_nodes()
    train_mask  = torch.zeros(n_nodes, dtype=torch.bool)
    test_mask   = torch.zeros(n_nodes, dtype=torch.bool)
    val_mask    = torch.zeros(n_nodes, dtype=torch.bool)
    
    for idx in train_idx:
      train_mask[idx] = True

    for idx in test_idx:
      test_mask[idx] = True
    
    for idx in val_idx:
      val_mask[idx] = True

    data['train_mask']  = train_mask
    data['test_mask']   = test_mask
    data['val_mask']    = val_mask

    self.data, self.slices = self.collate([data])

# %% [markdown]
# ## Training Function

# %%
def train(model, data, epochs = 200, classes = ['0','1'], lr = 0.001, weight_decay=0, cm_title = 'GNN'):
    title = cm_title + '_' + str(epochs) + '_' + str(weight_decay).replace('.', '_')

    model_path  = 'Models/' + title
    image_path  = 'Images/' + title
    report_path = 'Reports/' + title + '.csv'

    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    train_mask  = data['train_mask']
    test_mask   = data['test_mask']
    val_mask    = data['val_mask']

    labels    = data.y
    output = ''

    # list to plot the train accuracy
    train_acc_curve = []
    train_lss_curve = []

    best_train_acc  = 0
    best_val_acc    = 0
    # best_test_acc   = 0
    best_train_lss  = 999

    for e in tqdm(range(epochs+1)):
        model.train()
        optimizer.zero_grad()
        logits      = model(data)
        output      = logits.argmax(1)
        # train_loss  = F.cross_entropy(logits[train_mask], labels[train_mask])
        train_loss  = F.nll_loss(logits[train_mask], labels[train_mask])
        train_acc   = (output[train_mask] == labels[train_mask]).float().mean()
        train_loss.backward()
        optimizer.step()

        # Append train acc. to plot curve later
        train_acc_curve.append(train_acc.item())
        train_lss_curve.append(train_loss.item())

        if train_acc > best_train_acc:
            best_train_acc = train_acc

        # Evaluation and test
        model.eval()
        logits      = model(data)
        output      = logits.argmax(1)
        # val_loss    = F.cross_entropy(logits[val_mask], labels[val_mask])
        val_loss    = F.nll_loss(logits[val_mask], labels[val_mask])
        val_acc     = (output[val_mask] == labels[val_mask]).float().mean()
        # test_acc    = (output[test_mask] == labels[test_mask]).float().mean()

        # Update best test/val acc.
        if val_acc > best_val_acc:
            best_val_acc = val_acc
        
        # if test_acc > best_test_acc:
        #     best_test_acc = test_acc
        
        # Save model with best train loss
        if train_loss < best_train_lss:
            best_train_lss = train_loss
            torch.save(model.state_dict(), model_path)

        if e % 20 == 0 or e == epochs:
            print('[Epoch: {:04d}]'.format(e),
            'train loss: {:.4f},'.format(train_loss.item()),
            'train acc: {:.4f},'.format(train_acc.item()),
            'val loss: {:.4f},'.format(val_loss.item()),
            'val acc: {:.4f} '.format(val_acc.item()),
            '(best train acc: {:.4f},'.format(best_train_acc.item()),
            'best val acc: {:.4f},'.format(best_val_acc.item()),
            'best train loss: {:.4f})'.format(best_train_lss))
    
    # Plot training accuracy curve
    plt.figure(figsize = (12,7))
    plt.plot(train_acc_curve)
    plt.xlabel('Epoch')
    plt.ylabel('Train Accuracy')
    plt.show()

    plt.figure(figsize = (12,7))
    plt.plot(train_lss_curve)
    plt.xlabel('Epoch')
    plt.ylabel('Train Loss')
    plt.show()

    # Load best model
    loaded_model = GNN7L_GraphConv(data).to(device)
    loaded_model.load_state_dict(torch.load(model_path))
    loaded_model.eval()
    logits = loaded_model(data)
    output = logits.argmax(1)

    print(classification_report(labels[test_mask].to('cpu'), output[test_mask].to('cpu')))

    class_report = classification_report(labels[test_mask].to('cpu'), output[test_mask].to('cpu'), output_dict=True)
    classification_report_dataframe = pd.DataFrame(class_report)
    classification_report_dataframe.to_csv(report_path)

    #Confusion Matrix
    norms = [None, "true"]
    for norm in norms:
        cm = confusion_matrix(labels[test_mask].to('cpu'), output[test_mask].to('cpu'), normalize=norm)

        plt.figure(figsize=(7,7))
        
        if norm == "true":
            sn.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'BuPu', xticklabels = classes, yticklabels = classes)
        else:
            sn.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu', xticklabels = classes, yticklabels = classes)
        plt.title(cm_title)
        plt.ylabel('Actual label')
        plt.xlabel('Predicted label')

        if norm == None:
            plt.savefig(image_path + '_notNorm.png')
        else:
            plt.savefig(image_path + '_Norm.png')

    return output

# %% [markdown]
# ## NeDBIT Multiclass

# %%
G = nx.read_gml('Graphs/graph_with_nedbit.gml')

seed_genes          = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_seed_genes.txt', header=None, sep=' ')
seed_genes.columns  = ["name", "GDA Score"]
seeds_list          = seed_genes["name"].values.tolist()

nedbit_scores = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_features_Score.csv')

# Remove seed genes
nedbit_scores_not_seed = nedbit_scores[~nedbit_scores['name'].isin(seeds_list)]
print(nedbit_scores_not_seed.shape)

# Sort scores for quartile division
nedbit_scores_not_seed = nedbit_scores_not_seed.sort_values(by = "out", ascending = False)
pseudo_labels = pd.qcut(x = nedbit_scores_not_seed["out"], q = 4, labels = ["RN", "LN", "WN", "LP"])

plt.hist(pseudo_labels)
plt.show()
# Out:
# (18736, 2)

# %%
nedbit_scores_not_seed['label'] = pseudo_labels

nedbit_scores_seed = nedbit_scores[nedbit_scores['name'].isin(seeds_list)]
nedbit_scores_seed = nedbit_scores_seed.assign(label = 'P')

# Convert dataframe to dict for searching nodes and their labels
not_seed_labels = dict(zip(nedbit_scores_not_seed['name'], nedbit_scores_not_seed['label']))
seed_labels     = dict(zip(nedbit_scores_seed['name'], nedbit_scores_seed['label']))

labels_dict = {'P':0, 'LP': 1, 'WN': 2, 'LN': 3, 'RN': 4}
labels = []

for node in G:
    if node in not_seed_labels:
        labels.append(labels_dict[not_seed_labels[node]])
    else:
        labels.append(labels_dict[seed_labels[node]])

labels = np.asarray(labels)
len(labels)
# Out:
# 19761

# %%
attributes = ['degree', 'ring', 'NetRank', 'NetShort', 'HeatDiff', 'InfoDiff']

dataset_with_nedbit = MyDataset(G, labels, attributes, num_classes=5)
data_with_nedbit = dataset_with_nedbit[0]

plt.hist(labels)
plt.show()

# %% [markdown]
# ### 7 Layers

# %%
gnn_conv = GNN7L_GraphConv(data_with_nedbit).to(device)
pred = train(gnn_conv, data_with_nedbit.to(device), 40000, cm_title='GraphConv7L_multiclass_16HC', classes=['P', 'LP', 'WN', 'LN', 'RN'], weight_decay=0.0005)
# Out:
#   0%|          | 0/40001 [00:00<?, ?it/s]
# [Epoch: 0000] train loss: 2.4379, train acc: 0.1551, val loss: 1.9707, val acc: 0.2307  (best train acc: 0.1551, best val acc: 0.2307, best train loss: 2.4379)
# [Epoch: 0020] train loss: 1.6020, train acc: 0.2570, val loss: 1.5967, val acc: 0.2526  (best train acc: 0.2570, best val acc: 0.2580, best train loss: 1.6020)
# [Epoch: 0040] train loss: 1.5559, train acc: 0.2827, val loss: 1.5443, val acc: 0.3086  (best train acc: 0.2845, best val acc: 0.3207, best train loss: 1.5559)
# [Epoch: 0060] train loss: 1.5233, train acc: 0.2819, val loss: 1.5023, val acc: 0.2958  (best train acc: 0.2864, best val acc: 0.3444, best train loss: 1.5233)
# [Epoch: 0080] train loss: 1.4882, train acc: 0.3248, val loss: 1.4688, val acc: 0.4121  (best train acc: 0.3248, best val acc: 0.4121, best train loss: 1.4882)
# [Epoch: 0100] train loss: 1.4519, train acc: 0.3754, val loss: 1.4181, val acc: 0.4250  (best train acc: 0.3754, best val acc: 0.4253, best train loss: 1.4519)
# [Epoch: 0120] train loss: 1.4245, train acc: 0.3955, val loss: 1.3881, val acc: 0.4408  (best train acc: 0.3955, best val acc: 0.4438, best train loss: 1.4245)
# [Epoch: 0140] train loss: 1.3940, train acc: 0.4158, val loss: 1.3616, val acc: 0.4489  (best train acc: 0.4158, best val acc: 0.4516, best train loss: 1.3940)
# [Epoch: 0160] train loss: 1.3759, train acc: 0.4337, val loss: 1.3361, val acc: 0.4600  (best train acc: 0.4337, best val acc: 0.4600, best train loss: 1.3719)
# [Epoch: 0180] train loss: 1.3611, train acc: 0.4398, val loss: 1.3169, val acc: 0.4607  (best train acc: 0.4464, best val acc: 0.4627, best train loss: 1.3506)
# [Epoch: 0200] train loss: 1.3373, train acc: 0.4441, val loss: 1.3010, val acc: 0.4688  (best train acc: 0.4495, best val acc: 0.4688, best train loss: 1.3334)
# [Epoch: 0220] train loss: 1.3237, train acc: 0.4533, val loss: 1.2941, val acc: 0.4745  (best train acc: 0.4539, best val acc: 0.4745, best train loss: 1.3237)
# [Epoch: 0240] train loss: 1.3212, train acc: 0.4503, val loss: 1.2806, val acc: 0.4742  (best train acc: 0.4585, best val acc: 0.4786, best train loss: 1.3177)
# [Epoch: 0260] train loss: 1.3120, train acc: 0.4560, val loss: 1.2710, val acc: 0.4772  (best train acc: 0.4623, best val acc: 0.4786, best train loss: 1.3077)
# [Epoch: 0280] train loss: 1.3055, train acc: 0.4565, val loss: 1.2652, val acc: 0.4779  (best train acc: 0.4637, best val acc: 0.4793, best train loss: 1.3040)
# [Epoch: 0300] train loss: 1.3099, train acc: 0.4536, val loss: 1.2593, val acc: 0.4799  (best train acc: 0.4699, best val acc: 0.4830, best train loss: 1.3001)
# [Epoch: 0320] train loss: 1.2980, train acc: 0.4698, val loss: 1.2552, val acc: 0.4782  (best train acc: 0.4699, best val acc: 0.4911, best train loss: 1.2914)
# [Epoch: 0340] train loss: 1.2981, train acc: 0.4579, val loss: 1.2524, val acc: 0.4796  (best train acc: 0.4699, best val acc: 0.4911, best train loss: 1.2898)
# [Epoch: 0360] train loss: 1.2828, train acc: 0.4660, val loss: 1.2500, val acc: 0.4799  (best train acc: 0.4699, best val acc: 0.4911, best train loss: 1.2828)
# [Epoch: 0380] train loss: 1.2905, train acc: 0.4691, val loss: 1.2471, val acc: 0.4860  (best train acc: 0.4719, best val acc: 0.4911, best train loss: 1.2799)
# [Epoch: 0400] train loss: 1.2895, train acc: 0.4672, val loss: 1.2455, val acc: 0.4799  (best train acc: 0.4719, best val acc: 0.4911, best train loss: 1.2799)
# [Epoch: 0420] train loss: 1.2852, train acc: 0.4629, val loss: 1.2421, val acc: 0.4887  (best train acc: 0.4765, best val acc: 0.4968, best train loss: 1.2764)
# [Epoch: 0440] train loss: 1.2841, train acc: 0.4700, val loss: 1.2415, val acc: 0.4816  (best train acc: 0.4765, best val acc: 0.4968, best train loss: 1.2764)
# [Epoch: 0460] train loss: 1.2771, train acc: 0.4720, val loss: 1.2382, val acc: 0.4904  (best train acc: 0.4765, best val acc: 0.4968, best train loss: 1.2736)
# [Epoch: 0480] train loss: 1.2713, train acc: 0.4728, val loss: 1.2362, val acc: 0.4890  (best train acc: 0.4772, best val acc: 0.4968, best train loss: 1.2710)
# [Epoch: 0500] train loss: 1.2769, train acc: 0.4803, val loss: 1.2356, val acc: 0.4840  (best train acc: 0.4803, best val acc: 0.4998, best train loss: 1.2683)
# [Epoch: 0520] train loss: 1.2801, train acc: 0.4648, val loss: 1.2343, val acc: 0.4850  (best train acc: 0.4803, best val acc: 0.5008, best train loss: 1.2683)
# [Epoch: 0540] train loss: 1.2702, train acc: 0.4774, val loss: 1.2335, val acc: 0.4860  (best train acc: 0.4803, best val acc: 0.5008, best train loss: 1.2649)
# [Epoch: 0560] train loss: 1.2729, train acc: 0.4684, val loss: 1.2293, val acc: 0.4911  (best train acc: 0.4803, best val acc: 0.5032, best train loss: 1.2631)
# [Epoch: 0580] train loss: 1.2640, train acc: 0.4686, val loss: 1.2283, val acc: 0.4975  (best train acc: 0.4803, best val acc: 0.5032, best train loss: 1.2617)
# [Epoch: 0600] train loss: 1.2622, train acc: 0.4755, val loss: 1.2281, val acc: 0.4884  (best train acc: 0.4803, best val acc: 0.5046, best train loss: 1.2617)
# [Epoch: 0620] train loss: 1.2661, train acc: 0.4762, val loss: 1.2346, val acc: 0.5002  (best train acc: 0.4803, best val acc: 0.5052, best train loss: 1.2599)
# [Epoch: 0640] train loss: 1.2602, train acc: 0.4808, val loss: 1.2255, val acc: 0.4968  (best train acc: 0.4808, best val acc: 0.5056, best train loss: 1.2579)
# [Epoch: 0660] train loss: 1.2558, train acc: 0.4764, val loss: 1.2239, val acc: 0.4971  (best train acc: 0.4808, best val acc: 0.5056, best train loss: 1.2533)
# [Epoch: 0680] train loss: 1.2624, train acc: 0.4746, val loss: 1.2222, val acc: 0.4961  (best train acc: 0.4808, best val acc: 0.5056, best train loss: 1.2533)
# [Epoch: 0700] train loss: 1.2603, train acc: 0.4793, val loss: 1.2226, val acc: 0.5019  (best train acc: 0.4808, best val acc: 0.5056, best train loss: 1.2533)
# [Epoch: 0720] train loss: 1.2582, train acc: 0.4751, val loss: 1.2205, val acc: 0.4978  (best train acc: 0.4817, best val acc: 0.5056, best train loss: 1.2494)
# [Epoch: 0740] train loss: 1.2550, train acc: 0.4721, val loss: 1.2257, val acc: 0.5039  (best train acc: 0.4817, best val acc: 0.5062, best train loss: 1.2494)
# [Epoch: 0760] train loss: 1.2516, train acc: 0.4746, val loss: 1.2209, val acc: 0.5062  (best train acc: 0.4835, best val acc: 0.5073, best train loss: 1.2494)
# [Epoch: 0780] train loss: 1.2537, train acc: 0.4743, val loss: 1.2217, val acc: 0.4880  (best train acc: 0.4835, best val acc: 0.5073, best train loss: 1.2482)
# [Epoch: 0800] train loss: 1.2514, train acc: 0.4700, val loss: 1.2186, val acc: 0.5002  (best train acc: 0.4848, best val acc: 0.5073, best train loss: 1.2482)
# [Epoch: 0820] train loss: 1.2538, train acc: 0.4784, val loss: 1.2175, val acc: 0.5029  (best train acc: 0.4848, best val acc: 0.5073, best train loss: 1.2444)
# [Epoch: 0840] train loss: 1.2540, train acc: 0.4733, val loss: 1.2196, val acc: 0.5046  (best train acc: 0.4848, best val acc: 0.5073, best train loss: 1.2444)
# [Epoch: 0860] train loss: 1.2536, train acc: 0.4787, val loss: 1.2155, val acc: 0.5005  (best train acc: 0.4848, best val acc: 0.5083, best train loss: 1.2444)
# [Epoch: 0880] train loss: 1.2449, train acc: 0.4801, val loss: 1.2149, val acc: 0.5059  (best train acc: 0.4848, best val acc: 0.5083, best train loss: 1.2439)
# [Epoch: 0900] train loss: 1.2463, train acc: 0.4780, val loss: 1.2131, val acc: 0.5025  (best train acc: 0.4858, best val acc: 0.5083, best train loss: 1.2399)
# [Epoch: 0920] train loss: 1.2449, train acc: 0.4797, val loss: 1.2133, val acc: 0.4961  (best train acc: 0.4858, best val acc: 0.5083, best train loss: 1.2399)
# [Epoch: 0940] train loss: 1.2453, train acc: 0.4819, val loss: 1.2155, val acc: 0.5032  (best train acc: 0.4858, best val acc: 0.5083, best train loss: 1.2399)
# [Epoch: 0960] train loss: 1.2481, train acc: 0.4778, val loss: 1.2151, val acc: 0.4938  (best train acc: 0.4858, best val acc: 0.5083, best train loss: 1.2399)
# [Epoch: 0980] train loss: 1.2449, train acc: 0.4797, val loss: 1.2112, val acc: 0.5042  (best train acc: 0.4859, best val acc: 0.5083, best train loss: 1.2399)
# [Epoch: 1000] train loss: 1.2483, train acc: 0.4790, val loss: 1.2151, val acc: 0.5019  (best train acc: 0.4859, best val acc: 0.5083, best train loss: 1.2396)
# [Epoch: 1020] train loss: 1.2484, train acc: 0.4823, val loss: 1.2174, val acc: 0.4894  (best train acc: 0.4859, best val acc: 0.5083, best train loss: 1.2396)
# [Epoch: 1040] train loss: 1.2438, train acc: 0.4821, val loss: 1.2089, val acc: 0.5032  (best train acc: 0.4864, best val acc: 0.5083, best train loss: 1.2341)
# [Epoch: 1060] train loss: 1.2378, train acc: 0.4851, val loss: 1.2095, val acc: 0.4961  (best train acc: 0.4894, best val acc: 0.5083, best train loss: 1.2341)
# [Epoch: 1080] train loss: 1.2345, train acc: 0.4824, val loss: 1.2081, val acc: 0.5069  (best train acc: 0.4894, best val acc: 0.5086, best train loss: 1.2341)
# [Epoch: 1100] train loss: 1.2383, train acc: 0.4821, val loss: 1.2084, val acc: 0.5059  (best train acc: 0.4894, best val acc: 0.5099, best train loss: 1.2319)
# [Epoch: 1120] train loss: 1.2407, train acc: 0.4777, val loss: 1.2061, val acc: 0.5056  (best train acc: 0.4894, best val acc: 0.5099, best train loss: 1.2319)
# [Epoch: 1140] train loss: 1.2373, train acc: 0.4867, val loss: 1.2057, val acc: 0.5005  (best train acc: 0.4908, best val acc: 0.5099, best train loss: 1.2312)
# [Epoch: 1160] train loss: 1.2344, train acc: 0.4851, val loss: 1.2062, val acc: 0.5052  (best train acc: 0.4908, best val acc: 0.5099, best train loss: 1.2312)
# [Epoch: 1180] train loss: 1.2410, train acc: 0.4774, val loss: 1.2126, val acc: 0.5049  (best train acc: 0.4909, best val acc: 0.5099, best train loss: 1.2279)
# [Epoch: 1200] train loss: 1.2317, train acc: 0.4803, val loss: 1.2046, val acc: 0.4992  (best train acc: 0.4909, best val acc: 0.5123, best train loss: 1.2279)
# [Epoch: 1220] train loss: 1.2356, train acc: 0.4769, val loss: 1.2075, val acc: 0.5069  (best train acc: 0.4909, best val acc: 0.5123, best train loss: 1.2269)
# [Epoch: 1240] train loss: 1.2385, train acc: 0.4843, val loss: 1.2095, val acc: 0.4911  (best train acc: 0.4909, best val acc: 0.5123, best train loss: 1.2269)
# [Epoch: 1260] train loss: 1.2325, train acc: 0.4905, val loss: 1.2031, val acc: 0.5025  (best train acc: 0.4916, best val acc: 0.5123, best train loss: 1.2269)
# [Epoch: 1280] train loss: 1.2313, train acc: 0.4941, val loss: 1.2030, val acc: 0.5059  (best train acc: 0.4941, best val acc: 0.5123, best train loss: 1.2264)
# [Epoch: 1300] train loss: 1.2278, train acc: 0.4845, val loss: 1.2021, val acc: 0.5076  (best train acc: 0.4941, best val acc: 0.5123, best train loss: 1.2233)
# [Epoch: 1320] train loss: 1.2320, train acc: 0.4828, val loss: 1.2013, val acc: 0.5069  (best train acc: 0.4941, best val acc: 0.5123, best train loss: 1.2221)
# [Epoch: 1340] train loss: 1.2287, train acc: 0.4882, val loss: 1.2003, val acc: 0.4971  (best train acc: 0.4941, best val acc: 0.5123, best train loss: 1.2205)
# [Epoch: 1360] train loss: 1.2266, train acc: 0.4851, val loss: 1.2001, val acc: 0.5076  (best train acc: 0.4941, best val acc: 0.5123, best train loss: 1.2205)
# [Epoch: 1380] train loss: 1.2317, train acc: 0.4887, val loss: 1.2053, val acc: 0.5083  (best train acc: 0.4941, best val acc: 0.5123, best train loss: 1.2205)
# [Epoch: 1400] train loss: 1.2312, train acc: 0.4855, val loss: 1.1993, val acc: 0.5025  (best train acc: 0.4941, best val acc: 0.5123, best train loss: 1.2205)
# [Epoch: 1420] train loss: 1.2242, train acc: 0.4873, val loss: 1.2045, val acc: 0.5130  (best train acc: 0.4958, best val acc: 0.5130, best train loss: 1.2205)
# [Epoch: 1440] train loss: 1.2318, train acc: 0.4834, val loss: 1.1985, val acc: 0.5059  (best train acc: 0.4958, best val acc: 0.5130, best train loss: 1.2205)
# [Epoch: 1460] train loss: 1.2369, train acc: 0.4873, val loss: 1.1986, val acc: 0.5012  (best train acc: 0.4958, best val acc: 0.5130, best train loss: 1.2205)
# [Epoch: 1480] train loss: 1.2235, train acc: 0.4926, val loss: 1.1971, val acc: 0.5042  (best train acc: 0.4958, best val acc: 0.5130, best train loss: 1.2205)
# [Epoch: 1500] train loss: 1.2273, train acc: 0.4889, val loss: 1.1961, val acc: 0.5042  (best train acc: 0.4958, best val acc: 0.5130, best train loss: 1.2201)
# [Epoch: 1520] train loss: 1.2265, train acc: 0.4895, val loss: 1.1969, val acc: 0.4981  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2151)
# [Epoch: 1540] train loss: 1.2285, train acc: 0.4873, val loss: 1.1989, val acc: 0.4954  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2151)
# [Epoch: 1560] train loss: 1.2304, train acc: 0.4886, val loss: 1.1982, val acc: 0.4978  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2151)
# [Epoch: 1580] train loss: 1.2228, train acc: 0.4978, val loss: 1.1948, val acc: 0.4978  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2146)
# [Epoch: 1600] train loss: 1.2290, train acc: 0.4943, val loss: 1.1998, val acc: 0.5113  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2146)
# [Epoch: 1620] train loss: 1.2272, train acc: 0.4865, val loss: 1.1927, val acc: 0.5046  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2146)
# [Epoch: 1640] train loss: 1.2181, train acc: 0.4912, val loss: 1.1931, val acc: 0.5062  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2146)
# [Epoch: 1660] train loss: 1.2196, train acc: 0.4850, val loss: 1.1944, val acc: 0.5066  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2136)
# [Epoch: 1680] train loss: 1.2211, train acc: 0.4907, val loss: 1.1922, val acc: 0.5073  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2120)
# [Epoch: 1700] train loss: 1.2355, train acc: 0.4853, val loss: 1.1940, val acc: 0.4965  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2106)
# [Epoch: 1720] train loss: 1.2154, train acc: 0.4952, val loss: 1.1953, val acc: 0.5056  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2106)
# [Epoch: 1740] train loss: 1.2252, train acc: 0.4872, val loss: 1.1931, val acc: 0.5089  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2106)
# [Epoch: 1760] train loss: 1.2160, train acc: 0.4944, val loss: 1.1927, val acc: 0.4981  (best train acc: 0.4983, best val acc: 0.5130, best train loss: 1.2106)
# [Epoch: 1780] train loss: 1.2113, train acc: 0.4987, val loss: 1.1920, val acc: 0.5002  (best train acc: 0.4987, best val acc: 0.5130, best train loss: 1.2106)
# [Epoch: 1800] train loss: 1.2155, train acc: 0.4923, val loss: 1.1901, val acc: 0.5066  (best train acc: 0.4987, best val acc: 0.5130, best train loss: 1.2093)
# [Epoch: 1820] train loss: 1.2215, train acc: 0.4893, val loss: 1.1895, val acc: 0.5066  (best train acc: 0.4987, best val acc: 0.5130, best train loss: 1.2093)
# [Epoch: 1840] train loss: 1.2202, train acc: 0.4894, val loss: 1.1906, val acc: 0.5106  (best train acc: 0.5028, best val acc: 0.5130, best train loss: 1.2093)
# [Epoch: 1860] train loss: 1.2100, train acc: 0.4962, val loss: 1.1902, val acc: 0.5113  (best train acc: 0.5028, best val acc: 0.5137, best train loss: 1.2093)
# [Epoch: 1880] train loss: 1.2116, train acc: 0.4976, val loss: 1.1862, val acc: 0.5086  (best train acc: 0.5028, best val acc: 0.5160, best train loss: 1.2086)
# [Epoch: 1900] train loss: 1.2095, train acc: 0.4937, val loss: 1.1892, val acc: 0.5089  (best train acc: 0.5028, best val acc: 0.5160, best train loss: 1.2019)
# [Epoch: 1920] train loss: 1.2123, train acc: 0.4943, val loss: 1.1876, val acc: 0.5042  (best train acc: 0.5028, best val acc: 0.5160, best train loss: 1.2019)
# [Epoch: 1940] train loss: 1.2052, train acc: 0.5009, val loss: 1.1861, val acc: 0.5062  (best train acc: 0.5028, best val acc: 0.5160, best train loss: 1.2019)
# [Epoch: 1960] train loss: 1.2105, train acc: 0.4970, val loss: 1.1854, val acc: 0.5076  (best train acc: 0.5028, best val acc: 0.5167, best train loss: 1.1996)
# [Epoch: 1980] train loss: 1.2086, train acc: 0.4936, val loss: 1.1907, val acc: 0.5126  (best train acc: 0.5038, best val acc: 0.5167, best train loss: 1.1994)
# [Epoch: 2000] train loss: 1.2177, train acc: 0.4939, val loss: 1.1869, val acc: 0.5042  (best train acc: 0.5038, best val acc: 0.5167, best train loss: 1.1994)
# [Epoch: 2020] train loss: 1.2062, train acc: 0.5020, val loss: 1.1861, val acc: 0.5073  (best train acc: 0.5038, best val acc: 0.5167, best train loss: 1.1971)
# [Epoch: 2040] train loss: 1.2035, train acc: 0.4992, val loss: 1.1854, val acc: 0.5056  (best train acc: 0.5038, best val acc: 0.5167, best train loss: 1.1967)
# [Epoch: 2060] train loss: 1.2019, train acc: 0.4966, val loss: 1.1841, val acc: 0.5103  (best train acc: 0.5038, best val acc: 0.5167, best train loss: 1.1947)
# [Epoch: 2080] train loss: 1.2062, train acc: 0.4971, val loss: 1.1853, val acc: 0.5120  (best train acc: 0.5038, best val acc: 0.5167, best train loss: 1.1947)
# [Epoch: 2100] train loss: 1.1967, train acc: 0.5000, val loss: 1.1822, val acc: 0.5089  (best train acc: 0.5038, best val acc: 0.5167, best train loss: 1.1947)
# [Epoch: 2120] train loss: 1.2029, train acc: 0.4941, val loss: 1.1831, val acc: 0.5126  (best train acc: 0.5038, best val acc: 0.5167, best train loss: 1.1947)
# [Epoch: 2140] train loss: 1.2134, train acc: 0.4876, val loss: 1.1881, val acc: 0.5167  (best train acc: 0.5038, best val acc: 0.5167, best train loss: 1.1947)
# [Epoch: 2160] train loss: 1.2004, train acc: 0.4952, val loss: 1.1900, val acc: 0.5120  (best train acc: 0.5038, best val acc: 0.5167, best train loss: 1.1947)
# [Epoch: 2180] train loss: 1.2029, train acc: 0.4935, val loss: 1.1851, val acc: 0.5137  (best train acc: 0.5038, best val acc: 0.5167, best train loss: 1.1947)
# [Epoch: 2200] train loss: 1.2003, train acc: 0.4986, val loss: 1.1822, val acc: 0.5079  (best train acc: 0.5038, best val acc: 0.5170, best train loss: 1.1947)
# [Epoch: 2220] train loss: 1.2024, train acc: 0.4982, val loss: 1.1841, val acc: 0.5140  (best train acc: 0.5042, best val acc: 0.5170, best train loss: 1.1947)
# [Epoch: 2240] train loss: 1.2136, train acc: 0.4913, val loss: 1.1866, val acc: 0.5022  (best train acc: 0.5043, best val acc: 0.5170, best train loss: 1.1947)
# [Epoch: 2260] train loss: 1.2054, train acc: 0.4983, val loss: 1.1804, val acc: 0.5106  (best train acc: 0.5043, best val acc: 0.5170, best train loss: 1.1943)
# [Epoch: 2280] train loss: 1.2042, train acc: 0.4947, val loss: 1.1814, val acc: 0.5110  (best train acc: 0.5043, best val acc: 0.5170, best train loss: 1.1929)
# [Epoch: 2300] train loss: 1.1973, train acc: 0.5034, val loss: 1.1802, val acc: 0.5099  (best train acc: 0.5043, best val acc: 0.5170, best train loss: 1.1929)
# [Epoch: 2320] train loss: 1.1951, train acc: 0.4982, val loss: 1.1819, val acc: 0.5137  (best train acc: 0.5056, best val acc: 0.5170, best train loss: 1.1909)
# [Epoch: 2340] train loss: 1.2031, train acc: 0.4990, val loss: 1.1851, val acc: 0.5039  (best train acc: 0.5072, best val acc: 0.5170, best train loss: 1.1908)
# [Epoch: 2360] train loss: 1.1967, train acc: 0.5015, val loss: 1.1807, val acc: 0.5147  (best train acc: 0.5072, best val acc: 0.5184, best train loss: 1.1844)
# [Epoch: 2380] train loss: 1.1919, train acc: 0.5006, val loss: 1.1824, val acc: 0.5079  (best train acc: 0.5072, best val acc: 0.5184, best train loss: 1.1844)
# [Epoch: 2400] train loss: 1.1979, train acc: 0.4972, val loss: 1.1794, val acc: 0.5150  (best train acc: 0.5072, best val acc: 0.5184, best train loss: 1.1844)
# [Epoch: 2420] train loss: 1.1991, train acc: 0.4960, val loss: 1.1811, val acc: 0.5096  (best train acc: 0.5072, best val acc: 0.5184, best train loss: 1.1844)
# [Epoch: 2440] train loss: 1.1954, train acc: 0.4993, val loss: 1.1822, val acc: 0.5147  (best train acc: 0.5072, best val acc: 0.5184, best train loss: 1.1844)
# [Epoch: 2460] train loss: 1.1897, train acc: 0.5015, val loss: 1.1800, val acc: 0.5147  (best train acc: 0.5072, best val acc: 0.5184, best train loss: 1.1844)
# [Epoch: 2480] train loss: 1.1969, train acc: 0.5011, val loss: 1.1833, val acc: 0.5056  (best train acc: 0.5072, best val acc: 0.5184, best train loss: 1.1844)
# [Epoch: 2500] train loss: 1.1954, train acc: 0.4978, val loss: 1.1863, val acc: 0.5170  (best train acc: 0.5072, best val acc: 0.5184, best train loss: 1.1844)
# [Epoch: 2520] train loss: 1.1886, train acc: 0.5055, val loss: 1.1796, val acc: 0.5140  (best train acc: 0.5084, best val acc: 0.5184, best train loss: 1.1844)
# [Epoch: 2540] train loss: 1.1901, train acc: 0.5016, val loss: 1.1788, val acc: 0.5140  (best train acc: 0.5084, best val acc: 0.5184, best train loss: 1.1844)
# [Epoch: 2560] train loss: 1.1880, train acc: 0.5067, val loss: 1.1788, val acc: 0.5133  (best train acc: 0.5093, best val acc: 0.5187, best train loss: 1.1844)
# [Epoch: 2580] train loss: 1.1992, train acc: 0.5025, val loss: 1.1858, val acc: 0.5035  (best train acc: 0.5093, best val acc: 0.5187, best train loss: 1.1844)
# [Epoch: 2600] train loss: 1.1975, train acc: 0.4982, val loss: 1.1797, val acc: 0.5089  (best train acc: 0.5093, best val acc: 0.5197, best train loss: 1.1844)
# [Epoch: 2620] train loss: 1.1915, train acc: 0.4989, val loss: 1.1804, val acc: 0.5103  (best train acc: 0.5093, best val acc: 0.5197, best train loss: 1.1844)
# [Epoch: 2640] train loss: 1.1914, train acc: 0.5023, val loss: 1.1800, val acc: 0.5187  (best train acc: 0.5093, best val acc: 0.5197, best train loss: 1.1844)
# [Epoch: 2660] train loss: 1.1941, train acc: 0.5001, val loss: 1.1781, val acc: 0.5177  (best train acc: 0.5093, best val acc: 0.5197, best train loss: 1.1844)
# [Epoch: 2680] train loss: 1.1928, train acc: 0.5012, val loss: 1.1793, val acc: 0.5110  (best train acc: 0.5093, best val acc: 0.5197, best train loss: 1.1844)
# [Epoch: 2700] train loss: 1.1935, train acc: 0.5027, val loss: 1.1860, val acc: 0.5153  (best train acc: 0.5093, best val acc: 0.5197, best train loss: 1.1844)
# [Epoch: 2720] train loss: 1.1967, train acc: 0.4971, val loss: 1.1779, val acc: 0.5180  (best train acc: 0.5093, best val acc: 0.5197, best train loss: 1.1844)
# [Epoch: 2740] train loss: 1.1897, train acc: 0.5042, val loss: 1.1805, val acc: 0.5103  (best train acc: 0.5093, best val acc: 0.5197, best train loss: 1.1824)
# [Epoch: 2760] train loss: 1.1988, train acc: 0.5026, val loss: 1.1789, val acc: 0.5147  (best train acc: 0.5122, best val acc: 0.5197, best train loss: 1.1824)
# [Epoch: 2780] train loss: 1.1881, train acc: 0.5055, val loss: 1.1784, val acc: 0.5116  (best train acc: 0.5122, best val acc: 0.5197, best train loss: 1.1824)
# [Epoch: 2800] train loss: 1.1961, train acc: 0.5006, val loss: 1.1806, val acc: 0.5079  (best train acc: 0.5122, best val acc: 0.5197, best train loss: 1.1824)
# [Epoch: 2820] train loss: 1.1841, train acc: 0.5100, val loss: 1.1787, val acc: 0.5184  (best train acc: 0.5122, best val acc: 0.5197, best train loss: 1.1775)
# [Epoch: 2840] train loss: 1.1950, train acc: 0.5036, val loss: 1.1839, val acc: 0.5086  (best train acc: 0.5122, best val acc: 0.5197, best train loss: 1.1775)
# [Epoch: 2860] train loss: 1.1981, train acc: 0.4947, val loss: 1.1861, val acc: 0.5143  (best train acc: 0.5122, best val acc: 0.5197, best train loss: 1.1775)
# [Epoch: 2880] train loss: 1.1848, train acc: 0.5038, val loss: 1.1786, val acc: 0.5153  (best train acc: 0.5122, best val acc: 0.5197, best train loss: 1.1775)
# [Epoch: 2900] train loss: 1.1866, train acc: 0.5036, val loss: 1.1831, val acc: 0.5187  (best train acc: 0.5122, best val acc: 0.5197, best train loss: 1.1775)
# [Epoch: 2920] train loss: 1.1836, train acc: 0.5089, val loss: 1.1791, val acc: 0.5160  (best train acc: 0.5136, best val acc: 0.5207, best train loss: 1.1775)
# [Epoch: 2940] train loss: 1.1917, train acc: 0.5001, val loss: 1.1812, val acc: 0.5187  (best train acc: 0.5136, best val acc: 0.5207, best train loss: 1.1775)
# [Epoch: 2960] train loss: 1.1782, train acc: 0.5058, val loss: 1.1780, val acc: 0.5133  (best train acc: 0.5136, best val acc: 0.5211, best train loss: 1.1775)
# [Epoch: 2980] train loss: 1.1900, train acc: 0.5056, val loss: 1.1802, val acc: 0.5099  (best train acc: 0.5136, best val acc: 0.5214, best train loss: 1.1775)
# [Epoch: 3000] train loss: 1.1849, train acc: 0.5054, val loss: 1.1786, val acc: 0.5174  (best train acc: 0.5136, best val acc: 0.5214, best train loss: 1.1775)
# [Epoch: 3020] train loss: 1.1967, train acc: 0.4946, val loss: 1.1821, val acc: 0.5150  (best train acc: 0.5136, best val acc: 0.5214, best train loss: 1.1775)
# [Epoch: 3040] train loss: 1.1848, train acc: 0.5039, val loss: 1.1779, val acc: 0.5170  (best train acc: 0.5136, best val acc: 0.5218, best train loss: 1.1775)
# [Epoch: 3060] train loss: 1.1810, train acc: 0.5069, val loss: 1.1785, val acc: 0.5110  (best train acc: 0.5136, best val acc: 0.5218, best train loss: 1.1775)
# [Epoch: 3080] train loss: 1.1851, train acc: 0.5040, val loss: 1.1829, val acc: 0.5180  (best train acc: 0.5136, best val acc: 0.5218, best train loss: 1.1736)
# [Epoch: 3100] train loss: 1.1870, train acc: 0.5021, val loss: 1.1778, val acc: 0.5214  (best train acc: 0.5136, best val acc: 0.5218, best train loss: 1.1736)
# [Epoch: 3120] train loss: 1.1796, train acc: 0.5017, val loss: 1.1827, val acc: 0.5177  (best train acc: 0.5136, best val acc: 0.5221, best train loss: 1.1736)
# [Epoch: 3140] train loss: 1.1819, train acc: 0.5024, val loss: 1.1772, val acc: 0.5153  (best train acc: 0.5136, best val acc: 0.5221, best train loss: 1.1736)
# [Epoch: 3160] train loss: 1.1828, train acc: 0.5081, val loss: 1.1779, val acc: 0.5123  (best train acc: 0.5136, best val acc: 0.5221, best train loss: 1.1736)
# [Epoch: 3180] train loss: 1.1758, train acc: 0.5105, val loss: 1.1770, val acc: 0.5150  (best train acc: 0.5136, best val acc: 0.5221, best train loss: 1.1736)
# [Epoch: 3200] train loss: 1.1782, train acc: 0.5132, val loss: 1.1798, val acc: 0.5187  (best train acc: 0.5136, best val acc: 0.5221, best train loss: 1.1736)
# [Epoch: 3220] train loss: 1.1915, train acc: 0.4997, val loss: 1.1853, val acc: 0.5167  (best train acc: 0.5136, best val acc: 0.5221, best train loss: 1.1736)
# [Epoch: 3240] train loss: 1.1855, train acc: 0.5038, val loss: 1.1805, val acc: 0.5207  (best train acc: 0.5136, best val acc: 0.5221, best train loss: 1.1736)
# [Epoch: 3260] train loss: 1.1834, train acc: 0.5072, val loss: 1.1818, val acc: 0.5029  (best train acc: 0.5136, best val acc: 0.5221, best train loss: 1.1736)
# [Epoch: 3280] train loss: 1.1788, train acc: 0.5038, val loss: 1.1768, val acc: 0.5133  (best train acc: 0.5136, best val acc: 0.5221, best train loss: 1.1736)
# [Epoch: 3300] train loss: 1.1796, train acc: 0.5064, val loss: 1.1762, val acc: 0.5184  (best train acc: 0.5158, best val acc: 0.5221, best train loss: 1.1712)
# [Epoch: 3320] train loss: 1.1837, train acc: 0.5053, val loss: 1.1759, val acc: 0.5153  (best train acc: 0.5158, best val acc: 0.5221, best train loss: 1.1712)
# [Epoch: 3340] train loss: 1.1779, train acc: 0.5048, val loss: 1.1766, val acc: 0.5120  (best train acc: 0.5163, best val acc: 0.5221, best train loss: 1.1681)
# [Epoch: 3360] train loss: 1.1810, train acc: 0.5075, val loss: 1.1776, val acc: 0.5170  (best train acc: 0.5163, best val acc: 0.5221, best train loss: 1.1681)
# [Epoch: 3380] train loss: 1.1834, train acc: 0.5051, val loss: 1.1793, val acc: 0.5150  (best train acc: 0.5163, best val acc: 0.5221, best train loss: 1.1681)
# [Epoch: 3400] train loss: 1.1782, train acc: 0.5088, val loss: 1.1758, val acc: 0.5197  (best train acc: 0.5163, best val acc: 0.5221, best train loss: 1.1681)
# [Epoch: 3420] train loss: 1.1759, train acc: 0.5103, val loss: 1.1770, val acc: 0.5116  (best train acc: 0.5163, best val acc: 0.5224, best train loss: 1.1681)
# [Epoch: 3440] train loss: 1.1834, train acc: 0.5074, val loss: 1.1763, val acc: 0.5110  (best train acc: 0.5163, best val acc: 0.5231, best train loss: 1.1681)
# [Epoch: 3460] train loss: 1.1811, train acc: 0.5087, val loss: 1.1752, val acc: 0.5116  (best train acc: 0.5163, best val acc: 0.5231, best train loss: 1.1681)
# [Epoch: 3480] train loss: 1.1807, train acc: 0.5059, val loss: 1.1751, val acc: 0.5160  (best train acc: 0.5163, best val acc: 0.5231, best train loss: 1.1681)
# [Epoch: 3500] train loss: 1.1796, train acc: 0.5066, val loss: 1.1823, val acc: 0.5002  (best train acc: 0.5163, best val acc: 0.5231, best train loss: 1.1679)
# [Epoch: 3520] train loss: 1.1789, train acc: 0.5117, val loss: 1.1749, val acc: 0.5137  (best train acc: 0.5163, best val acc: 0.5231, best train loss: 1.1679)
# [Epoch: 3540] train loss: 1.1801, train acc: 0.5129, val loss: 1.1752, val acc: 0.5177  (best train acc: 0.5163, best val acc: 0.5231, best train loss: 1.1679)
# [Epoch: 3560] train loss: 1.1798, train acc: 0.5110, val loss: 1.1736, val acc: 0.5211  (best train acc: 0.5163, best val acc: 0.5231, best train loss: 1.1679)
# [Epoch: 3580] train loss: 1.1815, train acc: 0.5090, val loss: 1.1764, val acc: 0.5062  (best train acc: 0.5163, best val acc: 0.5234, best train loss: 1.1679)
# [Epoch: 3600] train loss: 1.1787, train acc: 0.5091, val loss: 1.1743, val acc: 0.5201  (best train acc: 0.5163, best val acc: 0.5234, best train loss: 1.1679)
# [Epoch: 3620] train loss: 1.1705, train acc: 0.5145, val loss: 1.1761, val acc: 0.5069  (best train acc: 0.5163, best val acc: 0.5251, best train loss: 1.1679)
# [Epoch: 3640] train loss: 1.1732, train acc: 0.5075, val loss: 1.1746, val acc: 0.5174  (best train acc: 0.5163, best val acc: 0.5251, best train loss: 1.1679)
# [Epoch: 3660] train loss: 1.1715, train acc: 0.5088, val loss: 1.1780, val acc: 0.5177  (best train acc: 0.5163, best val acc: 0.5251, best train loss: 1.1679)
# [Epoch: 3680] train loss: 1.1782, train acc: 0.5056, val loss: 1.1733, val acc: 0.5201  (best train acc: 0.5163, best val acc: 0.5251, best train loss: 1.1678)
# [Epoch: 3700] train loss: 1.1757, train acc: 0.5077, val loss: 1.1741, val acc: 0.5137  (best train acc: 0.5163, best val acc: 0.5255, best train loss: 1.1678)
# [Epoch: 3720] train loss: 1.1812, train acc: 0.5068, val loss: 1.1728, val acc: 0.5150  (best train acc: 0.5163, best val acc: 0.5265, best train loss: 1.1669)
# [Epoch: 3740] train loss: 1.1750, train acc: 0.5084, val loss: 1.1742, val acc: 0.5153  (best train acc: 0.5163, best val acc: 0.5265, best train loss: 1.1669)
# [Epoch: 3760] train loss: 1.1719, train acc: 0.5091, val loss: 1.1746, val acc: 0.5164  (best train acc: 0.5163, best val acc: 0.5265, best train loss: 1.1669)
# [Epoch: 3780] train loss: 1.1813, train acc: 0.5031, val loss: 1.1728, val acc: 0.5221  (best train acc: 0.5163, best val acc: 0.5265, best train loss: 1.1669)
# [Epoch: 3800] train loss: 1.1769, train acc: 0.5088, val loss: 1.1725, val acc: 0.5207  (best train acc: 0.5163, best val acc: 0.5265, best train loss: 1.1666)
# [Epoch: 3820] train loss: 1.1737, train acc: 0.5086, val loss: 1.1739, val acc: 0.5191  (best train acc: 0.5163, best val acc: 0.5265, best train loss: 1.1662)
# [Epoch: 3840] train loss: 1.1760, train acc: 0.5127, val loss: 1.1767, val acc: 0.5066  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1661)
# [Epoch: 3860] train loss: 1.1769, train acc: 0.5070, val loss: 1.1731, val acc: 0.5187  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1661)
# [Epoch: 3880] train loss: 1.1716, train acc: 0.5117, val loss: 1.1721, val acc: 0.5221  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1617)
# [Epoch: 3900] train loss: 1.1705, train acc: 0.5103, val loss: 1.1710, val acc: 0.5197  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1617)
# [Epoch: 3920] train loss: 1.1735, train acc: 0.5087, val loss: 1.1744, val acc: 0.5224  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1617)
# [Epoch: 3940] train loss: 1.1708, train acc: 0.5084, val loss: 1.1747, val acc: 0.5174  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1617)
# [Epoch: 3960] train loss: 1.1729, train acc: 0.5117, val loss: 1.1865, val acc: 0.5093  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1617)
# [Epoch: 3980] train loss: 1.1736, train acc: 0.5127, val loss: 1.1703, val acc: 0.5177  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1617)
# [Epoch: 4000] train loss: 1.1680, train acc: 0.5066, val loss: 1.1773, val acc: 0.5228  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1617)
# [Epoch: 4020] train loss: 1.1703, train acc: 0.5160, val loss: 1.1710, val acc: 0.5170  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1617)
# [Epoch: 4040] train loss: 1.1700, train acc: 0.5108, val loss: 1.1708, val acc: 0.5214  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1617)
# [Epoch: 4060] train loss: 1.1663, train acc: 0.5105, val loss: 1.1715, val acc: 0.5201  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1617)
# [Epoch: 4080] train loss: 1.1771, train acc: 0.5072, val loss: 1.1699, val acc: 0.5224  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1594)
# [Epoch: 4100] train loss: 1.1765, train acc: 0.5100, val loss: 1.1752, val acc: 0.5224  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1594)
# [Epoch: 4120] train loss: 1.1917, train acc: 0.5022, val loss: 1.2040, val acc: 0.4833  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1594)
# [Epoch: 4140] train loss: 1.1768, train acc: 0.5135, val loss: 1.1809, val acc: 0.5029  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1594)
# [Epoch: 4160] train loss: 1.1712, train acc: 0.5133, val loss: 1.1717, val acc: 0.5174  (best train acc: 0.5181, best val acc: 0.5265, best train loss: 1.1594)
# [Epoch: 4180] train loss: 1.1674, train acc: 0.5145, val loss: 1.1732, val acc: 0.5234  (best train acc: 0.5181, best val acc: 0.5272, best train loss: 1.1594)
# [Epoch: 4200] train loss: 1.1699, train acc: 0.5116, val loss: 1.1700, val acc: 0.5207  (best train acc: 0.5192, best val acc: 0.5272, best train loss: 1.1594)
# [Epoch: 4220] train loss: 1.1736, train acc: 0.5067, val loss: 1.1732, val acc: 0.5116  (best train acc: 0.5192, best val acc: 0.5272, best train loss: 1.1594)
# [Epoch: 4240] train loss: 1.1663, train acc: 0.5119, val loss: 1.1704, val acc: 0.5211  (best train acc: 0.5192, best val acc: 0.5272, best train loss: 1.1594)
# [Epoch: 4260] train loss: 1.1676, train acc: 0.5094, val loss: 1.1689, val acc: 0.5184  (best train acc: 0.5192, best val acc: 0.5272, best train loss: 1.1594)
# [Epoch: 4280] train loss: 1.1716, train acc: 0.5092, val loss: 1.1701, val acc: 0.5194  (best train acc: 0.5192, best val acc: 0.5275, best train loss: 1.1594)
# [Epoch: 4300] train loss: 1.1677, train acc: 0.5100, val loss: 1.1709, val acc: 0.5204  (best train acc: 0.5192, best val acc: 0.5275, best train loss: 1.1594)
# [Epoch: 4320] train loss: 1.1692, train acc: 0.5119, val loss: 1.1705, val acc: 0.5224  (best train acc: 0.5192, best val acc: 0.5275, best train loss: 1.1594)
# [Epoch: 4340] train loss: 1.1700, train acc: 0.5126, val loss: 1.1698, val acc: 0.5201  (best train acc: 0.5199, best val acc: 0.5275, best train loss: 1.1594)
# [Epoch: 4360] train loss: 1.1645, train acc: 0.5149, val loss: 1.1709, val acc: 0.5224  (best train acc: 0.5199, best val acc: 0.5275, best train loss: 1.1594)
# [Epoch: 4380] train loss: 1.1613, train acc: 0.5139, val loss: 1.1684, val acc: 0.5204  (best train acc: 0.5199, best val acc: 0.5275, best train loss: 1.1594)
# [Epoch: 4400] train loss: 1.1642, train acc: 0.5117, val loss: 1.1706, val acc: 0.5224  (best train acc: 0.5199, best val acc: 0.5295, best train loss: 1.1587)
# [Epoch: 4420] train loss: 1.1708, train acc: 0.5092, val loss: 1.1719, val acc: 0.5224  (best train acc: 0.5199, best val acc: 0.5295, best train loss: 1.1554)
# [Epoch: 4440] train loss: 1.1688, train acc: 0.5127, val loss: 1.1701, val acc: 0.5143  (best train acc: 0.5210, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4460] train loss: 1.1632, train acc: 0.5150, val loss: 1.1750, val acc: 0.5066  (best train acc: 0.5210, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4480] train loss: 1.1648, train acc: 0.5150, val loss: 1.1705, val acc: 0.5214  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4500] train loss: 1.1616, train acc: 0.5124, val loss: 1.1685, val acc: 0.5265  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4520] train loss: 1.1746, train acc: 0.5084, val loss: 1.1841, val acc: 0.4998  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4540] train loss: 1.1645, train acc: 0.5108, val loss: 1.1699, val acc: 0.5231  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4560] train loss: 1.1625, train acc: 0.5098, val loss: 1.1698, val acc: 0.5218  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4580] train loss: 1.1708, train acc: 0.5128, val loss: 1.1706, val acc: 0.5184  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4600] train loss: 1.1703, train acc: 0.5064, val loss: 1.1710, val acc: 0.5204  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4620] train loss: 1.1642, train acc: 0.5155, val loss: 1.1743, val acc: 0.5089  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4640] train loss: 1.1624, train acc: 0.5111, val loss: 1.1748, val acc: 0.5228  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4660] train loss: 1.1690, train acc: 0.5086, val loss: 1.1701, val acc: 0.5180  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1545)
# [Epoch: 4680] train loss: 1.1636, train acc: 0.5182, val loss: 1.1729, val acc: 0.5197  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4700] train loss: 1.1785, train acc: 0.5072, val loss: 1.1761, val acc: 0.5231  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4720] train loss: 1.1662, train acc: 0.5180, val loss: 1.1701, val acc: 0.5170  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4740] train loss: 1.1630, train acc: 0.5166, val loss: 1.1745, val acc: 0.5106  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4760] train loss: 1.1623, train acc: 0.5147, val loss: 1.1704, val acc: 0.5207  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4780] train loss: 1.1600, train acc: 0.5205, val loss: 1.1702, val acc: 0.5194  (best train acc: 0.5223, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4800] train loss: 1.1591, train acc: 0.5140, val loss: 1.1758, val acc: 0.5231  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4820] train loss: 1.1637, train acc: 0.5150, val loss: 1.1723, val acc: 0.5147  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4840] train loss: 1.1648, train acc: 0.5142, val loss: 1.1718, val acc: 0.5174  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4860] train loss: 1.1680, train acc: 0.5085, val loss: 1.1811, val acc: 0.5251  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4880] train loss: 1.1672, train acc: 0.5144, val loss: 1.1712, val acc: 0.5143  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4900] train loss: 1.1545, train acc: 0.5192, val loss: 1.1727, val acc: 0.5251  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4920] train loss: 1.1684, train acc: 0.5149, val loss: 1.1721, val acc: 0.5231  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4940] train loss: 1.1667, train acc: 0.5130, val loss: 1.1755, val acc: 0.5089  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4960] train loss: 1.1612, train acc: 0.5144, val loss: 1.1719, val acc: 0.5214  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1527)
# [Epoch: 4980] train loss: 1.1563, train acc: 0.5160, val loss: 1.1766, val acc: 0.5224  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5000] train loss: 1.1606, train acc: 0.5180, val loss: 1.1704, val acc: 0.5177  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5020] train loss: 1.1633, train acc: 0.5144, val loss: 1.1696, val acc: 0.5180  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5040] train loss: 1.1592, train acc: 0.5182, val loss: 1.1725, val acc: 0.5224  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5060] train loss: 1.1577, train acc: 0.5168, val loss: 1.1687, val acc: 0.5160  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5080] train loss: 1.1592, train acc: 0.5206, val loss: 1.1715, val acc: 0.5153  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5100] train loss: 1.1570, train acc: 0.5166, val loss: 1.1798, val acc: 0.5218  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5120] train loss: 1.1611, train acc: 0.5148, val loss: 1.1770, val acc: 0.5079  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5140] train loss: 1.1827, train acc: 0.5011, val loss: 1.1851, val acc: 0.5231  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5160] train loss: 1.1727, train acc: 0.5048, val loss: 1.1723, val acc: 0.5224  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5180] train loss: 1.1559, train acc: 0.5146, val loss: 1.1711, val acc: 0.5218  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5200] train loss: 1.1558, train acc: 0.5165, val loss: 1.1717, val acc: 0.5214  (best train acc: 0.5239, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5220] train loss: 1.1603, train acc: 0.5129, val loss: 1.1699, val acc: 0.5174  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5240] train loss: 1.1545, train acc: 0.5140, val loss: 1.1721, val acc: 0.5143  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5260] train loss: 1.1626, train acc: 0.5124, val loss: 1.1756, val acc: 0.5218  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5280] train loss: 1.1565, train acc: 0.5193, val loss: 1.1684, val acc: 0.5214  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1484)
# [Epoch: 5300] train loss: 1.1585, train acc: 0.5162, val loss: 1.1690, val acc: 0.5211  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1481)
# [Epoch: 5320] train loss: 1.1470, train acc: 0.5180, val loss: 1.1694, val acc: 0.5231  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1468)
# [Epoch: 5340] train loss: 1.1559, train acc: 0.5211, val loss: 1.1692, val acc: 0.5164  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1449)
# [Epoch: 5360] train loss: 1.1504, train acc: 0.5230, val loss: 1.1697, val acc: 0.5197  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1444)
# [Epoch: 5380] train loss: 1.1565, train acc: 0.5194, val loss: 1.1742, val acc: 0.5258  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1444)
# [Epoch: 5400] train loss: 1.1535, train acc: 0.5188, val loss: 1.1713, val acc: 0.5238  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1444)
# [Epoch: 5420] train loss: 1.1509, train acc: 0.5197, val loss: 1.1744, val acc: 0.5116  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1444)
# [Epoch: 5440] train loss: 1.1549, train acc: 0.5132, val loss: 1.1686, val acc: 0.5174  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1444)
# [Epoch: 5460] train loss: 1.1514, train acc: 0.5183, val loss: 1.1754, val acc: 0.5241  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1444)
# [Epoch: 5480] train loss: 1.1521, train acc: 0.5183, val loss: 1.1692, val acc: 0.5130  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1444)
# [Epoch: 5500] train loss: 1.1621, train acc: 0.5174, val loss: 1.1685, val acc: 0.5207  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1444)
# [Epoch: 5520] train loss: 1.1507, train acc: 0.5176, val loss: 1.1735, val acc: 0.5231  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1444)
# [Epoch: 5540] train loss: 1.1523, train acc: 0.5200, val loss: 1.1689, val acc: 0.5194  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1444)
# [Epoch: 5560] train loss: 1.1489, train acc: 0.5229, val loss: 1.1722, val acc: 0.5106  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1423)
# [Epoch: 5580] train loss: 1.1532, train acc: 0.5189, val loss: 1.1684, val acc: 0.5150  (best train acc: 0.5271, best val acc: 0.5295, best train loss: 1.1421)
# [Epoch: 5600] train loss: 1.1479, train acc: 0.5234, val loss: 1.1772, val acc: 0.5241  (best train acc: 0.5284, best val acc: 0.5295, best train loss: 1.1411)
# [Epoch: 5620] train loss: 1.1562, train acc: 0.5147, val loss: 1.1744, val acc: 0.5184  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1411)
# [Epoch: 5640] train loss: 1.1426, train acc: 0.5205, val loss: 1.1697, val acc: 0.5164  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1410)
# [Epoch: 5660] train loss: 1.1539, train acc: 0.5185, val loss: 1.1661, val acc: 0.5160  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1410)
# [Epoch: 5680] train loss: 1.1528, train acc: 0.5143, val loss: 1.1686, val acc: 0.5228  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1402)
# [Epoch: 5700] train loss: 1.1528, train acc: 0.5128, val loss: 1.1681, val acc: 0.5204  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1402)
# [Epoch: 5720] train loss: 1.1536, train acc: 0.5207, val loss: 1.1673, val acc: 0.5211  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1376)
# [Epoch: 5740] train loss: 1.1581, train acc: 0.5145, val loss: 1.1681, val acc: 0.5174  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1376)
# [Epoch: 5760] train loss: 1.1527, train acc: 0.5171, val loss: 1.1667, val acc: 0.5221  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1376)
# [Epoch: 5780] train loss: 1.1437, train acc: 0.5223, val loss: 1.1659, val acc: 0.5184  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1376)
# [Epoch: 5800] train loss: 1.1529, train acc: 0.5202, val loss: 1.1657, val acc: 0.5201  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1376)
# [Epoch: 5820] train loss: 1.1639, train acc: 0.5088, val loss: 1.1725, val acc: 0.5255  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1376)
# [Epoch: 5840] train loss: 1.1542, train acc: 0.5110, val loss: 1.1686, val acc: 0.5224  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1376)
# [Epoch: 5860] train loss: 1.1440, train acc: 0.5192, val loss: 1.1716, val acc: 0.5261  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1376)
# [Epoch: 5880] train loss: 1.1430, train acc: 0.5254, val loss: 1.1643, val acc: 0.5245  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1353)
# [Epoch: 5900] train loss: 1.1439, train acc: 0.5217, val loss: 1.1654, val acc: 0.5201  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1353)
# [Epoch: 5920] train loss: 1.1523, train acc: 0.5182, val loss: 1.1656, val acc: 0.5241  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1353)
# [Epoch: 5940] train loss: 1.1375, train acc: 0.5259, val loss: 1.1742, val acc: 0.5258  (best train acc: 0.5290, best val acc: 0.5295, best train loss: 1.1353)
# [Epoch: 5960] train loss: 1.1413, train acc: 0.5223, val loss: 1.1655, val acc: 0.5143  (best train acc: 0.5297, best val acc: 0.5295, best train loss: 1.1343)
# ...
# [Epoch: 38100] train loss: 0.8339, train acc: 0.6863, val loss: 0.8415, val acc: 0.7187  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38120] train loss: 0.7975, train acc: 0.7104, val loss: 0.8336, val acc: 0.7282  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38140] train loss: 0.8535, train acc: 0.6818, val loss: 0.8204, val acc: 0.7164  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38160] train loss: 0.8318, train acc: 0.6917, val loss: 0.8190, val acc: 0.7231  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38180] train loss: 0.9605, train acc: 0.5833, val loss: 0.8416, val acc: 0.7086  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38200] train loss: 0.9034, train acc: 0.6421, val loss: 0.8726, val acc: 0.7103  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38220] train loss: 0.8022, train acc: 0.7072, val loss: 0.8362, val acc: 0.7278  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38240] train loss: 0.7864, train acc: 0.7157, val loss: 0.8028, val acc: 0.7288  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38260] train loss: 0.7992, train acc: 0.7040, val loss: 0.8097, val acc: 0.7238  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38280] train loss: 0.8496, train acc: 0.6838, val loss: 0.8609, val acc: 0.6995  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38300] train loss: 0.8010, train acc: 0.6937, val loss: 0.8165, val acc: 0.7255  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38320] train loss: 0.8968, train acc: 0.6541, val loss: 0.8140, val acc: 0.7211  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38340] train loss: 0.8149, train acc: 0.6802, val loss: 0.8133, val acc: 0.7275  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7698)
# [Epoch: 38360] train loss: 0.8132, train acc: 0.6900, val loss: 0.8139, val acc: 0.7245  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38380] train loss: 0.8514, train acc: 0.6705, val loss: 0.8610, val acc: 0.7079  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38400] train loss: 0.8475, train acc: 0.6651, val loss: 0.8679, val acc: 0.7025  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38420] train loss: 0.9390, train acc: 0.6147, val loss: 0.8710, val acc: 0.7059  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38440] train loss: 0.8584, train acc: 0.6758, val loss: 0.8781, val acc: 0.6816  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38460] train loss: 0.9054, train acc: 0.6334, val loss: 0.9081, val acc: 0.6978  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38480] train loss: 0.8694, train acc: 0.6649, val loss: 0.8867, val acc: 0.6917  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38500] train loss: 0.8384, train acc: 0.7010, val loss: 0.8366, val acc: 0.7120  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38520] train loss: 0.8444, train acc: 0.6687, val loss: 0.8145, val acc: 0.7241  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38540] train loss: 0.8094, train acc: 0.7004, val loss: 0.8283, val acc: 0.7184  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38560] train loss: 0.8502, train acc: 0.6609, val loss: 0.8410, val acc: 0.7167  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38580] train loss: 0.8349, train acc: 0.6749, val loss: 0.8020, val acc: 0.7292  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38600] train loss: 0.8212, train acc: 0.6890, val loss: 0.8823, val acc: 0.7106  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38620] train loss: 0.8317, train acc: 0.6902, val loss: 0.8224, val acc: 0.7268  (best train acc: 0.7251, best val acc: 0.7342, best train loss: 0.7652)
# [Epoch: 38640] train loss: 0.7753, train acc: 0.7136, val loss: 0.8254, val acc: 0.7221  (best train acc: 0.7251, best val acc: 0.7363, best train loss: 0.7652)
# [Epoch: 38660] train loss: 0.7965, train acc: 0.7096, val loss: 0.8148, val acc: 0.7265  (best train acc: 0.7251, best val acc: 0.7363, best train loss: 0.7652)
# [Epoch: 38680] train loss: 0.8284, train acc: 0.6811, val loss: 0.8186, val acc: 0.7292  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38700] train loss: 0.8251, train acc: 0.6970, val loss: 0.8716, val acc: 0.7143  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38720] train loss: 0.8917, train acc: 0.6604, val loss: 0.8128, val acc: 0.7214  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38740] train loss: 0.8140, train acc: 0.7018, val loss: 0.8139, val acc: 0.7288  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38760] train loss: 0.8278, train acc: 0.6927, val loss: 0.8821, val acc: 0.6965  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38780] train loss: 0.8076, train acc: 0.7003, val loss: 0.8387, val acc: 0.7191  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38800] train loss: 0.8521, train acc: 0.6608, val loss: 0.8205, val acc: 0.7241  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38820] train loss: 0.8148, train acc: 0.7021, val loss: 0.8454, val acc: 0.7150  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38840] train loss: 0.8284, train acc: 0.6756, val loss: 0.8141, val acc: 0.7292  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38860] train loss: 0.8632, train acc: 0.6478, val loss: 0.8160, val acc: 0.7265  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38880] train loss: 0.8332, train acc: 0.6906, val loss: 0.8205, val acc: 0.7231  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38900] train loss: 0.7786, train acc: 0.7225, val loss: 0.8419, val acc: 0.7184  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38920] train loss: 0.8052, train acc: 0.6954, val loss: 0.8285, val acc: 0.7191  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38940] train loss: 0.7934, train acc: 0.7141, val loss: 0.8516, val acc: 0.7126  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38960] train loss: 0.9345, train acc: 0.6451, val loss: 0.9410, val acc: 0.6718  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 38980] train loss: 0.8858, train acc: 0.6656, val loss: 0.9408, val acc: 0.6786  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39000] train loss: 0.9580, train acc: 0.5899, val loss: 0.8542, val acc: 0.7207  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39020] train loss: 0.8757, train acc: 0.6531, val loss: 0.8285, val acc: 0.7234  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39040] train loss: 0.8057, train acc: 0.7000, val loss: 0.8192, val acc: 0.7218  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39060] train loss: 0.8073, train acc: 0.7027, val loss: 0.8024, val acc: 0.7309  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39080] train loss: 0.8941, train acc: 0.6657, val loss: 0.8575, val acc: 0.7191  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39100] train loss: 0.8474, train acc: 0.6791, val loss: 0.8785, val acc: 0.7049  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39120] train loss: 0.8077, train acc: 0.7086, val loss: 0.8394, val acc: 0.7265  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39140] train loss: 0.8606, train acc: 0.6549, val loss: 0.8098, val acc: 0.7272  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39160] train loss: 1.0108, train acc: 0.5913, val loss: 0.9171, val acc: 0.6870  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39180] train loss: 0.8104, train acc: 0.6991, val loss: 0.8653, val acc: 0.7103  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39200] train loss: 0.8617, train acc: 0.6465, val loss: 0.9152, val acc: 0.6651  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39220] train loss: 0.8547, train acc: 0.6803, val loss: 0.8825, val acc: 0.6917  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39240] train loss: 0.8843, train acc: 0.6591, val loss: 0.8614, val acc: 0.7160  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39260] train loss: 0.8432, train acc: 0.6773, val loss: 0.8104, val acc: 0.7248  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39280] train loss: 0.9295, train acc: 0.5969, val loss: 0.8196, val acc: 0.7228  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39300] train loss: 0.8259, train acc: 0.6857, val loss: 0.8116, val acc: 0.7322  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39320] train loss: 0.8367, train acc: 0.6797, val loss: 0.8344, val acc: 0.7238  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39340] train loss: 0.8594, train acc: 0.6498, val loss: 0.8097, val acc: 0.7295  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39360] train loss: 0.7762, train acc: 0.7191, val loss: 0.8144, val acc: 0.7272  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39380] train loss: 0.8291, train acc: 0.6968, val loss: 0.8705, val acc: 0.7046  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39400] train loss: 0.8271, train acc: 0.6904, val loss: 0.8393, val acc: 0.7170  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39420] train loss: 0.8139, train acc: 0.6990, val loss: 0.8389, val acc: 0.7164  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39440] train loss: 0.8569, train acc: 0.6703, val loss: 0.8296, val acc: 0.7177  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39460] train loss: 0.8391, train acc: 0.6718, val loss: 0.8261, val acc: 0.7251  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39480] train loss: 0.7817, train acc: 0.7192, val loss: 0.8308, val acc: 0.7133  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39500] train loss: 0.7960, train acc: 0.7049, val loss: 0.8147, val acc: 0.7268  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39520] train loss: 0.8600, train acc: 0.6666, val loss: 0.8224, val acc: 0.7201  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39540] train loss: 0.8269, train acc: 0.7022, val loss: 0.8330, val acc: 0.7191  (best train acc: 0.7251, best val acc: 0.7369, best train loss: 0.7652)
# [Epoch: 39560] train loss: 0.7673, train acc: 0.7251, val loss: 0.7905, val acc: 0.7315  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7638)
# [Epoch: 39580] train loss: 0.8975, train acc: 0.6247, val loss: 0.8118, val acc: 0.7224  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7638)
# [Epoch: 39600] train loss: 0.8150, train acc: 0.6966, val loss: 0.8219, val acc: 0.7241  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7638)
# [Epoch: 39620] train loss: 0.9712, train acc: 0.5735, val loss: 0.8320, val acc: 0.7255  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7638)
# [Epoch: 39640] train loss: 0.8158, train acc: 0.6875, val loss: 0.8137, val acc: 0.7309  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7638)
# [Epoch: 39660] train loss: 0.7965, train acc: 0.7078, val loss: 0.8353, val acc: 0.7221  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7638)
# [Epoch: 39680] train loss: 0.7738, train acc: 0.7154, val loss: 0.8230, val acc: 0.7288  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7638)
# [Epoch: 39700] train loss: 0.8393, train acc: 0.6644, val loss: 0.8296, val acc: 0.7231  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7638)
# [Epoch: 39720] train loss: 0.8322, train acc: 0.6868, val loss: 0.8149, val acc: 0.7261  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7638)
# [Epoch: 39740] train loss: 0.8200, train acc: 0.6781, val loss: 0.8142, val acc: 0.7309  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7638)
# [Epoch: 39760] train loss: 0.8180, train acc: 0.6828, val loss: 0.8098, val acc: 0.7302  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7638)
# [Epoch: 39780] train loss: 0.8440, train acc: 0.6604, val loss: 0.8818, val acc: 0.7032  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
# [Epoch: 39800] train loss: 0.7922, train acc: 0.7144, val loss: 0.8163, val acc: 0.7302  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
# [Epoch: 39820] train loss: 0.8160, train acc: 0.6954, val loss: 0.8328, val acc: 0.7204  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
# [Epoch: 39840] train loss: 0.8009, train acc: 0.7072, val loss: 0.8183, val acc: 0.7255  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
# [Epoch: 39860] train loss: 0.7830, train acc: 0.7100, val loss: 0.8076, val acc: 0.7268  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
# [Epoch: 39880] train loss: 0.7998, train acc: 0.7002, val loss: 0.8199, val acc: 0.7258  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
# [Epoch: 39900] train loss: 0.7954, train acc: 0.7106, val loss: 0.8253, val acc: 0.7292  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
# [Epoch: 39920] train loss: 1.0485, train acc: 0.6192, val loss: 1.0503, val acc: 0.5858  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
# [Epoch: 39940] train loss: 0.8760, train acc: 0.6719, val loss: 0.8880, val acc: 0.6863  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
# [Epoch: 39960] train loss: 0.8158, train acc: 0.7011, val loss: 0.8016, val acc: 0.7224  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
# [Epoch: 39980] train loss: 0.8134, train acc: 0.6943, val loss: 0.8216, val acc: 0.7251  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
# [Epoch: 40000] train loss: 0.8819, train acc: 0.6601, val loss: 0.8261, val acc: 0.7248  (best train acc: 0.7263, best val acc: 0.7369, best train loss: 0.7597)
#               precision    recall  f1-score   support
#
#            0       0.38      0.02      0.04       154
#            1       0.88      0.88      0.88       703
#            2       0.73      0.70      0.71       702
#            3       0.56      0.77      0.65       703
#            4       0.77      0.67      0.72       702
#
#     accuracy                           0.72      2964
#    macro avg       0.66      0.61      0.60      2964
# weighted avg       0.72      0.72      0.70      2964

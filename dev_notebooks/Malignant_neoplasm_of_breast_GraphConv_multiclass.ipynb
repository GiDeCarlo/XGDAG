# %% [markdown]
# ## Packets

# %%
import random
import numpy as np
import pandas as pd
import seaborn as sn
import networkx as nx
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric
from torch_geometric.nn.conv import GraphConv
from torch_geometric.utils import from_networkx
from torch_geometric.data import InMemoryDataset

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(torch.__version__)
print(torch_geometric.__version__)
print(device)
# Out:
# 1.11.0
# 2.0.4
# cuda

# %% [markdown]
# ## GNNs

# %%
class GNN7L_GraphConv (nn.Module):
    def __init__(self, data):
        super().__init__()
        self.conv1 = GraphConv(data.num_features, 16, aggr='mean')
        self.conv2 = GraphConv(16, 16, aggr='mean')
        self.conv3 = GraphConv(16, 16, aggr='mean')
        self.conv4 = GraphConv(16, 16, aggr='mean')
        self.conv5 = GraphConv(16, 16, aggr='mean')
        self.conv6 = GraphConv(16, 16, aggr='mean')
        self.conv7 = GraphConv(16, int(data.num_classes), aggr='mean')

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        x = F.relu(self.conv4(x, edge_index))
        x = F.relu(self.conv5(x, edge_index))
        x = F.relu(self.conv6(x, edge_index))
        x = F.dropout(x, training=self.training)
        x = self.conv7(x, edge_index)

        return F.log_softmax(x, dim=1)

# %% [markdown]
# ## Dataset loader

# %%
# Dataset class: it allows to translate a vector (Graph, Attributes, Labels)
# into a dataset compatible with the PyTorch models.
# 
# Parameters:
# - G: NetworkX graph
# - Labels: of the nodes used for classification
# - attributes: List of the nodes' attributes

class MyDataset(InMemoryDataset):
  def __init__(self, G, labels, attributes, num_classes=2):
    super(MyDataset, self).__init__('.', None, None, None)

    # import data from the networkx graph with the attributes of the nodes
    data = from_networkx(G, attributes)
      
    y = torch.from_numpy(labels).type(torch.long)

    data.x = data.x.float()
    data.y = y.clone().detach()
    data.num_classes = num_classes

    # Using train_test_split function from sklearn to stratify train/test/val sets
    indices = range(G.number_of_nodes())
    # Stratified split of train/test/val sets. Returned indices are used to create the masks
    X_train, X_test, y_train, y_test, train_idx, test_idx = train_test_split(data.x, data.y, indices, test_size=0.3, stratify=labels, random_state=42)
    # To create validation set, test set is splitted in half
    X_test, X_val, y_test, y_val, test_idx, val_idx = train_test_split(X_test, y_test, test_idx, test_size=0.5, stratify=y_test, random_state=42)

    n_nodes = G.number_of_nodes()
    train_mask  = torch.zeros(n_nodes, dtype=torch.bool)
    test_mask   = torch.zeros(n_nodes, dtype=torch.bool)
    val_mask    = torch.zeros(n_nodes, dtype=torch.bool)
    
    for idx in train_idx:
      train_mask[idx] = True

    for idx in test_idx:
      test_mask[idx] = True
    
    for idx in val_idx:
      val_mask[idx] = True

    data['train_mask']  = train_mask
    data['test_mask']   = test_mask
    data['val_mask']    = val_mask

    self.data, self.slices = self.collate([data])

# %% [markdown]
# ## Training Function

# %%
def train(model, data, epochs = 200, classes = ['0','1'], lr = 0.001, weight_decay=0, cm_title = 'GNN'):
    title = cm_title + '_' + str(epochs) + '_' + str(weight_decay).replace('.', '_')

    model_path  = 'Models/' + title
    image_path  = 'Images/' + title
    report_path = 'Reports/' + title + '.csv'

    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    train_mask  = data['train_mask']
    test_mask   = data['test_mask']
    val_mask    = data['val_mask']

    labels    = data.y
    output = ''

    # list to plot the train accuracy
    train_acc_curve = []
    train_lss_curve = []

    best_train_acc  = 0
    best_val_acc    = 0
    # best_test_acc   = 0
    best_train_lss  = 999

    for e in tqdm(range(epochs+1)):
        model.train()
        optimizer.zero_grad()
        logits      = model(data)
        output      = logits.argmax(1)
        # train_loss  = F.cross_entropy(logits[train_mask], labels[train_mask])
        train_loss  = F.nll_loss(logits[train_mask], labels[train_mask])
        train_acc   = (output[train_mask] == labels[train_mask]).float().mean()
        train_loss.backward()
        optimizer.step()

        # Append train acc. to plot curve later
        train_acc_curve.append(train_acc.item())
        train_lss_curve.append(train_loss.item())

        if train_acc > best_train_acc:
            best_train_acc = train_acc

        # Evaluation and test
        model.eval()
        logits      = model(data)
        output      = logits.argmax(1)
        # val_loss    = F.cross_entropy(logits[val_mask], labels[val_mask])
        val_loss    = F.nll_loss(logits[val_mask], labels[val_mask])
        val_acc     = (output[val_mask] == labels[val_mask]).float().mean()
        # test_acc    = (output[test_mask] == labels[test_mask]).float().mean()

        # Update best test/val acc.
        if val_acc > best_val_acc:
            best_val_acc = val_acc
        
        # if test_acc > best_test_acc:
        #     best_test_acc = test_acc
        
        # Save model with best train loss
        if train_loss < best_train_lss:
            best_train_lss = train_loss
            torch.save(model.state_dict(), model_path)

        if e % 20 == 0 or e == epochs:
            print('[Epoch: {:04d}]'.format(e),
            'train loss: {:.4f},'.format(train_loss.item()),
            'train acc: {:.4f},'.format(train_acc.item()),
            'val loss: {:.4f},'.format(val_loss.item()),
            'val acc: {:.4f} '.format(val_acc.item()),
            '(best train acc: {:.4f},'.format(best_train_acc.item()),
            'best val acc: {:.4f},'.format(best_val_acc.item()),
            'best train loss: {:.4f})'.format(best_train_lss))
    
    # Plot training accuracy curve
    plt.figure(figsize = (12,7))
    plt.plot(train_acc_curve)
    plt.xlabel('Epoch')
    plt.ylabel('Train Accuracy')
    plt.show()

    plt.figure(figsize = (12,7))
    plt.plot(train_lss_curve)
    plt.xlabel('Epoch')
    plt.ylabel('Train Loss')
    plt.show()

    # Load best model
    loaded_model = GNN7L_GraphConv(data).to(device)
    loaded_model.load_state_dict(torch.load(model_path))
    loaded_model.eval()
    logits = loaded_model(data)
    output = logits.argmax(1)

    print(classification_report(labels[test_mask].to('cpu'), output[test_mask].to('cpu')))

    class_report = classification_report(labels[test_mask].to('cpu'), output[test_mask].to('cpu'), output_dict=True)
    classification_report_dataframe = pd.DataFrame(class_report)
    classification_report_dataframe.to_csv(report_path)

    #Confusion Matrix
    norms = [None, "true"]
    for norm in norms:
        cm = confusion_matrix(labels[test_mask].to('cpu'), output[test_mask].to('cpu'), normalize=norm)

        plt.figure(figsize=(7,7))
        
        if norm == "true":
            sn.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'BuPu', xticklabels = classes, yticklabels = classes)
        else:
            sn.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu', xticklabels = classes, yticklabels = classes)
        plt.title(cm_title)
        plt.ylabel('Actual label')
        plt.xlabel('Predicted label')

        if norm == None:
            plt.savefig(image_path + '_notNorm.png')
        else:
            plt.savefig(image_path + '_Norm.png')

    return output

# %% [markdown]
# ## NeDBIT Multiclass

# %%
G = nx.read_gml('Graphs/graph_with_normalized_nedbit.gml')

seed_genes          = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_seed_genes.txt', header=None, sep=' ')
seed_genes.columns  = ["name", "GDA Score"]
seeds_list          = seed_genes["name"].values.tolist()

nedbit_scores = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_features_Score.csv')

# Remove seed genes
nedbit_scores_not_seed = nedbit_scores[~nedbit_scores['name'].isin(seeds_list)]
print(nedbit_scores_not_seed.shape)

# Sort scores for quartile division
nedbit_scores_not_seed = nedbit_scores_not_seed.sort_values(by = "out", ascending = False)
pseudo_labels = pd.qcut(x = nedbit_scores_not_seed["out"], q = 4, labels = ["RN", "LN", "WN", "LP"])

plt.hist(pseudo_labels)
plt.show()
# Out:
# (18736, 2)

# %%
nedbit_scores_not_seed['label'] = pseudo_labels

nedbit_scores_seed = nedbit_scores[nedbit_scores['name'].isin(seeds_list)]
nedbit_scores_seed = nedbit_scores_seed.assign(label = 'P')

# Convert dataframe to dict for searching nodes and their labels
not_seed_labels = dict(zip(nedbit_scores_not_seed['name'], nedbit_scores_not_seed['label']))
seed_labels     = dict(zip(nedbit_scores_seed['name'], nedbit_scores_seed['label']))

labels_dict = {'P':0, 'LP': 1, 'WN': 2, 'LN': 3, 'RN': 4}
labels = []

for node in G:
    if node in not_seed_labels:
        labels.append(labels_dict[not_seed_labels[node]])
    else:
        labels.append(labels_dict[seed_labels[node]])

labels = np.asarray(labels)
len(labels)
# Out:
# 19761

# %%
attributes = ['degree', 'ring', 'NetRank', 'NetShort', 'HeatDiff', 'InfoDiff']

dataset_with_nedbit = MyDataset(G, labels, attributes, num_classes=5)
data_with_nedbit = dataset_with_nedbit[0]

plt.hist(labels)
plt.show()

# %% [markdown]
# ### 7 Layers

# %%
gnn_conv = GNN7L_GraphConv(data_with_nedbit).to(device)
pred = train(gnn_conv, data_with_nedbit.to(device), 50000, cm_title='GraphConv7L_multiclass_16HC_v2', classes=['P', 'LP', 'WN', 'LN', 'RN'], weight_decay=0.0005)
# Out:
#   0%|          | 0/50001 [00:00<?, ?it/s]
# [Epoch: 0000] train loss: 89.1047, train acc: 0.2359, val loss: 74.7601, val acc: 0.2368  (best train acc: 0.2359, best val acc: 0.2368, best train loss: 89.1047)
# [Epoch: 0020] train loss: 5.1211, train acc: 0.2501, val loss: 2.3854, val acc: 0.3818  (best train acc: 0.2693, best val acc: 0.4445, best train loss: 5.1211)
# [Epoch: 0040] train loss: 1.4736, train acc: 0.2976, val loss: 1.2375, val acc: 0.4681  (best train acc: 0.3991, best val acc: 0.5747, best train loss: 1.4736)
# [Epoch: 0060] train loss: 1.3117, train acc: 0.4592, val loss: 1.1192, val acc: 0.6725  (best train acc: 0.4592, best val acc: 0.6725, best train loss: 1.3117)
# [Epoch: 0080] train loss: 1.2965, train acc: 0.4680, val loss: 1.0616, val acc: 0.6796  (best train acc: 0.4728, best val acc: 0.6796, best train loss: 1.2877)
# [Epoch: 0100] train loss: 1.2605, train acc: 0.4822, val loss: 1.0054, val acc: 0.7184  (best train acc: 0.4862, best val acc: 0.7184, best train loss: 1.2581)
# [Epoch: 0120] train loss: 1.2424, train acc: 0.4854, val loss: 0.9757, val acc: 0.7612  (best train acc: 0.4920, best val acc: 0.7612, best train loss: 1.2422)
# [Epoch: 0140] train loss: 1.2256, train acc: 0.4934, val loss: 0.9547, val acc: 0.7727  (best train acc: 0.4992, best val acc: 0.7727, best train loss: 1.2228)
# [Epoch: 0160] train loss: 1.2207, train acc: 0.4910, val loss: 0.9418, val acc: 0.7808  (best train acc: 0.5017, best val acc: 0.7828, best train loss: 1.2051)
# [Epoch: 0180] train loss: 1.1996, train acc: 0.5040, val loss: 0.9264, val acc: 0.7892  (best train acc: 0.5074, best val acc: 0.7892, best train loss: 1.1926)
# [Epoch: 0200] train loss: 1.1858, train acc: 0.5103, val loss: 0.8984, val acc: 0.7956  (best train acc: 0.5194, best val acc: 0.7963, best train loss: 1.1734)
# [Epoch: 0220] train loss: 1.1690, train acc: 0.5275, val loss: 0.8893, val acc: 0.8037  (best train acc: 0.5275, best val acc: 0.8054, best train loss: 1.1690)
# [Epoch: 0240] train loss: 1.1563, train acc: 0.5221, val loss: 0.8777, val acc: 0.7949  (best train acc: 0.5312, best val acc: 0.8078, best train loss: 1.1560)
# [Epoch: 0260] train loss: 1.1484, train acc: 0.5283, val loss: 0.8547, val acc: 0.8105  (best train acc: 0.5343, best val acc: 0.8128, best train loss: 1.1426)
# [Epoch: 0280] train loss: 1.1340, train acc: 0.5291, val loss: 0.8440, val acc: 0.8142  (best train acc: 0.5349, best val acc: 0.8142, best train loss: 1.1259)
# [Epoch: 0300] train loss: 1.1191, train acc: 0.5409, val loss: 0.8268, val acc: 0.8202  (best train acc: 0.5416, best val acc: 0.8202, best train loss: 1.1140)
# [Epoch: 0320] train loss: 1.1029, train acc: 0.5423, val loss: 0.8008, val acc: 0.8293  (best train acc: 0.5484, best val acc: 0.8300, best train loss: 1.0978)
# [Epoch: 0340] train loss: 1.0985, train acc: 0.5447, val loss: 0.7990, val acc: 0.8310  (best train acc: 0.5602, best val acc: 0.8361, best train loss: 1.0755)
# [Epoch: 0360] train loss: 1.0794, train acc: 0.5496, val loss: 0.7625, val acc: 0.8374  (best train acc: 0.5602, best val acc: 0.8388, best train loss: 1.0755)
# [Epoch: 0380] train loss: 1.0737, train acc: 0.5549, val loss: 0.7723, val acc: 0.8425  (best train acc: 0.5602, best val acc: 0.8445, best train loss: 1.0647)
# [Epoch: 0400] train loss: 1.0578, train acc: 0.5636, val loss: 0.7359, val acc: 0.8526  (best train acc: 0.5677, best val acc: 0.8526, best train loss: 1.0523)
# [Epoch: 0420] train loss: 1.0353, train acc: 0.5731, val loss: 0.7168, val acc: 0.8607  (best train acc: 0.5823, best val acc: 0.8607, best train loss: 1.0279)
# [Epoch: 0440] train loss: 1.0151, train acc: 0.5883, val loss: 0.7037, val acc: 0.8648  (best train acc: 0.5883, best val acc: 0.8648, best train loss: 1.0151)
# [Epoch: 0460] train loss: 1.0111, train acc: 0.6034, val loss: 0.6916, val acc: 0.8654  (best train acc: 0.6050, best val acc: 0.8661, best train loss: 1.0021)
# [Epoch: 0480] train loss: 0.9940, train acc: 0.6131, val loss: 0.6793, val acc: 0.8661  (best train acc: 0.6131, best val acc: 0.8691, best train loss: 0.9940)
# [Epoch: 0500] train loss: 0.9848, train acc: 0.6186, val loss: 0.6661, val acc: 0.8742  (best train acc: 0.6187, best val acc: 0.8742, best train loss: 0.9800)
# [Epoch: 0520] train loss: 1.0005, train acc: 0.6058, val loss: 0.6507, val acc: 0.8766  (best train acc: 0.6245, best val acc: 0.8766, best train loss: 0.9685)
# [Epoch: 0540] train loss: 0.9649, train acc: 0.6241, val loss: 0.6417, val acc: 0.8766  (best train acc: 0.6245, best val acc: 0.8809, best train loss: 0.9647)
# [Epoch: 0560] train loss: 0.9677, train acc: 0.6157, val loss: 0.6357, val acc: 0.8799  (best train acc: 0.6245, best val acc: 0.8809, best train loss: 0.9599)
# [Epoch: 0580] train loss: 0.9651, train acc: 0.6151, val loss: 0.6228, val acc: 0.8796  (best train acc: 0.6277, best val acc: 0.8830, best train loss: 0.9492)
# [Epoch: 0600] train loss: 0.9616, train acc: 0.6136, val loss: 0.6297, val acc: 0.8782  (best train acc: 0.6277, best val acc: 0.8836, best train loss: 0.9485)
# [Epoch: 0620] train loss: 0.9575, train acc: 0.6196, val loss: 0.6233, val acc: 0.8820  (best train acc: 0.6282, best val acc: 0.8847, best train loss: 0.9427)
# [Epoch: 0640] train loss: 0.9513, train acc: 0.6196, val loss: 0.6016, val acc: 0.8843  (best train acc: 0.6282, best val acc: 0.8847, best train loss: 0.9403)
# [Epoch: 0660] train loss: 0.9383, train acc: 0.6234, val loss: 0.6023, val acc: 0.8809  (best train acc: 0.6283, best val acc: 0.8853, best train loss: 0.9339)
# [Epoch: 0680] train loss: 0.9437, train acc: 0.6152, val loss: 0.6078, val acc: 0.8793  (best train acc: 0.6283, best val acc: 0.8860, best train loss: 0.9248)
# [Epoch: 0700] train loss: 0.9442, train acc: 0.6146, val loss: 0.5998, val acc: 0.8820  (best train acc: 0.6299, best val acc: 0.8887, best train loss: 0.9248)
# [Epoch: 0720] train loss: 0.9284, train acc: 0.6268, val loss: 0.5840, val acc: 0.8890  (best train acc: 0.6314, best val acc: 0.8907, best train loss: 0.9185)
# [Epoch: 0740] train loss: 0.9340, train acc: 0.6199, val loss: 0.5773, val acc: 0.8887  (best train acc: 0.6314, best val acc: 0.8921, best train loss: 0.9155)
# [Epoch: 0760] train loss: 0.9250, train acc: 0.6285, val loss: 0.5718, val acc: 0.8901  (best train acc: 0.6314, best val acc: 0.8921, best train loss: 0.9155)
# [Epoch: 0780] train loss: 0.9167, train acc: 0.6246, val loss: 0.5704, val acc: 0.8901  (best train acc: 0.6314, best val acc: 0.8921, best train loss: 0.9110)
# [Epoch: 0800] train loss: 0.9147, train acc: 0.6244, val loss: 0.5631, val acc: 0.8897  (best train acc: 0.6314, best val acc: 0.8924, best train loss: 0.9058)
# [Epoch: 0820] train loss: 0.9105, train acc: 0.6236, val loss: 0.5570, val acc: 0.8847  (best train acc: 0.6314, best val acc: 0.8924, best train loss: 0.9058)
# [Epoch: 0840] train loss: 0.9135, train acc: 0.6236, val loss: 0.5553, val acc: 0.8860  (best train acc: 0.6314, best val acc: 0.8924, best train loss: 0.9011)
# [Epoch: 0860] train loss: 0.8985, train acc: 0.6317, val loss: 0.5530, val acc: 0.8927  (best train acc: 0.6335, best val acc: 0.8931, best train loss: 0.8968)
# [Epoch: 0880] train loss: 0.9032, train acc: 0.6251, val loss: 0.5567, val acc: 0.8904  (best train acc: 0.6335, best val acc: 0.8931, best train loss: 0.8968)
# [Epoch: 0900] train loss: 0.9192, train acc: 0.6215, val loss: 0.5800, val acc: 0.8809  (best train acc: 0.6335, best val acc: 0.8931, best train loss: 0.8968)
# [Epoch: 0920] train loss: 0.9178, train acc: 0.6205, val loss: 0.5487, val acc: 0.8931  (best train acc: 0.6335, best val acc: 0.8931, best train loss: 0.8916)
# [Epoch: 0940] train loss: 0.9089, train acc: 0.6185, val loss: 0.5630, val acc: 0.8668  (best train acc: 0.6335, best val acc: 0.8934, best train loss: 0.8897)
# [Epoch: 0960] train loss: 0.8891, train acc: 0.6238, val loss: 0.5076, val acc: 0.8894  (best train acc: 0.6336, best val acc: 0.8948, best train loss: 0.8781)
# [Epoch: 0980] train loss: 0.8677, train acc: 0.6375, val loss: 0.5107, val acc: 0.8907  (best train acc: 0.6375, best val acc: 0.8948, best train loss: 0.8677)
# [Epoch: 1000] train loss: 0.8742, train acc: 0.6253, val loss: 0.5157, val acc: 0.8759  (best train acc: 0.6375, best val acc: 0.8951, best train loss: 0.8558)
# [Epoch: 1020] train loss: 0.8599, train acc: 0.6283, val loss: 0.4920, val acc: 0.8958  (best train acc: 0.6375, best val acc: 0.8958, best train loss: 0.8470)
# [Epoch: 1040] train loss: 0.8518, train acc: 0.6347, val loss: 0.5039, val acc: 0.8907  (best train acc: 0.6375, best val acc: 0.8965, best train loss: 0.8470)
# [Epoch: 1060] train loss: 0.8582, train acc: 0.6327, val loss: 0.4839, val acc: 0.8921  (best train acc: 0.6477, best val acc: 0.8965, best train loss: 0.8470)
# [Epoch: 1080] train loss: 0.8420, train acc: 0.6408, val loss: 0.4840, val acc: 0.8887  (best train acc: 0.6477, best val acc: 0.8965, best train loss: 0.8416)
# [Epoch: 1100] train loss: 0.8479, train acc: 0.6378, val loss: 0.4715, val acc: 0.8961  (best train acc: 0.6477, best val acc: 0.8965, best train loss: 0.8343)
# [Epoch: 1120] train loss: 0.8582, train acc: 0.6304, val loss: 0.4722, val acc: 0.8965  (best train acc: 0.6506, best val acc: 0.8978, best train loss: 0.8225)
# [Epoch: 1140] train loss: 0.8446, train acc: 0.6513, val loss: 0.4662, val acc: 0.8924  (best train acc: 0.6530, best val acc: 0.8978, best train loss: 0.8225)
# [Epoch: 1160] train loss: 0.8580, train acc: 0.6340, val loss: 0.4712, val acc: 0.8897  (best train acc: 0.6546, best val acc: 0.8978, best train loss: 0.8225)
# [Epoch: 1180] train loss: 0.8331, train acc: 0.6502, val loss: 0.4604, val acc: 0.8867  (best train acc: 0.6580, best val acc: 0.8978, best train loss: 0.8225)
# [Epoch: 1200] train loss: 0.8379, train acc: 0.6566, val loss: 0.4714, val acc: 0.8880  (best train acc: 0.6721, best val acc: 0.8978, best train loss: 0.8225)
# [Epoch: 1220] train loss: 0.8283, train acc: 0.6519, val loss: 0.4540, val acc: 0.8934  (best train acc: 0.6721, best val acc: 0.8978, best train loss: 0.8225)
# [Epoch: 1240] train loss: 0.8273, train acc: 0.6626, val loss: 0.4696, val acc: 0.8806  (best train acc: 0.6721, best val acc: 0.8978, best train loss: 0.8225)
# [Epoch: 1260] train loss: 0.8268, train acc: 0.6598, val loss: 0.4637, val acc: 0.8850  (best train acc: 0.6721, best val acc: 0.8978, best train loss: 0.8225)
# [Epoch: 1280] train loss: 0.8258, train acc: 0.6690, val loss: 0.4536, val acc: 0.8934  (best train acc: 0.6747, best val acc: 0.8978, best train loss: 0.8190)
# [Epoch: 1300] train loss: 0.8188, train acc: 0.6671, val loss: 0.4484, val acc: 0.8961  (best train acc: 0.6747, best val acc: 0.8978, best train loss: 0.8132)
# [Epoch: 1320] train loss: 0.8334, train acc: 0.6644, val loss: 0.4507, val acc: 0.8931  (best train acc: 0.6747, best val acc: 0.8978, best train loss: 0.8132)
# [Epoch: 1340] train loss: 0.8172, train acc: 0.6706, val loss: 0.4427, val acc: 0.8965  (best train acc: 0.6747, best val acc: 0.8978, best train loss: 0.8132)
# [Epoch: 1360] train loss: 0.8352, train acc: 0.6651, val loss: 0.4459, val acc: 0.8911  (best train acc: 0.6797, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1380] train loss: 0.8290, train acc: 0.6588, val loss: 0.4376, val acc: 0.8958  (best train acc: 0.6797, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1400] train loss: 0.8431, train acc: 0.6602, val loss: 0.4522, val acc: 0.8901  (best train acc: 0.6797, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1420] train loss: 0.8242, train acc: 0.6658, val loss: 0.4364, val acc: 0.8917  (best train acc: 0.6797, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1440] train loss: 0.8294, train acc: 0.6624, val loss: 0.4444, val acc: 0.8944  (best train acc: 0.6797, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1460] train loss: 0.8110, train acc: 0.6687, val loss: 0.4456, val acc: 0.8944  (best train acc: 0.6824, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1480] train loss: 0.8210, train acc: 0.6668, val loss: 0.4372, val acc: 0.8958  (best train acc: 0.6824, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1500] train loss: 0.8255, train acc: 0.6643, val loss: 0.4438, val acc: 0.8934  (best train acc: 0.6824, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1520] train loss: 0.8104, train acc: 0.6720, val loss: 0.4367, val acc: 0.8944  (best train acc: 0.6824, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1540] train loss: 0.8234, train acc: 0.6671, val loss: 0.4334, val acc: 0.8944  (best train acc: 0.6824, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1560] train loss: 0.8243, train acc: 0.6641, val loss: 0.4254, val acc: 0.8927  (best train acc: 0.6824, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1580] train loss: 0.8117, train acc: 0.6805, val loss: 0.4344, val acc: 0.8938  (best train acc: 0.6824, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1600] train loss: 0.8350, train acc: 0.6636, val loss: 0.4466, val acc: 0.8927  (best train acc: 0.6847, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1620] train loss: 0.8112, train acc: 0.6705, val loss: 0.4284, val acc: 0.8944  (best train acc: 0.6847, best val acc: 0.8978, best train loss: 0.7968)
# [Epoch: 1640] train loss: 0.8267, train acc: 0.6585, val loss: 0.4312, val acc: 0.8880  (best train acc: 0.6847, best val acc: 0.8978, best train loss: 0.7955)
# [Epoch: 1660] train loss: 0.8070, train acc: 0.6692, val loss: 0.4280, val acc: 0.8948  (best train acc: 0.6847, best val acc: 0.8978, best train loss: 0.7955)
# [Epoch: 1680] train loss: 0.8089, train acc: 0.6774, val loss: 0.4377, val acc: 0.8921  (best train acc: 0.6847, best val acc: 0.8978, best train loss: 0.7952)
# [Epoch: 1700] train loss: 0.8075, train acc: 0.6694, val loss: 0.4329, val acc: 0.8921  (best train acc: 0.6847, best val acc: 0.8978, best train loss: 0.7855)
# [Epoch: 1720] train loss: 0.8141, train acc: 0.6752, val loss: 0.4406, val acc: 0.8961  (best train acc: 0.6873, best val acc: 0.8988, best train loss: 0.7855)
# [Epoch: 1740] train loss: 0.7887, train acc: 0.6741, val loss: 0.4307, val acc: 0.8924  (best train acc: 0.6873, best val acc: 0.8992, best train loss: 0.7855)
# [Epoch: 1760] train loss: 0.7897, train acc: 0.6786, val loss: 0.4194, val acc: 0.8968  (best train acc: 0.6873, best val acc: 0.8992, best train loss: 0.7855)
# [Epoch: 1780] train loss: 0.8028, train acc: 0.6834, val loss: 0.4230, val acc: 0.8927  (best train acc: 0.6873, best val acc: 0.8992, best train loss: 0.7855)
# [Epoch: 1800] train loss: 0.8368, train acc: 0.6632, val loss: 0.4426, val acc: 0.8695  (best train acc: 0.6873, best val acc: 0.8992, best train loss: 0.7855)
# [Epoch: 1820] train loss: 0.8225, train acc: 0.6713, val loss: 0.4712, val acc: 0.8570  (best train acc: 0.6873, best val acc: 0.8992, best train loss: 0.7855)
# [Epoch: 1840] train loss: 0.7925, train acc: 0.6677, val loss: 0.4342, val acc: 0.8836  (best train acc: 0.6898, best val acc: 0.8992, best train loss: 0.7855)
# [Epoch: 1860] train loss: 0.7405, train acc: 0.7016, val loss: 0.4086, val acc: 0.8965  (best train acc: 0.7113, best val acc: 0.8992, best train loss: 0.7398)
# [Epoch: 1880] train loss: 0.7274, train acc: 0.7032, val loss: 0.4036, val acc: 0.8870  (best train acc: 0.7157, best val acc: 0.8992, best train loss: 0.7272)
# [Epoch: 1900] train loss: 0.7354, train acc: 0.7086, val loss: 0.4054, val acc: 0.8965  (best train acc: 0.7157, best val acc: 0.9002, best train loss: 0.7256)
# [Epoch: 1920] train loss: 0.7358, train acc: 0.7063, val loss: 0.3923, val acc: 0.8944  (best train acc: 0.7165, best val acc: 0.9002, best train loss: 0.7142)
# [Epoch: 1940] train loss: 0.7272, train acc: 0.7084, val loss: 0.3918, val acc: 0.8961  (best train acc: 0.7165, best val acc: 0.9002, best train loss: 0.7142)
# [Epoch: 1960] train loss: 0.7270, train acc: 0.7062, val loss: 0.3906, val acc: 0.8921  (best train acc: 0.7165, best val acc: 0.9002, best train loss: 0.7142)
# [Epoch: 1980] train loss: 0.7342, train acc: 0.7072, val loss: 0.3897, val acc: 0.8985  (best train acc: 0.7188, best val acc: 0.9002, best train loss: 0.7090)
# [Epoch: 2000] train loss: 0.7392, train acc: 0.7018, val loss: 0.3999, val acc: 0.8941  (best train acc: 0.7204, best val acc: 0.9002, best train loss: 0.7090)
# [Epoch: 2020] train loss: 0.7382, train acc: 0.7117, val loss: 0.4030, val acc: 0.8911  (best train acc: 0.7204, best val acc: 0.9002, best train loss: 0.7090)
# [Epoch: 2040] train loss: 0.7654, train acc: 0.7000, val loss: 0.4200, val acc: 0.8725  (best train acc: 0.7204, best val acc: 0.9002, best train loss: 0.7090)
# [Epoch: 2060] train loss: 0.7654, train acc: 0.6654, val loss: 0.4193, val acc: 0.8840  (best train acc: 0.7204, best val acc: 0.9002, best train loss: 0.7090)
# [Epoch: 2080] train loss: 0.7306, train acc: 0.6998, val loss: 0.3920, val acc: 0.8958  (best train acc: 0.7204, best val acc: 0.9002, best train loss: 0.7090)
# [Epoch: 2100] train loss: 0.7353, train acc: 0.7144, val loss: 0.3925, val acc: 0.8934  (best train acc: 0.7204, best val acc: 0.9002, best train loss: 0.7090)
# [Epoch: 2120] train loss: 0.7217, train acc: 0.7212, val loss: 0.3877, val acc: 0.8961  (best train acc: 0.7212, best val acc: 0.9002, best train loss: 0.7078)
# [Epoch: 2140] train loss: 0.7493, train acc: 0.7031, val loss: 0.3967, val acc: 0.8931  (best train acc: 0.7212, best val acc: 0.9002, best train loss: 0.7078)
# [Epoch: 2160] train loss: 0.7020, train acc: 0.7196, val loss: 0.3879, val acc: 0.8975  (best train acc: 0.7212, best val acc: 0.9002, best train loss: 0.7020)
# [Epoch: 2180] train loss: 0.7464, train acc: 0.6972, val loss: 0.3875, val acc: 0.8958  (best train acc: 0.7220, best val acc: 0.9002, best train loss: 0.7020)
# [Epoch: 2200] train loss: 0.7307, train acc: 0.7047, val loss: 0.3876, val acc: 0.8978  (best train acc: 0.7250, best val acc: 0.9002, best train loss: 0.7020)
# [Epoch: 2220] train loss: 0.7344, train acc: 0.7055, val loss: 0.3920, val acc: 0.8961  (best train acc: 0.7250, best val acc: 0.9002, best train loss: 0.7020)
# [Epoch: 2240] train loss: 0.7200, train acc: 0.7138, val loss: 0.3991, val acc: 0.8894  (best train acc: 0.7250, best val acc: 0.9002, best train loss: 0.7020)
# [Epoch: 2260] train loss: 0.7201, train acc: 0.7245, val loss: 0.3921, val acc: 0.8975  (best train acc: 0.7269, best val acc: 0.9002, best train loss: 0.7020)
# [Epoch: 2280] train loss: 0.7275, train acc: 0.7159, val loss: 0.3999, val acc: 0.8921  (best train acc: 0.7269, best val acc: 0.9002, best train loss: 0.7015)
# [Epoch: 2300] train loss: 0.7307, train acc: 0.7069, val loss: 0.3873, val acc: 0.8944  (best train acc: 0.7269, best val acc: 0.9002, best train loss: 0.7013)
# [Epoch: 2320] train loss: 0.7211, train acc: 0.7122, val loss: 0.3981, val acc: 0.8860  (best train acc: 0.7269, best val acc: 0.9002, best train loss: 0.7013)
# [Epoch: 2340] train loss: 0.7277, train acc: 0.7163, val loss: 0.3925, val acc: 0.8965  (best train acc: 0.7294, best val acc: 0.9002, best train loss: 0.6988)
# [Epoch: 2360] train loss: 0.7410, train acc: 0.6972, val loss: 0.4185, val acc: 0.8874  (best train acc: 0.7294, best val acc: 0.9002, best train loss: 0.6988)
# [Epoch: 2380] train loss: 0.7183, train acc: 0.7176, val loss: 0.3923, val acc: 0.8954  (best train acc: 0.7294, best val acc: 0.9002, best train loss: 0.6988)
# [Epoch: 2400] train loss: 0.7355, train acc: 0.7016, val loss: 0.3750, val acc: 0.8975  (best train acc: 0.7294, best val acc: 0.9002, best train loss: 0.6988)
# [Epoch: 2420] train loss: 0.7311, train acc: 0.7119, val loss: 0.3892, val acc: 0.8961  (best train acc: 0.7294, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2440] train loss: 0.7140, train acc: 0.7170, val loss: 0.3862, val acc: 0.8954  (best train acc: 0.7294, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2460] train loss: 0.7489, train acc: 0.7021, val loss: 0.4387, val acc: 0.8830  (best train acc: 0.7294, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2480] train loss: 0.7231, train acc: 0.7157, val loss: 0.3957, val acc: 0.8847  (best train acc: 0.7294, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2500] train loss: 0.7110, train acc: 0.7131, val loss: 0.3778, val acc: 0.8927  (best train acc: 0.7294, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2520] train loss: 0.7031, train acc: 0.7221, val loss: 0.3807, val acc: 0.8975  (best train acc: 0.7294, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2540] train loss: 0.7234, train acc: 0.7117, val loss: 0.3839, val acc: 0.8995  (best train acc: 0.7297, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2560] train loss: 0.7422, train acc: 0.7085, val loss: 0.4108, val acc: 0.8823  (best train acc: 0.7297, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2580] train loss: 0.7367, train acc: 0.7085, val loss: 0.3765, val acc: 0.8975  (best train acc: 0.7297, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2600] train loss: 0.7122, train acc: 0.7129, val loss: 0.4148, val acc: 0.8860  (best train acc: 0.7297, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2620] train loss: 0.7284, train acc: 0.7098, val loss: 0.3969, val acc: 0.8934  (best train acc: 0.7297, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2640] train loss: 0.7194, train acc: 0.7106, val loss: 0.3846, val acc: 0.8958  (best train acc: 0.7297, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2660] train loss: 0.6984, train acc: 0.7265, val loss: 0.3743, val acc: 0.8958  (best train acc: 0.7297, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2680] train loss: 0.7121, train acc: 0.7096, val loss: 0.3827, val acc: 0.8981  (best train acc: 0.7297, best val acc: 0.9002, best train loss: 0.6957)
# [Epoch: 2700] train loss: 0.7080, train acc: 0.7176, val loss: 0.3697, val acc: 0.8965  (best train acc: 0.7314, best val acc: 0.9002, best train loss: 0.6885)
# [Epoch: 2720] train loss: 0.7026, train acc: 0.7248, val loss: 0.3764, val acc: 0.8965  (best train acc: 0.7314, best val acc: 0.9002, best train loss: 0.6885)
# [Epoch: 2740] train loss: 0.7162, train acc: 0.7207, val loss: 0.3835, val acc: 0.8850  (best train acc: 0.7314, best val acc: 0.9002, best train loss: 0.6885)
# [Epoch: 2760] train loss: 0.7292, train acc: 0.7019, val loss: 0.3687, val acc: 0.8927  (best train acc: 0.7314, best val acc: 0.9002, best train loss: 0.6885)
# [Epoch: 2780] train loss: 0.7133, train acc: 0.7128, val loss: 0.3718, val acc: 0.8924  (best train acc: 0.7314, best val acc: 0.9002, best train loss: 0.6885)
# [Epoch: 2800] train loss: 0.7116, train acc: 0.7198, val loss: 0.3855, val acc: 0.8924  (best train acc: 0.7356, best val acc: 0.9002, best train loss: 0.6885)
# [Epoch: 2820] train loss: 0.6893, train acc: 0.7315, val loss: 0.3842, val acc: 0.8934  (best train acc: 0.7366, best val acc: 0.9002, best train loss: 0.6814)
# [Epoch: 2840] train loss: 0.6792, train acc: 0.7363, val loss: 0.3781, val acc: 0.8924  (best train acc: 0.7465, best val acc: 0.9002, best train loss: 0.6597)
# [Epoch: 2860] train loss: 0.6702, train acc: 0.7391, val loss: 0.3763, val acc: 0.8874  (best train acc: 0.7465, best val acc: 0.9002, best train loss: 0.6476)
# [Epoch: 2880] train loss: 0.6520, train acc: 0.7389, val loss: 0.3677, val acc: 0.8914  (best train acc: 0.7467, best val acc: 0.9002, best train loss: 0.6432)
# [Epoch: 2900] train loss: 0.6603, train acc: 0.7283, val loss: 0.3806, val acc: 0.8809  (best train acc: 0.7467, best val acc: 0.9002, best train loss: 0.6432)
# [Epoch: 2920] train loss: 0.6756, train acc: 0.7225, val loss: 0.3791, val acc: 0.8911  (best train acc: 0.7467, best val acc: 0.9002, best train loss: 0.6432)
# [Epoch: 2940] train loss: 0.6536, train acc: 0.7344, val loss: 0.3577, val acc: 0.9012  (best train acc: 0.7467, best val acc: 0.9012, best train loss: 0.6339)
# [Epoch: 2960] train loss: 0.6491, train acc: 0.7389, val loss: 0.3511, val acc: 0.9019  (best train acc: 0.7467, best val acc: 0.9029, best train loss: 0.6300)
# [Epoch: 2980] train loss: 0.6608, train acc: 0.7344, val loss: 0.3524, val acc: 0.9008  (best train acc: 0.7467, best val acc: 0.9029, best train loss: 0.6300)
# [Epoch: 3000] train loss: 0.6352, train acc: 0.7434, val loss: 0.3493, val acc: 0.8968  (best train acc: 0.7467, best val acc: 0.9029, best train loss: 0.6300)
# [Epoch: 3020] train loss: 0.6513, train acc: 0.7365, val loss: 0.3538, val acc: 0.8911  (best train acc: 0.7467, best val acc: 0.9029, best train loss: 0.6300)
# [Epoch: 3040] train loss: 0.6373, train acc: 0.7448, val loss: 0.3444, val acc: 0.9015  (best train acc: 0.7514, best val acc: 0.9029, best train loss: 0.6238)
# [Epoch: 3060] train loss: 0.6493, train acc: 0.7305, val loss: 0.3463, val acc: 0.8988  (best train acc: 0.7514, best val acc: 0.9035, best train loss: 0.6238)
# [Epoch: 3080] train loss: 0.6321, train acc: 0.7381, val loss: 0.3593, val acc: 0.8887  (best train acc: 0.7514, best val acc: 0.9035, best train loss: 0.6238)
# [Epoch: 3100] train loss: 0.6430, train acc: 0.7428, val loss: 0.3415, val acc: 0.8992  (best train acc: 0.7514, best val acc: 0.9035, best train loss: 0.6189)
# [Epoch: 3120] train loss: 0.6293, train acc: 0.7433, val loss: 0.3419, val acc: 0.9032  (best train acc: 0.7514, best val acc: 0.9035, best train loss: 0.6189)
# [Epoch: 3140] train loss: 0.6437, train acc: 0.7405, val loss: 0.3372, val acc: 0.9025  (best train acc: 0.7514, best val acc: 0.9035, best train loss: 0.6189)
# [Epoch: 3160] train loss: 0.6393, train acc: 0.7452, val loss: 0.3390, val acc: 0.8998  (best train acc: 0.7514, best val acc: 0.9035, best train loss: 0.6189)
# [Epoch: 3180] train loss: 0.6500, train acc: 0.7390, val loss: 0.3269, val acc: 0.9039  (best train acc: 0.7514, best val acc: 0.9042, best train loss: 0.6189)
# [Epoch: 3200] train loss: 0.6229, train acc: 0.7409, val loss: 0.3429, val acc: 0.9022  (best train acc: 0.7514, best val acc: 0.9046, best train loss: 0.6189)
# [Epoch: 3220] train loss: 0.6399, train acc: 0.7455, val loss: 0.3316, val acc: 0.9005  (best train acc: 0.7519, best val acc: 0.9046, best train loss: 0.6189)
# [Epoch: 3240] train loss: 0.6290, train acc: 0.7466, val loss: 0.3274, val acc: 0.9022  (best train acc: 0.7519, best val acc: 0.9046, best train loss: 0.6189)
# [Epoch: 3260] train loss: 0.6195, train acc: 0.7443, val loss: 0.3318, val acc: 0.8998  (best train acc: 0.7519, best val acc: 0.9046, best train loss: 0.6189)
# [Epoch: 3280] train loss: 0.6336, train acc: 0.7370, val loss: 0.3355, val acc: 0.9012  (best train acc: 0.7519, best val acc: 0.9046, best train loss: 0.6189)
# [Epoch: 3300] train loss: 0.6349, train acc: 0.7489, val loss: 0.3332, val acc: 0.9039  (best train acc: 0.7519, best val acc: 0.9046, best train loss: 0.6181)
# [Epoch: 3320] train loss: 0.6214, train acc: 0.7514, val loss: 0.3263, val acc: 0.9032  (best train acc: 0.7529, best val acc: 0.9046, best train loss: 0.6175)
# [Epoch: 3340] train loss: 0.6306, train acc: 0.7442, val loss: 0.3185, val acc: 0.8998  (best train acc: 0.7529, best val acc: 0.9046, best train loss: 0.6175)
# [Epoch: 3360] train loss: 0.6311, train acc: 0.7430, val loss: 0.3293, val acc: 0.9022  (best train acc: 0.7529, best val acc: 0.9046, best train loss: 0.6126)
# [Epoch: 3380] train loss: 0.6270, train acc: 0.7467, val loss: 0.3195, val acc: 0.9035  (best train acc: 0.7538, best val acc: 0.9046, best train loss: 0.6099)
# [Epoch: 3400] train loss: 0.6465, train acc: 0.7426, val loss: 0.3568, val acc: 0.8948  (best train acc: 0.7540, best val acc: 0.9052, best train loss: 0.6090)
# [Epoch: 3420] train loss: 0.6469, train acc: 0.7392, val loss: 0.3444, val acc: 0.8870  (best train acc: 0.7540, best val acc: 0.9052, best train loss: 0.6090)
# [Epoch: 3440] train loss: 0.6342, train acc: 0.7473, val loss: 0.3265, val acc: 0.9032  (best train acc: 0.7540, best val acc: 0.9062, best train loss: 0.6090)
# [Epoch: 3460] train loss: 0.6361, train acc: 0.7358, val loss: 0.3191, val acc: 0.8948  (best train acc: 0.7540, best val acc: 0.9062, best train loss: 0.6090)
# [Epoch: 3480] train loss: 0.6376, train acc: 0.7339, val loss: 0.3311, val acc: 0.9015  (best train acc: 0.7540, best val acc: 0.9062, best train loss: 0.6090)
# [Epoch: 3500] train loss: 0.6259, train acc: 0.7433, val loss: 0.3199, val acc: 0.9025  (best train acc: 0.7540, best val acc: 0.9062, best train loss: 0.6090)
# [Epoch: 3520] train loss: 0.6344, train acc: 0.7449, val loss: 0.3177, val acc: 0.9019  (best train acc: 0.7540, best val acc: 0.9062, best train loss: 0.6090)
# [Epoch: 3540] train loss: 0.6498, train acc: 0.7340, val loss: 0.3182, val acc: 0.9029  (best train acc: 0.7540, best val acc: 0.9062, best train loss: 0.6090)
# [Epoch: 3560] train loss: 0.6338, train acc: 0.7452, val loss: 0.3207, val acc: 0.9032  (best train acc: 0.7540, best val acc: 0.9062, best train loss: 0.6090)
# [Epoch: 3580] train loss: 0.6326, train acc: 0.7372, val loss: 0.3334, val acc: 0.8941  (best train acc: 0.7540, best val acc: 0.9062, best train loss: 0.6090)
# [Epoch: 3600] train loss: 0.6195, train acc: 0.7489, val loss: 0.3197, val acc: 0.9025  (best train acc: 0.7564, best val acc: 0.9062, best train loss: 0.6060)
# [Epoch: 3620] train loss: 0.6164, train acc: 0.7463, val loss: 0.3295, val acc: 0.9035  (best train acc: 0.7564, best val acc: 0.9062, best train loss: 0.6060)
# [Epoch: 3640] train loss: 0.6293, train acc: 0.7397, val loss: 0.3254, val acc: 0.9049  (best train acc: 0.7564, best val acc: 0.9073, best train loss: 0.6060)
# [Epoch: 3660] train loss: 0.6218, train acc: 0.7509, val loss: 0.3284, val acc: 0.9012  (best train acc: 0.7564, best val acc: 0.9073, best train loss: 0.6060)
# [Epoch: 3680] train loss: 0.6348, train acc: 0.7422, val loss: 0.3189, val acc: 0.8965  (best train acc: 0.7564, best val acc: 0.9073, best train loss: 0.6060)
# [Epoch: 3700] train loss: 0.6088, train acc: 0.7515, val loss: 0.3153, val acc: 0.9019  (best train acc: 0.7579, best val acc: 0.9086, best train loss: 0.5977)
# [Epoch: 3720] train loss: 0.6359, train acc: 0.7407, val loss: 0.3186, val acc: 0.9069  (best train acc: 0.7579, best val acc: 0.9089, best train loss: 0.5977)
# [Epoch: 3740] train loss: 0.6242, train acc: 0.7423, val loss: 0.3105, val acc: 0.9052  (best train acc: 0.7579, best val acc: 0.9089, best train loss: 0.5977)
# [Epoch: 3760] train loss: 0.6156, train acc: 0.7453, val loss: 0.3105, val acc: 0.9032  (best train acc: 0.7579, best val acc: 0.9089, best train loss: 0.5977)
# [Epoch: 3780] train loss: 0.6424, train acc: 0.7325, val loss: 0.3622, val acc: 0.8816  (best train acc: 0.7579, best val acc: 0.9096, best train loss: 0.5977)
# [Epoch: 3800] train loss: 0.6369, train acc: 0.7436, val loss: 0.2967, val acc: 0.9079  (best train acc: 0.7579, best val acc: 0.9096, best train loss: 0.5977)
# [Epoch: 3820] train loss: 0.6129, train acc: 0.7531, val loss: 0.3200, val acc: 0.9086  (best train acc: 0.7579, best val acc: 0.9106, best train loss: 0.5977)
# [Epoch: 3840] train loss: 0.6319, train acc: 0.7449, val loss: 0.3107, val acc: 0.9079  (best train acc: 0.7579, best val acc: 0.9106, best train loss: 0.5977)
# [Epoch: 3860] train loss: 0.6311, train acc: 0.7431, val loss: 0.3114, val acc: 0.9059  (best train acc: 0.7579, best val acc: 0.9106, best train loss: 0.5977)
# [Epoch: 3880] train loss: 0.6349, train acc: 0.7420, val loss: 0.3102, val acc: 0.9096  (best train acc: 0.7592, best val acc: 0.9110, best train loss: 0.5977)
# [Epoch: 3900] train loss: 0.6183, train acc: 0.7454, val loss: 0.3057, val acc: 0.9093  (best train acc: 0.7600, best val acc: 0.9116, best train loss: 0.5977)
# [Epoch: 3920] train loss: 0.6147, train acc: 0.7564, val loss: 0.3094, val acc: 0.9049  (best train acc: 0.7600, best val acc: 0.9116, best train loss: 0.5977)
# [Epoch: 3940] train loss: 0.6191, train acc: 0.7487, val loss: 0.3197, val acc: 0.8988  (best train acc: 0.7600, best val acc: 0.9130, best train loss: 0.5977)
# [Epoch: 3960] train loss: 0.6386, train acc: 0.7398, val loss: 0.3557, val acc: 0.8809  (best train acc: 0.7622, best val acc: 0.9130, best train loss: 0.5977)
# [Epoch: 3980] train loss: 0.6072, train acc: 0.7545, val loss: 0.2997, val acc: 0.9130  (best train acc: 0.7622, best val acc: 0.9130, best train loss: 0.5977)
# [Epoch: 4000] train loss: 0.6182, train acc: 0.7509, val loss: 0.3284, val acc: 0.8958  (best train acc: 0.7622, best val acc: 0.9130, best train loss: 0.5977)
# [Epoch: 4020] train loss: 0.6292, train acc: 0.7400, val loss: 0.3318, val acc: 0.8968  (best train acc: 0.7622, best val acc: 0.9130, best train loss: 0.5977)
# [Epoch: 4040] train loss: 0.6255, train acc: 0.7467, val loss: 0.3146, val acc: 0.8992  (best train acc: 0.7622, best val acc: 0.9137, best train loss: 0.5977)
# [Epoch: 4060] train loss: 0.6039, train acc: 0.7496, val loss: 0.3003, val acc: 0.9106  (best train acc: 0.7622, best val acc: 0.9140, best train loss: 0.5977)
# [Epoch: 4080] train loss: 0.6061, train acc: 0.7523, val loss: 0.3113, val acc: 0.9096  (best train acc: 0.7622, best val acc: 0.9140, best train loss: 0.5977)
# [Epoch: 4100] train loss: 0.6023, train acc: 0.7565, val loss: 0.3181, val acc: 0.9089  (best train acc: 0.7622, best val acc: 0.9140, best train loss: 0.5977)
# [Epoch: 4120] train loss: 0.6113, train acc: 0.7530, val loss: 0.3088, val acc: 0.9089  (best train acc: 0.7622, best val acc: 0.9143, best train loss: 0.5971)
# [Epoch: 4140] train loss: 0.6119, train acc: 0.7520, val loss: 0.3086, val acc: 0.9120  (best train acc: 0.7640, best val acc: 0.9143, best train loss: 0.5971)
# [Epoch: 4160] train loss: 0.6186, train acc: 0.7556, val loss: 0.3107, val acc: 0.9093  (best train acc: 0.7640, best val acc: 0.9143, best train loss: 0.5971)
# [Epoch: 4180] train loss: 0.6076, train acc: 0.7543, val loss: 0.3098, val acc: 0.9137  (best train acc: 0.7640, best val acc: 0.9147, best train loss: 0.5971)
# [Epoch: 4200] train loss: 0.6157, train acc: 0.7540, val loss: 0.3087, val acc: 0.9106  (best train acc: 0.7640, best val acc: 0.9150, best train loss: 0.5967)
# [Epoch: 4220] train loss: 0.6110, train acc: 0.7533, val loss: 0.3048, val acc: 0.9143  (best train acc: 0.7640, best val acc: 0.9150, best train loss: 0.5967)
# [Epoch: 4240] train loss: 0.6302, train acc: 0.7338, val loss: 0.3065, val acc: 0.9153  (best train acc: 0.7640, best val acc: 0.9160, best train loss: 0.5942)
# [Epoch: 4260] train loss: 0.6418, train acc: 0.7385, val loss: 0.3168, val acc: 0.8961  (best train acc: 0.7640, best val acc: 0.9160, best train loss: 0.5942)
# [Epoch: 4280] train loss: 0.6087, train acc: 0.7482, val loss: 0.3053, val acc: 0.9079  (best train acc: 0.7640, best val acc: 0.9167, best train loss: 0.5932)
# [Epoch: 4300] train loss: 0.6092, train acc: 0.7512, val loss: 0.3046, val acc: 0.9099  (best train acc: 0.7640, best val acc: 0.9167, best train loss: 0.5932)
# [Epoch: 4320] train loss: 0.5920, train acc: 0.7582, val loss: 0.3015, val acc: 0.9167  (best train acc: 0.7658, best val acc: 0.9167, best train loss: 0.5920)
# [Epoch: 4340] train loss: 0.6110, train acc: 0.7566, val loss: 0.3018, val acc: 0.9120  (best train acc: 0.7658, best val acc: 0.9167, best train loss: 0.5904)
# [Epoch: 4360] train loss: 0.6414, train acc: 0.7394, val loss: 0.3189, val acc: 0.9066  (best train acc: 0.7658, best val acc: 0.9167, best train loss: 0.5904)
# [Epoch: 4380] train loss: 0.6253, train acc: 0.7452, val loss: 0.3361, val acc: 0.9008  (best train acc: 0.7658, best val acc: 0.9167, best train loss: 0.5904)
# [Epoch: 4400] train loss: 0.6069, train acc: 0.7499, val loss: 0.3110, val acc: 0.9147  (best train acc: 0.7658, best val acc: 0.9167, best train loss: 0.5904)
# [Epoch: 4420] train loss: 0.6092, train acc: 0.7503, val loss: 0.3106, val acc: 0.9157  (best train acc: 0.7658, best val acc: 0.9167, best train loss: 0.5902)
# [Epoch: 4440] train loss: 0.6000, train acc: 0.7572, val loss: 0.2969, val acc: 0.9180  (best train acc: 0.7658, best val acc: 0.9180, best train loss: 0.5866)
# [Epoch: 4460] train loss: 0.6082, train acc: 0.7493, val loss: 0.3002, val acc: 0.9116  (best train acc: 0.7658, best val acc: 0.9180, best train loss: 0.5866)
# [Epoch: 4480] train loss: 0.5903, train acc: 0.7603, val loss: 0.3018, val acc: 0.9137  (best train acc: 0.7658, best val acc: 0.9180, best train loss: 0.5841)
# [Epoch: 4500] train loss: 0.6129, train acc: 0.7419, val loss: 0.3471, val acc: 0.8860  (best train acc: 0.7658, best val acc: 0.9180, best train loss: 0.5841)
# [Epoch: 4520] train loss: 0.6453, train acc: 0.7285, val loss: 0.3563, val acc: 0.8897  (best train acc: 0.7658, best val acc: 0.9180, best train loss: 0.5841)
# [Epoch: 4540] train loss: 0.6100, train acc: 0.7417, val loss: 0.3432, val acc: 0.9069  (best train acc: 0.7658, best val acc: 0.9180, best train loss: 0.5841)
# [Epoch: 4560] train loss: 0.6046, train acc: 0.7470, val loss: 0.3216, val acc: 0.9042  (best train acc: 0.7658, best val acc: 0.9180, best train loss: 0.5841)
# [Epoch: 4580] train loss: 0.6044, train acc: 0.7544, val loss: 0.2973, val acc: 0.9116  (best train acc: 0.7663, best val acc: 0.9180, best train loss: 0.5841)
# [Epoch: 4600] train loss: 0.6085, train acc: 0.7470, val loss: 0.3162, val acc: 0.9002  (best train acc: 0.7663, best val acc: 0.9180, best train loss: 0.5841)
# [Epoch: 4620] train loss: 0.6204, train acc: 0.7432, val loss: 0.3064, val acc: 0.9153  (best train acc: 0.7663, best val acc: 0.9180, best train loss: 0.5841)
# [Epoch: 4640] train loss: 0.5912, train acc: 0.7629, val loss: 0.3031, val acc: 0.9130  (best train acc: 0.7663, best val acc: 0.9180, best train loss: 0.5839)
# [Epoch: 4660] train loss: 0.5884, train acc: 0.7587, val loss: 0.2983, val acc: 0.9167  (best train acc: 0.7663, best val acc: 0.9180, best train loss: 0.5819)
# [Epoch: 4680] train loss: 0.5789, train acc: 0.7632, val loss: 0.3010, val acc: 0.9174  (best train acc: 0.7663, best val acc: 0.9180, best train loss: 0.5789)
# [Epoch: 4700] train loss: 0.6144, train acc: 0.7445, val loss: 0.3195, val acc: 0.8951  (best train acc: 0.7663, best val acc: 0.9180, best train loss: 0.5779)
# [Epoch: 4720] train loss: 0.6019, train acc: 0.7548, val loss: 0.3043, val acc: 0.9113  (best train acc: 0.7663, best val acc: 0.9180, best train loss: 0.5779)
# [Epoch: 4740] train loss: 0.5883, train acc: 0.7616, val loss: 0.2970, val acc: 0.9170  (best train acc: 0.7663, best val acc: 0.9187, best train loss: 0.5779)
# [Epoch: 4760] train loss: 0.5832, train acc: 0.7660, val loss: 0.2855, val acc: 0.9184  (best train acc: 0.7668, best val acc: 0.9197, best train loss: 0.5779)
# [Epoch: 4780] train loss: 0.5777, train acc: 0.7608, val loss: 0.2953, val acc: 0.9167  (best train acc: 0.7679, best val acc: 0.9197, best train loss: 0.5777)
# [Epoch: 4800] train loss: 0.6028, train acc: 0.7574, val loss: 0.2933, val acc: 0.9164  (best train acc: 0.7679, best val acc: 0.9197, best train loss: 0.5768)
# [Epoch: 4820] train loss: 0.6176, train acc: 0.7404, val loss: 0.3487, val acc: 0.8981  (best train acc: 0.7679, best val acc: 0.9197, best train loss: 0.5768)
# [Epoch: 4840] train loss: 0.5975, train acc: 0.7558, val loss: 0.2922, val acc: 0.9174  (best train acc: 0.7679, best val acc: 0.9197, best train loss: 0.5768)
# [Epoch: 4860] train loss: 0.5793, train acc: 0.7642, val loss: 0.3003, val acc: 0.9180  (best train acc: 0.7679, best val acc: 0.9204, best train loss: 0.5761)
# [Epoch: 4880] train loss: 0.6040, train acc: 0.7517, val loss: 0.2844, val acc: 0.9140  (best train acc: 0.7679, best val acc: 0.9204, best train loss: 0.5761)
# [Epoch: 4900] train loss: 0.5419, train acc: 0.7811, val loss: 0.2631, val acc: 0.9150  (best train acc: 0.7811, best val acc: 0.9204, best train loss: 0.5419)
# [Epoch: 4920] train loss: 0.5387, train acc: 0.7820, val loss: 0.2649, val acc: 0.9086  (best train acc: 0.7828, best val acc: 0.9204, best train loss: 0.5354)
# [Epoch: 4940] train loss: 0.5445, train acc: 0.7720, val loss: 0.2568, val acc: 0.9137  (best train acc: 0.7828, best val acc: 0.9204, best train loss: 0.5269)
# [Epoch: 4960] train loss: 0.5274, train acc: 0.7805, val loss: 0.2570, val acc: 0.9123  (best train acc: 0.7849, best val acc: 0.9204, best train loss: 0.5269)
# [Epoch: 4980] train loss: 0.5866, train acc: 0.7540, val loss: 0.2675, val acc: 0.8965  (best train acc: 0.7849, best val acc: 0.9204, best train loss: 0.5269)
# [Epoch: 5000] train loss: 0.5409, train acc: 0.7719, val loss: 0.2577, val acc: 0.9140  (best train acc: 0.7849, best val acc: 0.9204, best train loss: 0.5269)
# [Epoch: 5020] train loss: 0.5340, train acc: 0.7741, val loss: 0.2724, val acc: 0.9137  (best train acc: 0.7849, best val acc: 0.9204, best train loss: 0.5259)
# [Epoch: 5040] train loss: 0.5301, train acc: 0.7745, val loss: 0.2607, val acc: 0.9170  (best train acc: 0.7860, best val acc: 0.9204, best train loss: 0.5150)
# [Epoch: 5060] train loss: 0.5299, train acc: 0.7773, val loss: 0.2602, val acc: 0.9110  (best train acc: 0.7860, best val acc: 0.9204, best train loss: 0.5150)
# [Epoch: 5080] train loss: 0.5419, train acc: 0.7632, val loss: 0.2627, val acc: 0.9116  (best train acc: 0.7860, best val acc: 0.9204, best train loss: 0.5150)
# [Epoch: 5100] train loss: 0.5205, train acc: 0.7760, val loss: 0.2644, val acc: 0.9133  (best train acc: 0.7860, best val acc: 0.9204, best train loss: 0.5141)
# [Epoch: 5120] train loss: 0.5270, train acc: 0.7734, val loss: 0.2701, val acc: 0.9099  (best train acc: 0.7860, best val acc: 0.9204, best train loss: 0.5120)
# [Epoch: 5140] train loss: 0.5327, train acc: 0.7650, val loss: 0.2587, val acc: 0.9106  (best train acc: 0.7860, best val acc: 0.9204, best train loss: 0.5097)
# [Epoch: 5160] train loss: 0.5248, train acc: 0.7746, val loss: 0.2546, val acc: 0.9140  (best train acc: 0.7860, best val acc: 0.9204, best train loss: 0.5072)
# [Epoch: 5180] train loss: 0.4966, train acc: 0.8001, val loss: 0.2627, val acc: 0.9143  (best train acc: 0.8038, best val acc: 0.9204, best train loss: 0.4877)
# [Epoch: 5200] train loss: 0.5038, train acc: 0.7901, val loss: 0.2527, val acc: 0.9147  (best train acc: 0.8049, best val acc: 0.9204, best train loss: 0.4772)
# [Epoch: 5220] train loss: 0.4722, train acc: 0.8077, val loss: 0.2454, val acc: 0.9187  (best train acc: 0.8122, best val acc: 0.9204, best train loss: 0.4709)
# [Epoch: 5240] train loss: 0.4799, train acc: 0.8044, val loss: 0.2418, val acc: 0.9191  (best train acc: 0.8151, best val acc: 0.9204, best train loss: 0.4642)
# [Epoch: 5260] train loss: 0.4644, train acc: 0.8168, val loss: 0.2457, val acc: 0.9180  (best train acc: 0.8168, best val acc: 0.9204, best train loss: 0.4642)
# [Epoch: 5280] train loss: 0.4855, train acc: 0.7981, val loss: 0.2466, val acc: 0.9167  (best train acc: 0.8198, best val acc: 0.9204, best train loss: 0.4552)
# [Epoch: 5300] train loss: 0.4670, train acc: 0.8144, val loss: 0.2470, val acc: 0.9160  (best train acc: 0.8198, best val acc: 0.9207, best train loss: 0.4552)
# [Epoch: 5320] train loss: 0.4667, train acc: 0.8088, val loss: 0.2468, val acc: 0.9167  (best train acc: 0.8198, best val acc: 0.9207, best train loss: 0.4552)
# [Epoch: 5340] train loss: 0.4686, train acc: 0.8161, val loss: 0.2562, val acc: 0.9106  (best train acc: 0.8206, best val acc: 0.9207, best train loss: 0.4552)
# [Epoch: 5360] train loss: 0.4748, train acc: 0.8050, val loss: 0.2446, val acc: 0.9177  (best train acc: 0.8206, best val acc: 0.9207, best train loss: 0.4552)
# [Epoch: 5380] train loss: 0.4660, train acc: 0.8164, val loss: 0.2470, val acc: 0.9197  (best train acc: 0.8206, best val acc: 0.9211, best train loss: 0.4552)
# [Epoch: 5400] train loss: 0.4643, train acc: 0.8104, val loss: 0.2403, val acc: 0.9194  (best train acc: 0.8231, best val acc: 0.9214, best train loss: 0.4539)
# [Epoch: 5420] train loss: 0.4714, train acc: 0.8041, val loss: 0.2471, val acc: 0.9120  (best train acc: 0.8231, best val acc: 0.9214, best train loss: 0.4539)
# [Epoch: 5440] train loss: 0.4679, train acc: 0.8131, val loss: 0.2399, val acc: 0.9184  (best train acc: 0.8231, best val acc: 0.9214, best train loss: 0.4539)
# [Epoch: 5460] train loss: 0.4706, train acc: 0.8086, val loss: 0.2651, val acc: 0.9008  (best train acc: 0.8231, best val acc: 0.9214, best train loss: 0.4496)
# [Epoch: 5480] train loss: 0.4748, train acc: 0.8035, val loss: 0.2796, val acc: 0.8958  (best train acc: 0.8231, best val acc: 0.9214, best train loss: 0.4496)
# [Epoch: 5500] train loss: 0.4570, train acc: 0.8162, val loss: 0.2430, val acc: 0.9207  (best train acc: 0.8231, best val acc: 0.9218, best train loss: 0.4496)
# [Epoch: 5520] train loss: 0.4625, train acc: 0.8144, val loss: 0.2481, val acc: 0.9150  (best train acc: 0.8241, best val acc: 0.9218, best train loss: 0.4496)
# [Epoch: 5540] train loss: 0.4591, train acc: 0.8124, val loss: 0.2500, val acc: 0.9184  (best train acc: 0.8241, best val acc: 0.9224, best train loss: 0.4496)
# [Epoch: 5560] train loss: 0.4569, train acc: 0.8175, val loss: 0.2721, val acc: 0.9029  (best train acc: 0.8241, best val acc: 0.9224, best train loss: 0.4496)
# [Epoch: 5580] train loss: 0.4688, train acc: 0.8193, val loss: 0.2421, val acc: 0.9204  (best train acc: 0.8241, best val acc: 0.9224, best train loss: 0.4496)
# [Epoch: 5600] train loss: 0.4644, train acc: 0.8087, val loss: 0.2390, val acc: 0.9191  (best train acc: 0.8262, best val acc: 0.9224, best train loss: 0.4459)
# [Epoch: 5620] train loss: 0.4599, train acc: 0.8156, val loss: 0.2416, val acc: 0.9201  (best train acc: 0.8262, best val acc: 0.9224, best train loss: 0.4459)
# [Epoch: 5640] train loss: 0.4851, train acc: 0.8024, val loss: 0.2468, val acc: 0.9147  (best train acc: 0.8262, best val acc: 0.9224, best train loss: 0.4459)
# [Epoch: 5660] train loss: 0.4605, train acc: 0.8100, val loss: 0.2788, val acc: 0.8981  (best train acc: 0.8262, best val acc: 0.9224, best train loss: 0.4459)
# [Epoch: 5680] train loss: 0.4553, train acc: 0.8169, val loss: 0.2506, val acc: 0.9150  (best train acc: 0.8262, best val acc: 0.9224, best train loss: 0.4459)
# [Epoch: 5700] train loss: 0.4679, train acc: 0.8095, val loss: 0.2443, val acc: 0.9218  (best train acc: 0.8262, best val acc: 0.9224, best train loss: 0.4445)
# [Epoch: 5720] train loss: 0.4578, train acc: 0.8167, val loss: 0.2647, val acc: 0.9059  (best train acc: 0.8262, best val acc: 0.9224, best train loss: 0.4414)
# [Epoch: 5740] train loss: 0.4648, train acc: 0.8176, val loss: 0.2448, val acc: 0.9207  (best train acc: 0.8262, best val acc: 0.9224, best train loss: 0.4414)
# [Epoch: 5760] train loss: 0.4720, train acc: 0.8073, val loss: 0.2482, val acc: 0.9160  (best train acc: 0.8262, best val acc: 0.9224, best train loss: 0.4414)
# [Epoch: 5780] train loss: 0.4476, train acc: 0.8188, val loss: 0.2396, val acc: 0.9214  (best train acc: 0.8262, best val acc: 0.9228, best train loss: 0.4414)
# [Epoch: 5800] train loss: 0.4750, train acc: 0.8080, val loss: 0.2421, val acc: 0.9187  (best train acc: 0.8262, best val acc: 0.9228, best train loss: 0.4414)
# [Epoch: 5820] train loss: 0.4759, train acc: 0.8016, val loss: 0.2713, val acc: 0.9083  (best train acc: 0.8262, best val acc: 0.9228, best train loss: 0.4414)
# [Epoch: 5840] train loss: 0.4637, train acc: 0.8148, val loss: 0.2480, val acc: 0.9174  (best train acc: 0.8262, best val acc: 0.9228, best train loss: 0.4414)
# [Epoch: 5860] train loss: 0.4641, train acc: 0.8142, val loss: 0.2467, val acc: 0.9197  (best train acc: 0.8301, best val acc: 0.9234, best train loss: 0.4414)
# [Epoch: 5880] train loss: 0.4815, train acc: 0.8070, val loss: 0.2708, val acc: 0.8995  (best train acc: 0.8301, best val acc: 0.9234, best train loss: 0.4414)
# [Epoch: 5900] train loss: 0.4708, train acc: 0.8084, val loss: 0.2421, val acc: 0.9204  (best train acc: 0.8301, best val acc: 0.9234, best train loss: 0.4414)
# [Epoch: 5920] train loss: 0.4460, train acc: 0.8211, val loss: 0.2448, val acc: 0.9234  (best train acc: 0.8301, best val acc: 0.9234, best train loss: 0.4414)
# [Epoch: 5940] train loss: 0.4622, train acc: 0.8151, val loss: 0.2519, val acc: 0.9197  (best train acc: 0.8301, best val acc: 0.9234, best train loss: 0.4414)
# [Epoch: 5960] train loss: 0.4449, train acc: 0.8221, val loss: 0.2430, val acc: 0.9218  (best train acc: 0.8301, best val acc: 0.9234, best train loss: 0.4414)
# ...
# [Epoch: 48100] train loss: 0.1997, train acc: 0.9253, val loss: 0.3081, val acc: 0.9346  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48120] train loss: 0.2168, train acc: 0.9145, val loss: 0.3145, val acc: 0.9373  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48140] train loss: 0.2100, train acc: 0.9187, val loss: 0.3289, val acc: 0.9339  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48160] train loss: 0.2038, train acc: 0.9258, val loss: 0.2971, val acc: 0.9363  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48180] train loss: 0.2033, train acc: 0.9238, val loss: 0.3092, val acc: 0.9258  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48200] train loss: 0.2034, train acc: 0.9219, val loss: 0.3202, val acc: 0.9305  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48220] train loss: 0.1976, train acc: 0.9237, val loss: 0.3130, val acc: 0.9356  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48240] train loss: 0.1922, train acc: 0.9248, val loss: 0.3268, val acc: 0.9359  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48260] train loss: 0.2027, train acc: 0.9211, val loss: 0.3112, val acc: 0.9315  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48280] train loss: 0.2082, train acc: 0.9185, val loss: 0.3268, val acc: 0.9342  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48300] train loss: 0.2015, train acc: 0.9256, val loss: 0.3174, val acc: 0.9255  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48320] train loss: 0.2204, train acc: 0.9169, val loss: 0.3050, val acc: 0.9315  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48340] train loss: 0.2073, train acc: 0.9231, val loss: 0.2332, val acc: 0.9346  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48360] train loss: 0.2037, train acc: 0.9221, val loss: 0.2693, val acc: 0.9363  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48380] train loss: 0.2133, train acc: 0.9124, val loss: 0.2819, val acc: 0.9352  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48400] train loss: 0.2040, train acc: 0.9213, val loss: 0.3088, val acc: 0.9359  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48420] train loss: 0.2114, train acc: 0.9199, val loss: 0.3125, val acc: 0.9369  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48440] train loss: 0.2100, train acc: 0.9182, val loss: 0.3084, val acc: 0.9332  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48460] train loss: 0.2006, train acc: 0.9255, val loss: 0.3088, val acc: 0.9349  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48480] train loss: 0.2095, train acc: 0.9175, val loss: 0.3246, val acc: 0.9356  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48500] train loss: 0.2016, train acc: 0.9216, val loss: 0.3251, val acc: 0.9363  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48520] train loss: 0.2094, train acc: 0.9222, val loss: 0.3148, val acc: 0.9278  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48540] train loss: 0.2142, train acc: 0.9213, val loss: 0.3101, val acc: 0.9268  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48560] train loss: 0.2091, train acc: 0.9221, val loss: 0.3169, val acc: 0.9339  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48580] train loss: 0.2338, train acc: 0.9065, val loss: 0.3243, val acc: 0.9346  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48600] train loss: 0.2179, train acc: 0.9132, val loss: 0.3139, val acc: 0.9366  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48620] train loss: 0.2091, train acc: 0.9192, val loss: 0.3385, val acc: 0.9312  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48640] train loss: 0.2524, train acc: 0.9036, val loss: 0.3088, val acc: 0.9278  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48660] train loss: 0.2212, train acc: 0.9115, val loss: 0.2894, val acc: 0.9363  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48680] train loss: 0.1981, train acc: 0.9242, val loss: 0.2911, val acc: 0.9359  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48700] train loss: 0.1918, train acc: 0.9260, val loss: 0.3060, val acc: 0.9346  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48720] train loss: 0.1971, train acc: 0.9257, val loss: 0.3156, val acc: 0.9315  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48740] train loss: 0.1957, train acc: 0.9250, val loss: 0.3188, val acc: 0.9349  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48760] train loss: 0.2098, train acc: 0.9182, val loss: 0.3271, val acc: 0.9342  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48780] train loss: 0.2008, train acc: 0.9223, val loss: 0.3385, val acc: 0.9352  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48800] train loss: 0.2006, train acc: 0.9241, val loss: 0.2970, val acc: 0.9319  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48820] train loss: 0.1925, train acc: 0.9280, val loss: 0.2766, val acc: 0.9329  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48840] train loss: 0.2039, train acc: 0.9210, val loss: 0.2869, val acc: 0.9346  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48860] train loss: 0.1967, train acc: 0.9237, val loss: 0.3260, val acc: 0.9373  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48880] train loss: 0.1982, train acc: 0.9258, val loss: 0.2935, val acc: 0.9356  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48900] train loss: 0.2020, train acc: 0.9258, val loss: 0.2657, val acc: 0.9352  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48920] train loss: 0.2238, train acc: 0.9130, val loss: 0.2735, val acc: 0.9315  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48940] train loss: 0.2026, train acc: 0.9203, val loss: 0.2951, val acc: 0.9315  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48960] train loss: 0.2018, train acc: 0.9233, val loss: 0.3117, val acc: 0.9315  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 48980] train loss: 0.2132, train acc: 0.9154, val loss: 0.3144, val acc: 0.9363  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49000] train loss: 0.2005, train acc: 0.9265, val loss: 0.3117, val acc: 0.9292  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49020] train loss: 0.2018, train acc: 0.9231, val loss: 0.3116, val acc: 0.9315  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49040] train loss: 0.2044, train acc: 0.9254, val loss: 0.3284, val acc: 0.9376  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49060] train loss: 0.2461, train acc: 0.9098, val loss: 0.3367, val acc: 0.9336  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49080] train loss: 0.2119, train acc: 0.9202, val loss: 0.2912, val acc: 0.9339  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49100] train loss: 0.1949, train acc: 0.9245, val loss: 0.3132, val acc: 0.9359  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49120] train loss: 0.2163, train acc: 0.9135, val loss: 0.3100, val acc: 0.9363  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49140] train loss: 0.2137, train acc: 0.9173, val loss: 0.3231, val acc: 0.9379  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49160] train loss: 0.2018, train acc: 0.9225, val loss: 0.3114, val acc: 0.9369  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49180] train loss: 0.1914, train acc: 0.9269, val loss: 0.3150, val acc: 0.9359  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49200] train loss: 0.2069, train acc: 0.9184, val loss: 0.3161, val acc: 0.9282  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49220] train loss: 0.2056, train acc: 0.9183, val loss: 0.3206, val acc: 0.9336  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49240] train loss: 0.2134, train acc: 0.9191, val loss: 0.3104, val acc: 0.9288  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49260] train loss: 0.2046, train acc: 0.9199, val loss: 0.3218, val acc: 0.9342  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49280] train loss: 0.1952, train acc: 0.9231, val loss: 0.3311, val acc: 0.9352  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49300] train loss: 0.1945, train acc: 0.9258, val loss: 0.3264, val acc: 0.9369  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49320] train loss: 0.2069, train acc: 0.9226, val loss: 0.3265, val acc: 0.9302  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49340] train loss: 0.2088, train acc: 0.9179, val loss: 0.3148, val acc: 0.9383  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49360] train loss: 0.2084, train acc: 0.9176, val loss: 0.3243, val acc: 0.9352  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49380] train loss: 0.2016, train acc: 0.9229, val loss: 0.3131, val acc: 0.9298  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49400] train loss: 0.2154, train acc: 0.9144, val loss: 0.2918, val acc: 0.9342  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49420] train loss: 0.2033, train acc: 0.9216, val loss: 0.2762, val acc: 0.9366  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49440] train loss: 0.1971, train acc: 0.9262, val loss: 0.3012, val acc: 0.9356  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49460] train loss: 0.2101, train acc: 0.9171, val loss: 0.3223, val acc: 0.9319  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49480] train loss: 0.2002, train acc: 0.9240, val loss: 0.3478, val acc: 0.9356  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49500] train loss: 0.2641, train acc: 0.9104, val loss: 0.3274, val acc: 0.9140  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49520] train loss: 0.2252, train acc: 0.9142, val loss: 0.2719, val acc: 0.9251  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49540] train loss: 0.2224, train acc: 0.9170, val loss: 0.2829, val acc: 0.9312  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49560] train loss: 0.2023, train acc: 0.9229, val loss: 0.3113, val acc: 0.9275  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49580] train loss: 0.2054, train acc: 0.9232, val loss: 0.2957, val acc: 0.9329  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49600] train loss: 0.1948, train acc: 0.9248, val loss: 0.3069, val acc: 0.9322  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49620] train loss: 0.2013, train acc: 0.9225, val loss: 0.3234, val acc: 0.9373  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49640] train loss: 0.2117, train acc: 0.9202, val loss: 0.3121, val acc: 0.9356  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49660] train loss: 0.1982, train acc: 0.9252, val loss: 0.3206, val acc: 0.9298  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49680] train loss: 0.2044, train acc: 0.9243, val loss: 0.3525, val acc: 0.9315  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49700] train loss: 0.2162, train acc: 0.9144, val loss: 0.3100, val acc: 0.9356  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49720] train loss: 0.2377, train acc: 0.9063, val loss: 0.3535, val acc: 0.9336  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49740] train loss: 0.2051, train acc: 0.9239, val loss: 0.2650, val acc: 0.9339  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49760] train loss: 0.1965, train acc: 0.9239, val loss: 0.2958, val acc: 0.9366  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49780] train loss: 0.2055, train acc: 0.9179, val loss: 0.3019, val acc: 0.9356  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49800] train loss: 0.2044, train acc: 0.9203, val loss: 0.3133, val acc: 0.9329  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49820] train loss: 0.2037, train acc: 0.9229, val loss: 0.3131, val acc: 0.9376  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49840] train loss: 0.2155, train acc: 0.9203, val loss: 0.3087, val acc: 0.9228  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49860] train loss: 0.2168, train acc: 0.9158, val loss: 0.2659, val acc: 0.9258  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49880] train loss: 0.2033, train acc: 0.9235, val loss: 0.2778, val acc: 0.9346  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49900] train loss: 0.2172, train acc: 0.9127, val loss: 0.3011, val acc: 0.9352  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49920] train loss: 0.2158, train acc: 0.9177, val loss: 0.2991, val acc: 0.9315  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49940] train loss: 0.1991, train acc: 0.9256, val loss: 0.3195, val acc: 0.9315  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49960] train loss: 0.2056, train acc: 0.9211, val loss: 0.3161, val acc: 0.9369  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 49980] train loss: 0.2018, train acc: 0.9219, val loss: 0.2993, val acc: 0.9305  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
# [Epoch: 50000] train loss: 0.2107, train acc: 0.9183, val loss: 0.3066, val acc: 0.9356  (best train acc: 0.9310, best val acc: 0.9403, best train loss: 0.1833)
#               precision    recall  f1-score   support
#
#            0       0.95      0.40      0.57       154
#            1       0.92      0.98      0.95       703
#            2       0.91      0.92      0.92       702
#            3       0.92      0.95      0.93       703
#            4       0.99      1.00      0.99       702
#
#     accuracy                           0.93      2964
#    macro avg       0.94      0.85      0.87      2964
# weighted avg       0.94      0.93      0.93      2964

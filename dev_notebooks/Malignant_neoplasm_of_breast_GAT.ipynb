# %% [markdown]
# ## Import packets

# %%
import random
import numpy as np
import pandas as pd
import seaborn as sn
import networkx as nx
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv
from torch_geometric.utils import from_networkx
from torch_geometric.data import InMemoryDataset

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ## GNN(s)

# %%
class GNN2L_GAT (nn.Module):
    def __init__(self, data):
        super().__init__()
        self.conv1 = GATv2Conv(data.num_features, 16, dropout=0.3)
        self.conv2 = GATv2Conv(16, int(data.num_classes))

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)

        return F.log_softmax(x, dim=1)

class GNN4L_GAT (nn.Module):
    def __init__(self, data):
        super().__init__()
        self.conv1 = GATv2Conv(data.num_features, 16)
        self.conv2 = GATv2Conv(16, 16)
        self.conv3 = GATv2Conv(16, 16)
        self.conv4 = GATv2Conv(16, int(data.num_classes), dropout=0.3)
    
    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        x = self.conv4(x, edge_index)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# ## Dataset loader

# %%
# Dataset class: it allows to translate a vector (Graph, Attributes, Labels)
# into a dataset compatible with the PyTorch models.
# 
# Parameters:
# - G: NetworkX graph
# - Labels: of the nodes used for classification
# - attributes: List of the nodes' attributes

class MyDataset(InMemoryDataset):
  def __init__(self, G, labels, attributes = None, num_classes = 2, balance = False, debug = False):
    super(MyDataset, self).__init__('.', None, None, None)

    # import data from the networkx graph with the attributes of the nodes
    data = from_networkx(G, attributes)
      
    y = torch.from_numpy(labels).type(torch.long)

    data.x = data.x.float()
    data.y = y.clone().detach()
    data.num_classes = num_classes

    # Using train_test_split function from sklearn to stratify train/test/val sets
    indices = range(G.number_of_nodes())
    # Stratified split of train/test/val sets. Returned indices are used to create the masks
    X_train, X_test, y_train, y_test, train_idx, test_idx = train_test_split(data.x, data.y, indices, test_size=0.3, stratify=labels)
    # To create validation set, test set is splitted in half
    X_test, X_val, y_test, y_val, test_idx, val_idx = train_test_split(X_test, y_test, test_idx, test_size=0.5, stratify=y_test)

    n_nodes = G.number_of_nodes()
    train_mask  = torch.zeros(n_nodes, dtype=torch.bool)
    test_mask   = torch.zeros(n_nodes, dtype=torch.bool)
    val_mask    = torch.zeros(n_nodes, dtype=torch.bool)

    dataframe = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_features.csv')
    dataframe = dict(zip(dataframe['name'], dataframe['class']))
    nodes_list = list(G.nodes)

    if not balance:
      for idx in train_idx:
        train_mask[idx] = True

      for idx in test_idx:
        test_mask[idx] = True
      
      for idx in val_idx:
        val_mask[idx] = True
    else:
      # BALANCING THE TRAINING DATASET
      # count the positive/negative nodes in the training mask
      positive_nodes_in_train = 0
      negative_nodes_in_train = 0
      for idx in train_idx:
        if dataframe[nodes_list[idx]]:
          positive_nodes_in_train += 1
        else:
          negative_nodes_in_train += 1
      
      positive_nodes_in_test = 0
      negative_nodes_in_test = 0
      for idx in test_idx:
        if dataframe[nodes_list[idx]]:
          positive_nodes_in_test += 1
        else:
          negative_nodes_in_test += 1
      
      positive_nodes_in_val = 0
      negative_nodes_in_val = 0
      for idx in val_idx:
        if dataframe[nodes_list[idx]]:
          positive_nodes_in_val += 1
        else:
          negative_nodes_in_val += 1

      # not adding the first (#negative - #positive) negative samples
      n_unbalanced_samples_train = negative_nodes_in_train - positive_nodes_in_train
      c = 0

      for idx in train_idx:
        if dataframe[nodes_list[idx]]:
          train_mask[idx] = True
        else:
          # add to train mask after n_unbalanced_samples_train skipped
          if c >= n_unbalanced_samples_train:
            train_mask[idx] = True
          c += 1
      
      n_unbalanced_samples_test = negative_nodes_in_test - positive_nodes_in_test
      c = 0

      for idx in test_idx:
        if dataframe[nodes_list[idx]]:
          test_mask[idx] = True
        else:
          # add to test mask after n_unbalanced_samples_test skipped
          if c >= n_unbalanced_samples_test:
            test_mask[idx] = True
          c += 1
      
      n_unbalanced_samples_val = negative_nodes_in_val - positive_nodes_in_val
      c = 0

      for idx in val_idx:
        if dataframe[nodes_list[idx]]:
          val_mask[idx] = True
        else:
          # add to val mask after n_unbalanced_samples_val skipped
          if c >= n_unbalanced_samples_val:
            val_mask[idx] = True
          c += 1
    
    # --- for debug purposes ---
    if debug:

      print('len train_idx:', len(train_idx))
      print('len test_idx:', len(test_idx))
      print('len val_idx:', len(val_idx))

      pos = 0
      neg = 0
      # let's see if the mask is now balanced
      for idx in train_idx:
        # if the idx has been added to the training mask
        if train_mask[idx]:
          if dataframe[nodes_list[idx]]:
            pos += 1
          else:
            neg += 1
      
      print('pos/neg in train mask:', pos, neg)
    
      pos = 0
      neg = 0
      # let's see if the mask is now balanced
      for idx in test_idx:
        # if the idx has been added to the testing mask
        if test_mask[idx]:
          if dataframe[nodes_list[idx]]:
            pos += 1
          else:
            neg += 1
      
      print('pos/neg in test mask:', pos, neg)

      pos = 0
      neg = 0
      # let's see if the mask is now balanced
      for idx in val_idx:
        # if the idx has been added to the validating mask
        if val_mask[idx]:
          if dataframe[nodes_list[idx]]:
            pos += 1
          else:
            neg += 1
      
      print('pos/neg in val mask:', pos, neg)

    data['train_mask']  = train_mask
    data['test_mask']   = test_mask
    data['val_mask']    = val_mask

    self.data, self.slices = self.collate([data])

# %% [markdown]
# ## Training Function

# %%
def train(model, data, epochs = 200, classes = ['0','1'], lr = 0.001, cm_title = 'GNN'):
    optimizer = torch.optim.Adam(model.parameters(), lr = lr)

    train_mask  = data['train_mask']
    test_mask   = data['test_mask']
    val_mask    = data['val_mask']

    labels    = data.y
    output = ''

    # list to plot the train accuracy
    train_acc_curve = []
    train_lss_curve = []

    best_train_acc  = 0
    best_val_acc    = 0
    best_test_acc   = 0

    for e in tqdm(range(epochs)):
        model.train()
        optimizer.zero_grad()
        logits      = model(data)
        output      = logits.argmax(1)
        # train_loss  = F.cross_entropy(logits[train_mask], labels[train_mask])
        train_loss  = F.nll_loss(logits[train_mask], labels[train_mask])
        train_acc   = (output[train_mask] == labels[train_mask]).float().mean()
        train_loss.backward()
        optimizer.step()

        # Append train acc. to plot curve later
        train_acc_curve.append(train_acc.item())
        train_lss_curve.append(train_loss.item())

        if train_acc > best_train_acc:
            best_train_acc = train_acc

        # Evaluation and test
        model.eval()
        logits      = model(data)
        output      = logits.argmax(1)
        # val_loss    = F.cross_entropy(logits[val_mask], labels[val_mask])
        val_loss    = F.nll_loss(logits[val_mask], labels[val_mask])
        val_acc     = (output[val_mask] == labels[val_mask]).float().mean()
        test_acc    = (output[test_mask] == labels[test_mask]).float().mean()

        # Update best test/val acc.
        if val_acc > best_val_acc:
            best_val_acc = val_acc
        
        if test_acc > best_test_acc:
            best_test_acc = test_acc

        if e % 20 == 0 or e == epochs:
            print('[Epoch: {:04d}]'.format(e),
            'train loss: {:.4f},'.format(train_loss.item()),
            'train acc: {:.4f},'.format(train_acc.item()),
            'test acc: {:.4f},'.format(test_acc.item()),
            'val loss: {:.4f},'.format(val_loss.item()),
            'val acc: {:.4f} '.format(val_acc.item()),
            '(best train acc: {:.4f},'.format(best_train_acc.item()),
            'best val acc: {:.4f},'.format(best_val_acc.item()),
            'best test acc: {:.4f})'.format(best_test_acc.item()))
    
    # Plot training accuracy curve
    plt.figure(figsize = (12,7))
    plt.plot(train_acc_curve)
    plt.xlabel('Epoch')
    plt.ylabel('Train Accuracy')
    plt.show()

    # Plot training loss curve
    plt.figure(figsize = (12,7))
    plt.plot(train_lss_curve)
    plt.xlabel('Epoch')
    plt.ylabel('Train Loss')
    plt.show()

    print(classification_report(labels[test_mask].to('cpu'), output[test_mask].to('cpu')))

    # # Plot the confusion matrix
    # cf_matrix = confusion_matrix(labels[test_mask], output[test_mask])
    
    # df_cm = pd.DataFrame(cf_matrix, index = [i for i in classes],
    #                         columns = [i for i in classes])
    # plt.figure(figsize = (12,7))
    # sn.heatmap(df_cm, annot=True)
    # plt.show()

    #Confusion Matrix
    norms = [None, "true"]
    for norm in norms:
        cm = confusion_matrix(labels[test_mask].to('cpu'), output[test_mask].to('cpu'), normalize=norm)

        plt.figure(figsize=(7,7))
        
        if norm == "true":
            sn.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'BuPu', xticklabels = classes, yticklabels = classes)
        else:
            sn.heatmap(cm, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'BuPu', xticklabels = classes, yticklabels = classes)
        plt.title(cm_title)
        plt.ylabel('Actual label')
        plt.xlabel('Predicted label')

    return output

# %% [markdown]
# ## Centrality Measures

# %%
G = nx.read_gml('Graphs/graph_with_normalized_centrality.gml')

class_dataframe = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_features.csv')
class_dataframe = dict(zip(class_dataframe['name'], class_dataframe['class']))

labels = []

for node in G:
    labels.append(class_dataframe[node])

labels = np.asarray(labels)

plt.hist(labels)
plt.show()

# %%
attributes = ['degree', 'betweenness', 'eigenvector', 'closeness']

dataset_with_norm_centrality = MyDataset(G, labels, attributes, balance=True ,debug=True)
data_with_norm_centrality = dataset_with_norm_centrality[0]
# Out:
# len train_idx: 13832
# len test_idx: 2964
# len val_idx: 2965
# pos/neg in train mask: 717 717
# pos/neg in test mask: 154 154
# pos/neg in val mask: 154 154

# %% [markdown]
# ### 2 Layers

# %%
gnn2l = GNN2L_GAT(data_with_norm_centrality).to(device)
pred = train(gnn2l, data_with_norm_centrality.to(device), 200, cm_title='GAT2L, balanced, 16HC')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# [Epoch: 0000] train loss: 0.6934, train acc: 0.5000, test acc: 0.5000, val loss: 0.6932, val acc: 0.5000  (best train acc: 0.5000, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0020] train loss: 0.6930, train acc: 0.5244, test acc: 0.5000, val loss: 0.6931, val acc: 0.5000  (best train acc: 0.5377, best val acc: 0.5682, best test acc: 0.5584)
# [Epoch: 0040] train loss: 0.6931, train acc: 0.5195, test acc: 0.5065, val loss: 0.6930, val acc: 0.5000  (best train acc: 0.5509, best val acc: 0.5682, best test acc: 0.5747)
# [Epoch: 0060] train loss: 0.6929, train acc: 0.5377, test acc: 0.5390, val loss: 0.6930, val acc: 0.5519  (best train acc: 0.5676, best val acc: 0.5909, best test acc: 0.5747)
# [Epoch: 0080] train loss: 0.6929, train acc: 0.5446, test acc: 0.5357, val loss: 0.6930, val acc: 0.5325  (best train acc: 0.5816, best val acc: 0.5942, best test acc: 0.5747)
# [Epoch: 0100] train loss: 0.6928, train acc: 0.5718, test acc: 0.5390, val loss: 0.6929, val acc: 0.5519  (best train acc: 0.5893, best val acc: 0.5974, best test acc: 0.5747)
# [Epoch: 0120] train loss: 0.6927, train acc: 0.5767, test acc: 0.5390, val loss: 0.6929, val acc: 0.5779  (best train acc: 0.5893, best val acc: 0.5974, best test acc: 0.5747)
# [Epoch: 0140] train loss: 0.6926, train acc: 0.5565, test acc: 0.5422, val loss: 0.6928, val acc: 0.5714  (best train acc: 0.5893, best val acc: 0.5974, best test acc: 0.5747)
# [Epoch: 0160] train loss: 0.6925, train acc: 0.5621, test acc: 0.5390, val loss: 0.6928, val acc: 0.5747  (best train acc: 0.5893, best val acc: 0.5974, best test acc: 0.5747)
# [Epoch: 0180] train loss: 0.6924, train acc: 0.5502, test acc: 0.5487, val loss: 0.6927, val acc: 0.5357  (best train acc: 0.5893, best val acc: 0.5974, best test acc: 0.5747)
#               precision    recall  f1-score   support
#
#            0       0.54      0.50      0.52       154
#            1       0.54      0.58      0.56       154
#
#     accuracy                           0.54       308
#    macro avg       0.54      0.54      0.54       308
# weighted avg       0.54      0.54      0.54       308

# %% [markdown]
# ### 4 Layers

# %%
gnn4l = GNN4L_GAT(data_with_norm_centrality).to(device)
pred = train(gnn4l, data_with_norm_centrality.to(device), 200, cm_title='GAT4L, balanced, 16HC')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# [Epoch: 0000] train loss: 0.7649, train acc: 0.5000, test acc: 0.5000, val loss: 0.7572, val acc: 0.5000  (best train acc: 0.5000, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0020] train loss: 0.6941, train acc: 0.4944, test acc: 0.5000, val loss: 0.6937, val acc: 0.5000  (best train acc: 0.5000, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0040] train loss: 0.6939, train acc: 0.5000, test acc: 0.5000, val loss: 0.6938, val acc: 0.5000  (best train acc: 0.5488, best val acc: 0.5065, best test acc: 0.5032)
# [Epoch: 0060] train loss: 0.6933, train acc: 0.4770, test acc: 0.5000, val loss: 0.6931, val acc: 0.5000  (best train acc: 0.5488, best val acc: 0.5065, best test acc: 0.5032)
# [Epoch: 0080] train loss: 0.6932, train acc: 0.4686, test acc: 0.5000, val loss: 0.6931, val acc: 0.5000  (best train acc: 0.5488, best val acc: 0.5065, best test acc: 0.5032)
# [Epoch: 0100] train loss: 0.6931, train acc: 0.5377, test acc: 0.5032, val loss: 0.6931, val acc: 0.5065  (best train acc: 0.5488, best val acc: 0.5260, best test acc: 0.5162)
# [Epoch: 0120] train loss: 0.6933, train acc: 0.5223, test acc: 0.5000, val loss: 0.6931, val acc: 0.5000  (best train acc: 0.5488, best val acc: 0.5260, best test acc: 0.5227)
# [Epoch: 0140] train loss: 0.6933, train acc: 0.5286, test acc: 0.5000, val loss: 0.6931, val acc: 0.5000  (best train acc: 0.5488, best val acc: 0.5260, best test acc: 0.5227)
# [Epoch: 0160] train loss: 0.6931, train acc: 0.5202, test acc: 0.5195, val loss: 0.6931, val acc: 0.5130  (best train acc: 0.5530, best val acc: 0.5260, best test acc: 0.5227)
# [Epoch: 0180] train loss: 0.6931, train acc: 0.5272, test acc: 0.5065, val loss: 0.6931, val acc: 0.5162  (best train acc: 0.5530, best val acc: 0.5260, best test acc: 0.5227)
#               precision    recall  f1-score   support
#
#            0       1.00      0.03      0.06       154
#            1       0.51      1.00      0.67       154
#
#     accuracy                           0.52       308
#    macro avg       0.75      0.52      0.37       308
# weighted avg       0.75      0.52      0.37       308

# %% [markdown]
# ## NeDBIT Features

# %%
attributes = ['degree', 'ring', 'NetRank', 'NetShort', 'HeatDiff', 'InfoDiff']

G_nb = nx.read_gml('Graphs/graph_with_nedbit.gml')

# Take the labels from the class column of the features' file
class_dataframe = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_features.csv')
class_dataframe = dict(zip(class_dataframe['name'], class_dataframe['class']))

labels = []

for node in G_nb:
    labels.append(class_dataframe[node])

labels = np.asarray(labels)

# %%
dataset_with_nedbit = MyDataset(G_nb, labels, attributes, balance = True, debug=True)
data_with_nedbit = dataset_with_nedbit[0]

plt.hist(labels)
plt.show()
# Out:
# len train_idx: 13832
# len test_idx: 2964
# len val_idx: 2965
# pos/neg in train mask: 717 717
# pos/neg in test mask: 154 154
# pos/neg in val mask: 154 154

# %%
# Statistiche da commentare
nx.radius(G)
# Out:
# 4

# %%
# Statistiche da commentare
nx.diameter(G)
# Out:
# 7

# %% [markdown]
# ### 2 Layer

# %%
gnn2l_gat = GNN2L_GAT(data_with_nedbit).to(device)
pred = train(gnn2l_gat, data_with_nedbit.to(device), 200, cm_title='GAT2L, balanced, 16HC')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# [Epoch: 0000] train loss: 2.8194, train acc: 0.4986, test acc: 0.5000, val loss: 3.1024, val acc: 0.5000  (best train acc: 0.4986, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0020] train loss: 1.5158, train acc: 0.5007, test acc: 0.5000, val loss: 1.7013, val acc: 0.5000  (best train acc: 0.5014, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0040] train loss: 0.8724, train acc: 0.5007, test acc: 0.5000, val loss: 0.8822, val acc: 0.5000  (best train acc: 0.5028, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0060] train loss: 0.6992, train acc: 0.5056, test acc: 0.5000, val loss: 0.7005, val acc: 0.5000  (best train acc: 0.5418, best val acc: 0.5227, best test acc: 0.5130)
# [Epoch: 0080] train loss: 0.6907, train acc: 0.4784, test acc: 0.4968, val loss: 0.6895, val acc: 0.5000  (best train acc: 0.5418, best val acc: 0.5487, best test acc: 0.5422)
# [Epoch: 0100] train loss: 0.6899, train acc: 0.4972, test acc: 0.4968, val loss: 0.6886, val acc: 0.5000  (best train acc: 0.5418, best val acc: 0.5487, best test acc: 0.5422)
# [Epoch: 0120] train loss: 0.6906, train acc: 0.4805, test acc: 0.4968, val loss: 0.6875, val acc: 0.4870  (best train acc: 0.5418, best val acc: 0.5487, best test acc: 0.5422)
# [Epoch: 0140] train loss: 0.6897, train acc: 0.4791, test acc: 0.5032, val loss: 0.6864, val acc: 0.4903  (best train acc: 0.5418, best val acc: 0.5487, best test acc: 0.5422)
# [Epoch: 0160] train loss: 0.6882, train acc: 0.4770, test acc: 0.4935, val loss: 0.6853, val acc: 0.4870  (best train acc: 0.5418, best val acc: 0.5487, best test acc: 0.5422)
# [Epoch: 0180] train loss: 0.6870, train acc: 0.5007, test acc: 0.5032, val loss: 0.6842, val acc: 0.4903  (best train acc: 0.5418, best val acc: 0.5487, best test acc: 0.5422)
#               precision    recall  f1-score   support
#
#            0       0.48      0.79      0.60       154
#            1       0.42      0.15      0.22       154
#
#     accuracy                           0.47       308
#    macro avg       0.45      0.47      0.41       308
# weighted avg       0.45      0.47      0.41       308

# %% [markdown]
# ### 4 Layers

# %%
gnn4l_gat = GNN4L_GAT(data_with_nedbit).to(device)
pred = train(gnn4l_gat, data_with_nedbit.to(device), 200, cm_title='GAT4L, balanced, 16HC')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# [Epoch: 0000] train loss: 2134.0527, train acc: 0.4930, test acc: 0.5000, val loss: 2100.6340, val acc: 0.5000  (best train acc: 0.4930, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0020] train loss: 749.7729, train acc: 0.5105, test acc: 0.5000, val loss: 759.0065, val acc: 0.5000  (best train acc: 0.5244, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0040] train loss: 22.5293, train acc: 0.5000, test acc: 0.5000, val loss: 25.9298, val acc: 0.5000  (best train acc: 0.5244, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0060] train loss: 41.3649, train acc: 0.5000, test acc: 0.5000, val loss: 35.8721, val acc: 0.5000  (best train acc: 0.5244, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0080] train loss: 12.3256, train acc: 0.5000, test acc: 0.5000, val loss: 10.4174, val acc: 0.5000  (best train acc: 0.5244, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0100] train loss: 1.5261, train acc: 0.4819, test acc: 0.5000, val loss: 1.2294, val acc: 0.5000  (best train acc: 0.5244, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0120] train loss: 0.7160, train acc: 0.4603, test acc: 0.4805, val loss: 0.7354, val acc: 0.4643  (best train acc: 0.5244, best val acc: 0.5097, best test acc: 0.5032)
# [Epoch: 0140] train loss: 0.7261, train acc: 0.5028, test acc: 0.5000, val loss: 0.7226, val acc: 0.5032  (best train acc: 0.5244, best val acc: 0.5097, best test acc: 0.5162)
# [Epoch: 0160] train loss: 0.6924, train acc: 0.5363, test acc: 0.5260, val loss: 0.6959, val acc: 0.5130  (best train acc: 0.5363, best val acc: 0.5195, best test acc: 0.5260)
# [Epoch: 0180] train loss: 0.6929, train acc: 0.5286, test acc: 0.5227, val loss: 0.6962, val acc: 0.5065  (best train acc: 0.5363, best val acc: 0.5227, best test acc: 0.5292)
#               precision    recall  f1-score   support
#
#            0       0.66      0.18      0.28       154
#            1       0.52      0.91      0.67       154
#
#     accuracy                           0.54       308
#    macro avg       0.59      0.54      0.47       308
# weighted avg       0.59      0.54      0.47       308

# %% [markdown]
# ## NeDBIT Features w/ Score

# %%
attributes = ['degree', 'ring', 'NetRank', 'NetShort', 'HeatDiff', 'InfoDiff', 'score']

G_nbs = nx.read_gml('Graphs/graph_with_nedbit_score.gml')

# Take the labels from the class column of the features' file
class_dataframe = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_features.csv')
class_dataframe = dict(zip(class_dataframe['name'], class_dataframe['class']))

labels = []

for node in G_nbs:
    labels.append(class_dataframe[node])

labels = np.asarray(labels)

# %%
dataset_with_nedbit_score = MyDataset(G_nbs, labels, attributes, balance = True, debug=True)
data_with_nedbit_score = dataset_with_nedbit_score[0]

plt.hist(labels)
plt.show()
# Out:
# len train_idx: 13832
# len test_idx: 2964
# len val_idx: 2965
# pos/neg in train mask: 717 717
# pos/neg in test mask: 154 154
# pos/neg in val mask: 154 154

# %% [markdown]
# ### 2 Layers

# %%
gnn2l_gat = GNN2L_GAT(data_with_nedbit_score).to(device)
pred = train(gnn2l_gat, data_with_nedbit_score.to(device), 200, cm_title='GAT2L, balanced w/ scores, 16HC')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# [Epoch: 0000] train loss: 1.1820, train acc: 0.5000, test acc: 0.5000, val loss: 3.3919, val acc: 0.5000  (best train acc: 0.5000, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0020] train loss: 0.7419, train acc: 0.5370, test acc: 0.5097, val loss: 2.9903, val acc: 0.5032  (best train acc: 0.5453, best val acc: 0.5292, best test acc: 0.5162)
# [Epoch: 0040] train loss: 0.7232, train acc: 0.5293, test acc: 0.5162, val loss: 1.5674, val acc: 0.5130  (best train acc: 0.5453, best val acc: 0.5292, best test acc: 0.5162)
# [Epoch: 0060] train loss: 0.7054, train acc: 0.5286, test acc: 0.5130, val loss: 1.0325, val acc: 0.5097  (best train acc: 0.5453, best val acc: 0.5292, best test acc: 0.5195)
# [Epoch: 0080] train loss: 0.6963, train acc: 0.5119, test acc: 0.4643, val loss: 0.7617, val acc: 0.5000  (best train acc: 0.5453, best val acc: 0.5292, best test acc: 0.5195)
# [Epoch: 0100] train loss: 0.6915, train acc: 0.5377, test acc: 0.4708, val loss: 0.7198, val acc: 0.5097  (best train acc: 0.5453, best val acc: 0.5292, best test acc: 0.5195)
# [Epoch: 0120] train loss: 0.6880, train acc: 0.5502, test acc: 0.5000, val loss: 0.9577, val acc: 0.5000  (best train acc: 0.5607, best val acc: 0.5292, best test acc: 0.5195)
# [Epoch: 0140] train loss: 0.6897, train acc: 0.5565, test acc: 0.5000, val loss: 0.8931, val acc: 0.5000  (best train acc: 0.5649, best val acc: 0.5292, best test acc: 0.5195)
# [Epoch: 0160] train loss: 0.6881, train acc: 0.5718, test acc: 0.5000, val loss: 0.7364, val acc: 0.5000  (best train acc: 0.5718, best val acc: 0.5292, best test acc: 0.5195)
# [Epoch: 0180] train loss: 0.6836, train acc: 0.5614, test acc: 0.5000, val loss: 0.7613, val acc: 0.5000  (best train acc: 0.5739, best val acc: 0.5292, best test acc: 0.5195)
#               precision    recall  f1-score   support
#
#            0       0.50      0.89      0.64       154
#            1       0.51      0.12      0.19       154
#
#     accuracy                           0.50       308
#    macro avg       0.51      0.50      0.42       308
# weighted avg       0.51      0.50      0.42       308

# %% [markdown]
# ### 4 Layers

# %%
gnn4l_gat = GNN4L_GAT(data_with_nedbit_score).to(device)
pred = train(gnn4l_gat, data_with_nedbit_score.to(device), 200, cm_title='GAT4L, balanced w/ scores, 16HC')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# [Epoch: 0000] train loss: 0.7104, train acc: 0.5000, test acc: 0.5000, val loss: 0.7058, val acc: 0.5000  (best train acc: 0.5000, best val acc: 0.5000, best test acc: 0.5000)
# [Epoch: 0020] train loss: 0.6948, train acc: 0.4902, test acc: 0.5000, val loss: 0.6952, val acc: 0.4935  (best train acc: 0.5649, best val acc: 0.5617, best test acc: 0.5617)
# [Epoch: 0040] train loss: 0.6925, train acc: 0.4861, test acc: 0.4935, val loss: 0.6939, val acc: 0.4773  (best train acc: 0.5704, best val acc: 0.5779, best test acc: 0.5714)
# [Epoch: 0060] train loss: 0.6925, train acc: 0.5565, test acc: 0.5552, val loss: 0.6931, val acc: 0.4903  (best train acc: 0.5711, best val acc: 0.5779, best test acc: 0.5714)
# [Epoch: 0080] train loss: 0.6824, train acc: 0.5628, test acc: 0.5682, val loss: 0.6773, val acc: 0.5649  (best train acc: 0.5865, best val acc: 0.5779, best test acc: 0.5714)
# [Epoch: 0100] train loss: 0.6825, train acc: 0.5530, test acc: 0.5649, val loss: 0.6770, val acc: 0.5812  (best train acc: 0.5865, best val acc: 0.5812, best test acc: 0.5812)
# [Epoch: 0120] train loss: 0.6825, train acc: 0.5586, test acc: 0.5649, val loss: 0.6783, val acc: 0.5552  (best train acc: 0.5865, best val acc: 0.5877, best test acc: 0.5812)
# [Epoch: 0140] train loss: 0.6821, train acc: 0.5607, test acc: 0.5617, val loss: 0.6778, val acc: 0.5779  (best train acc: 0.5865, best val acc: 0.5877, best test acc: 0.5812)
# [Epoch: 0160] train loss: 0.6770, train acc: 0.5635, test acc: 0.5552, val loss: 0.6765, val acc: 0.5714  (best train acc: 0.5865, best val acc: 0.5877, best test acc: 0.5812)
# [Epoch: 0180] train loss: 0.6757, train acc: 0.5565, test acc: 0.5487, val loss: 0.6769, val acc: 0.5519  (best train acc: 0.5865, best val acc: 0.5877, best test acc: 0.5812)
#               precision    recall  f1-score   support
#
#            0       0.59      0.35      0.44       154
#            1       0.54      0.76      0.63       154
#
#     accuracy                           0.56       308
#    macro avg       0.57      0.56      0.54       308
# weighted avg       0.57      0.56      0.54       308

# %% [markdown]
# ## NeDBIT Multiclass

# %%
G = nx.read_gml('Graphs/graph_with_nedbit.gml')

# %%
seed_genes          = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_seed_genes.txt', header=None, sep=' ')
seed_genes.columns  = ["name", "GDA Score"]
seeds_list          = seed_genes["name"].values.tolist()

nedbit_scores = pd.read_csv('Datasets/C0006142_Malignant_neoplasm_of_breast_features_Score.csv')

# Remove seed genes
nedbit_scores_not_seed = nedbit_scores[~nedbit_scores['name'].isin(seeds_list)]
print(nedbit_scores_not_seed.shape)

# Sort scores for quartile division
nedbit_scores_not_seed = nedbit_scores_not_seed.sort_values(by = "out", ascending = False)
pseudo_labels = pd.qcut(x = nedbit_scores_not_seed["out"], q = 4, labels = ["RN", "LN", "WN", "LP"])

plt.hist(pseudo_labels)
plt.show()
# Out:
# (18736, 2)

# %%
nedbit_scores_not_seed['label'] = pseudo_labels

nedbit_scores_seed = nedbit_scores[nedbit_scores['name'].isin(seeds_list)]
nedbit_scores_seed['label'] = 'P'

# Convert dataframe to dict for searching nodes and their labels
not_seed_labels = dict(zip(nedbit_scores_not_seed['name'], nedbit_scores_not_seed['label']))
seed_labels     = dict(zip(nedbit_scores_seed['name'], nedbit_scores_seed['label']))

labels_dict = {'P':0, 'LP': 1, 'WN': 2, 'LN': 3, 'RN': 4}
labels = []

for node in G:
    if node in not_seed_labels:
        labels.append(labels_dict[not_seed_labels[node]])
    else:
        labels.append(labels_dict[seed_labels[node]])

labels = np.asarray(labels)
len(labels)
# Out:
# C:\Users\pmaur\AppData\Local\Temp\ipykernel_2464\1918763083.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nedbit_scores_seed['label'] = 'P'
# 19761

# %%
attributes = ['degree', 'ring', 'NetRank', 'NetShort', 'HeatDiff', 'InfoDiff']

dataset_with_nedbit = MyDataset(G, labels, attributes, num_classes=5, balance=False, debug=False)
data_with_nedbit = dataset_with_nedbit[0]

plt.hist(labels)
plt.show()

# %% [markdown]
# ### 2 Layers

# %%
gnn2l_gat = GNN2L_GAT(data_with_nedbit).to(device)
pred = train(gnn2l_gat, data_with_nedbit.to(device), 200, cm_title='GAT2L, multiclass, 16HC')
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# [Epoch: 0000] train loss: 23.9111, train acc: 0.2370, test acc: 0.2372, val loss: 19.7775, val acc: 0.2371  (best train acc: 0.2370, best val acc: 0.2371, best test acc: 0.2372)
# [Epoch: 0020] train loss: 17.3468, train acc: 0.2370, test acc: 0.2372, val loss: 14.2413, val acc: 0.2371  (best train acc: 0.2370, best val acc: 0.2371, best test acc: 0.2372)
# [Epoch: 0040] train loss: 12.1319, train acc: 0.2369, test acc: 0.2372, val loss: 9.3867, val acc: 0.2371  (best train acc: 0.2370, best val acc: 0.2371, best test acc: 0.2372)
# [Epoch: 0060] train loss: 2.8166, train acc: 0.2368, test acc: 0.2372, val loss: 2.7063, val acc: 0.2371  (best train acc: 0.2371, best val acc: 0.2371, best test acc: 0.2372)
# [Epoch: 0080] train loss: 2.1133, train acc: 0.2333, test acc: 0.2372, val loss: 2.2612, val acc: 0.2371  (best train acc: 0.2383, best val acc: 0.2371, best test acc: 0.2372)
# [Epoch: 0100] train loss: 2.0112, train acc: 0.2189, test acc: 0.2372, val loss: 2.1548, val acc: 0.2371  (best train acc: 0.2383, best val acc: 0.2371, best test acc: 0.2372)
# [Epoch: 0120] train loss: 1.9280, train acc: 0.1985, test acc: 0.2372, val loss: 2.0692, val acc: 0.2371  (best train acc: 0.2383, best val acc: 0.2371, best test acc: 0.2372)
# [Epoch: 0140] train loss: 1.8656, train acc: 0.1889, test acc: 0.2372, val loss: 1.9946, val acc: 0.2371  (best train acc: 0.2383, best val acc: 0.2371, best test acc: 0.2372)
# [Epoch: 0160] train loss: 1.7908, train acc: 0.1911, test acc: 0.2372, val loss: 1.9218, val acc: 0.2371  (best train acc: 0.2383, best val acc: 0.2371, best test acc: 0.2372)
# [Epoch: 0180] train loss: 1.7501, train acc: 0.2039, test acc: 0.2372, val loss: 1.8717, val acc: 0.2371  (best train acc: 0.2383, best val acc: 0.2371, best test acc: 0.2372)
# c:\Users\pmaur\miniconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\pmaur\miniconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\pmaur\miniconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       154
#            1       0.00      0.00      0.00       703
#            2       0.00      0.00      0.00       702
#            3       0.24      1.00      0.38       703
#            4       0.00      0.00      0.00       702
#
#     accuracy                           0.24      2964
#    macro avg       0.05      0.20      0.08      2964
# weighted avg       0.06      0.24      0.09      2964

# %% [markdown]
# ### 4 Layers

# %%
gnn4l_gat = GNN4L_GAT(data_with_nedbit).to(device)
pred = train(gnn4l_gat, data_with_nedbit.to(device), 2500, cm_title='GAT4L, multiclass, 16HC', classes=['P', 'LP', 'WN', 'LN', 'RN'])
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# [Epoch: 0000] train loss: 5.8440, train acc: 0.0518, test acc: 0.0520, val loss: 5.1691, val acc: 0.0519  (best train acc: 0.0518, best val acc: 0.0519, best test acc: 0.0520)
# [Epoch: 0020] train loss: 2.0366, train acc: 0.0526, test acc: 0.0520, val loss: 1.9924, val acc: 0.0519  (best train acc: 0.0532, best val acc: 0.0519, best test acc: 0.0520)
# [Epoch: 0040] train loss: 1.7023, train acc: 0.2306, test acc: 0.2368, val loss: 1.6925, val acc: 0.2371  (best train acc: 0.2306, best val acc: 0.2371, best test acc: 0.2368)
# [Epoch: 0060] train loss: 1.6102, train acc: 0.2282, test acc: 0.2365, val loss: 1.6050, val acc: 0.2371  (best train acc: 0.2316, best val acc: 0.2371, best test acc: 0.2368)
# [Epoch: 0080] train loss: 1.5699, train acc: 0.2642, test acc: 0.2655, val loss: 1.5668, val acc: 0.2678  (best train acc: 0.3055, best val acc: 0.3177, best test acc: 0.3188)
# [Epoch: 0100] train loss: 1.5468, train acc: 0.3081, test acc: 0.3198, val loss: 1.5441, val acc: 0.3191  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0120] train loss: 1.5350, train acc: 0.2144, test acc: 0.2335, val loss: 1.5323, val acc: 0.2341  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0140] train loss: 1.5263, train acc: 0.2147, test acc: 0.2335, val loss: 1.5246, val acc: 0.2341  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0160] train loss: 1.5222, train acc: 0.2060, test acc: 0.2314, val loss: 1.5202, val acc: 0.2317  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0180] train loss: 1.5198, train acc: 0.1981, test acc: 0.2308, val loss: 1.5178, val acc: 0.2300  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0200] train loss: 1.5189, train acc: 0.1935, test acc: 0.2237, val loss: 1.5166, val acc: 0.2209  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0220] train loss: 1.5181, train acc: 0.2108, test acc: 0.2065, val loss: 1.5158, val acc: 0.2105  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0240] train loss: 1.5175, train acc: 0.2334, test acc: 0.2581, val loss: 1.5154, val acc: 0.2513  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0260] train loss: 1.5175, train acc: 0.2487, test acc: 0.2621, val loss: 1.5151, val acc: 0.2614  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0280] train loss: 1.5178, train acc: 0.2593, test acc: 0.2635, val loss: 1.5148, val acc: 0.2634  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0300] train loss: 1.5173, train acc: 0.2656, test acc: 0.2655, val loss: 1.5145, val acc: 0.2664  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0320] train loss: 1.5168, train acc: 0.2728, test acc: 0.2655, val loss: 1.5142, val acc: 0.2705  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0340] train loss: 1.5171, train acc: 0.2570, test acc: 0.2686, val loss: 1.5138, val acc: 0.2691  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0360] train loss: 1.5163, train acc: 0.2887, test acc: 0.2952, val loss: 1.5135, val acc: 0.2927  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0380] train loss: 1.5153, train acc: 0.2863, test acc: 0.2972, val loss: 1.5131, val acc: 0.2924  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0400] train loss: 1.5157, train acc: 0.2943, test acc: 0.2999, val loss: 1.5127, val acc: 0.2961  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0420] train loss: 1.5156, train acc: 0.2997, test acc: 0.3070, val loss: 1.5123, val acc: 0.3032  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0440] train loss: 1.5136, train acc: 0.2950, test acc: 0.3047, val loss: 1.5119, val acc: 0.3002  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0460] train loss: 1.5138, train acc: 0.2960, test acc: 0.3097, val loss: 1.5114, val acc: 0.3008  (best train acc: 0.3081, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0480] train loss: 1.5130, train acc: 0.3057, test acc: 0.3080, val loss: 1.5109, val acc: 0.3130  (best train acc: 0.3098, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0500] train loss: 1.5129, train acc: 0.3023, test acc: 0.3057, val loss: 1.5103, val acc: 0.3126  (best train acc: 0.3098, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0520] train loss: 1.5124, train acc: 0.3028, test acc: 0.3111, val loss: 1.5096, val acc: 0.3140  (best train acc: 0.3098, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0540] train loss: 1.5116, train acc: 0.3052, test acc: 0.3111, val loss: 1.5089, val acc: 0.3164  (best train acc: 0.3098, best val acc: 0.3191, best test acc: 0.3198)
# [Epoch: 0560] train loss: 1.5113, train acc: 0.3048, test acc: 0.3107, val loss: 1.5079, val acc: 0.3204  (best train acc: 0.3116, best val acc: 0.3224, best test acc: 0.3198)
# [Epoch: 0580] train loss: 1.5107, train acc: 0.3049, test acc: 0.3158, val loss: 1.5067, val acc: 0.3150  (best train acc: 0.3116, best val acc: 0.3231, best test acc: 0.3198)
# [Epoch: 0600] train loss: 1.5089, train acc: 0.2974, test acc: 0.3286, val loss: 1.5049, val acc: 0.3272  (best train acc: 0.3116, best val acc: 0.3275, best test acc: 0.3286)
# [Epoch: 0620] train loss: 1.5048, train acc: 0.3034, test acc: 0.3235, val loss: 1.5010, val acc: 0.3197  (best train acc: 0.3116, best val acc: 0.3288, best test acc: 0.3310)
# [Epoch: 0640] train loss: 1.4679, train acc: 0.3289, test acc: 0.3455, val loss: 1.4487, val acc: 0.3440  (best train acc: 0.3289, best val acc: 0.3444, best test acc: 0.3482)
# [Epoch: 0660] train loss: 1.4424, train acc: 0.3509, test acc: 0.4190, val loss: 1.4254, val acc: 0.4179  (best train acc: 0.4152, best val acc: 0.4361, best test acc: 0.4372)
# [Epoch: 0680] train loss: 1.4299, train acc: 0.4109, test acc: 0.4268, val loss: 1.4108, val acc: 0.4253  (best train acc: 0.4152, best val acc: 0.4361, best test acc: 0.4372)
# [Epoch: 0700] train loss: 1.4244, train acc: 0.3916, test acc: 0.4140, val loss: 1.4039, val acc: 0.4185  (best train acc: 0.4160, best val acc: 0.4361, best test acc: 0.4372)
# [Epoch: 0720] train loss: 1.4188, train acc: 0.4088, test acc: 0.4271, val loss: 1.3997, val acc: 0.4236  (best train acc: 0.4160, best val acc: 0.4361, best test acc: 0.4372)
# [Epoch: 0740] train loss: 1.4155, train acc: 0.4091, test acc: 0.4170, val loss: 1.3959, val acc: 0.4189  (best train acc: 0.4160, best val acc: 0.4361, best test acc: 0.4372)
# [Epoch: 0760] train loss: 1.4129, train acc: 0.4027, test acc: 0.4109, val loss: 1.3927, val acc: 0.4196  (best train acc: 0.4160, best val acc: 0.4361, best test acc: 0.4379)
# [Epoch: 0780] train loss: 1.4147, train acc: 0.4008, test acc: 0.4325, val loss: 1.3898, val acc: 0.4354  (best train acc: 0.4200, best val acc: 0.4368, best test acc: 0.4383)
# [Epoch: 0800] train loss: 1.4087, train acc: 0.4145, test acc: 0.4315, val loss: 1.3874, val acc: 0.4331  (best train acc: 0.4229, best val acc: 0.4418, best test acc: 0.4410)
# [Epoch: 0820] train loss: 1.4066, train acc: 0.4203, test acc: 0.4258, val loss: 1.3853, val acc: 0.4266  (best train acc: 0.4231, best val acc: 0.4418, best test acc: 0.4410)
# [Epoch: 0840] train loss: 1.4054, train acc: 0.4127, test acc: 0.4295, val loss: 1.3836, val acc: 0.4391  (best train acc: 0.4231, best val acc: 0.4418, best test acc: 0.4410)
# [Epoch: 0860] train loss: 1.4039, train acc: 0.4111, test acc: 0.4291, val loss: 1.3817, val acc: 0.4418  (best train acc: 0.4245, best val acc: 0.4445, best test acc: 0.4410)
# [Epoch: 0880] train loss: 1.3984, train acc: 0.4156, test acc: 0.4393, val loss: 1.3803, val acc: 0.4465  (best train acc: 0.4247, best val acc: 0.4465, best test acc: 0.4410)
# [Epoch: 0900] train loss: 1.3988, train acc: 0.4085, test acc: 0.4268, val loss: 1.3781, val acc: 0.4378  (best train acc: 0.4305, best val acc: 0.4482, best test acc: 0.4410)
# [Epoch: 0920] train loss: 1.3964, train acc: 0.4201, test acc: 0.4386, val loss: 1.3757, val acc: 0.4442  (best train acc: 0.4312, best val acc: 0.4482, best test acc: 0.4410)
# [Epoch: 0940] train loss: 1.3941, train acc: 0.4261, test acc: 0.4396, val loss: 1.3730, val acc: 0.4432  (best train acc: 0.4343, best val acc: 0.4489, best test acc: 0.4433)
# [Epoch: 0960] train loss: 1.3909, train acc: 0.4284, test acc: 0.4470, val loss: 1.3713, val acc: 0.4503  (best train acc: 0.4389, best val acc: 0.4513, best test acc: 0.4487)
# [Epoch: 0980] train loss: 1.3890, train acc: 0.4329, test acc: 0.4416, val loss: 1.3683, val acc: 0.4469  (best train acc: 0.4389, best val acc: 0.4550, best test acc: 0.4518)
# [Epoch: 1000] train loss: 1.3805, train acc: 0.4281, test acc: 0.4396, val loss: 1.3660, val acc: 0.4405  (best train acc: 0.4389, best val acc: 0.4560, best test acc: 0.4518)
# [Epoch: 1020] train loss: 1.3842, train acc: 0.4349, test acc: 0.4470, val loss: 1.3634, val acc: 0.4482  (best train acc: 0.4389, best val acc: 0.4560, best test acc: 0.4518)
# [Epoch: 1040] train loss: 1.3825, train acc: 0.4281, test acc: 0.4541, val loss: 1.3613, val acc: 0.4546  (best train acc: 0.4391, best val acc: 0.4563, best test acc: 0.4555)
# [Epoch: 1060] train loss: 1.3784, train acc: 0.4370, test acc: 0.4534, val loss: 1.3585, val acc: 0.4530  (best train acc: 0.4398, best val acc: 0.4563, best test acc: 0.4555)
# [Epoch: 1080] train loss: 1.3803, train acc: 0.4346, test acc: 0.4480, val loss: 1.3560, val acc: 0.4459  (best train acc: 0.4422, best val acc: 0.4567, best test acc: 0.4602)
# [Epoch: 1100] train loss: 1.3791, train acc: 0.4365, test acc: 0.4602, val loss: 1.3543, val acc: 0.4540  (best train acc: 0.4422, best val acc: 0.4567, best test acc: 0.4602)
# [Epoch: 1120] train loss: 1.3674, train acc: 0.4328, test acc: 0.4501, val loss: 1.3517, val acc: 0.4546  (best train acc: 0.4446, best val acc: 0.4583, best test acc: 0.4632)
# [Epoch: 1140] train loss: 1.3727, train acc: 0.4325, test acc: 0.4568, val loss: 1.3504, val acc: 0.4543  (best train acc: 0.4446, best val acc: 0.4587, best test acc: 0.4632)
# [Epoch: 1160] train loss: 1.3757, train acc: 0.4353, test acc: 0.4494, val loss: 1.3477, val acc: 0.4492  (best train acc: 0.4446, best val acc: 0.4587, best test acc: 0.4632)
# [Epoch: 1180] train loss: 1.3667, train acc: 0.4439, test acc: 0.4487, val loss: 1.3456, val acc: 0.4533  (best train acc: 0.4458, best val acc: 0.4614, best test acc: 0.4669)
# [Epoch: 1200] train loss: 1.3655, train acc: 0.4378, test acc: 0.4524, val loss: 1.3442, val acc: 0.4573  (best train acc: 0.4463, best val acc: 0.4617, best test acc: 0.4669)
# [Epoch: 1220] train loss: 1.3699, train acc: 0.4402, test acc: 0.4578, val loss: 1.3439, val acc: 0.4607  (best train acc: 0.4463, best val acc: 0.4617, best test acc: 0.4669)
# [Epoch: 1240] train loss: 1.3633, train acc: 0.4371, test acc: 0.4599, val loss: 1.3411, val acc: 0.4563  (best train acc: 0.4463, best val acc: 0.4631, best test acc: 0.4669)
# [Epoch: 1260] train loss: 1.3523, train acc: 0.4404, test acc: 0.4592, val loss: 1.3391, val acc: 0.4597  (best train acc: 0.4463, best val acc: 0.4634, best test acc: 0.4669)
# [Epoch: 1280] train loss: 1.3552, train acc: 0.4409, test acc: 0.4582, val loss: 1.3374, val acc: 0.4600  (best train acc: 0.4463, best val acc: 0.4634, best test acc: 0.4669)
# [Epoch: 1300] train loss: 1.3570, train acc: 0.4419, test acc: 0.4582, val loss: 1.3361, val acc: 0.4624  (best train acc: 0.4463, best val acc: 0.4641, best test acc: 0.4669)
# [Epoch: 1320] train loss: 1.3521, train acc: 0.4375, test acc: 0.4548, val loss: 1.3342, val acc: 0.4594  (best train acc: 0.4463, best val acc: 0.4648, best test acc: 0.4669)
# [Epoch: 1340] train loss: 1.3496, train acc: 0.4369, test acc: 0.4541, val loss: 1.3320, val acc: 0.4567  (best train acc: 0.4463, best val acc: 0.4648, best test acc: 0.4669)
# [Epoch: 1360] train loss: 1.3456, train acc: 0.4373, test acc: 0.4514, val loss: 1.3309, val acc: 0.4570  (best train acc: 0.4463, best val acc: 0.4648, best test acc: 0.4669)
# [Epoch: 1380] train loss: 1.3473, train acc: 0.4359, test acc: 0.4558, val loss: 1.3302, val acc: 0.4590  (best train acc: 0.4466, best val acc: 0.4648, best test acc: 0.4669)
# [Epoch: 1400] train loss: 1.3509, train acc: 0.4380, test acc: 0.4511, val loss: 1.3290, val acc: 0.4617  (best train acc: 0.4466, best val acc: 0.4648, best test acc: 0.4669)
# [Epoch: 1420] train loss: 1.3481, train acc: 0.4383, test acc: 0.4511, val loss: 1.3284, val acc: 0.4594  (best train acc: 0.4466, best val acc: 0.4648, best test acc: 0.4669)
# [Epoch: 1440] train loss: 1.3491, train acc: 0.4390, test acc: 0.4575, val loss: 1.3282, val acc: 0.4614  (best train acc: 0.4466, best val acc: 0.4648, best test acc: 0.4669)
# [Epoch: 1460] train loss: 1.3482, train acc: 0.4396, test acc: 0.4541, val loss: 1.3269, val acc: 0.4634  (best train acc: 0.4466, best val acc: 0.4648, best test acc: 0.4669)
# [Epoch: 1480] train loss: 1.3493, train acc: 0.4395, test acc: 0.4501, val loss: 1.3265, val acc: 0.4627  (best train acc: 0.4466, best val acc: 0.4648, best test acc: 0.4669)
# [Epoch: 1500] train loss: 1.3485, train acc: 0.4508, test acc: 0.4524, val loss: 1.3264, val acc: 0.4624  (best train acc: 0.4508, best val acc: 0.4648, best test acc: 0.4669)
# [Epoch: 1520] train loss: 1.3467, train acc: 0.4493, test acc: 0.4538, val loss: 1.3261, val acc: 0.4624  (best train acc: 0.4508, best val acc: 0.4661, best test acc: 0.4669)
# [Epoch: 1540] train loss: 1.3421, train acc: 0.4482, test acc: 0.4558, val loss: 1.3248, val acc: 0.4637  (best train acc: 0.4508, best val acc: 0.4661, best test acc: 0.4669)
# [Epoch: 1560] train loss: 1.3494, train acc: 0.4458, test acc: 0.4568, val loss: 1.3255, val acc: 0.4648  (best train acc: 0.4516, best val acc: 0.4661, best test acc: 0.4669)
# [Epoch: 1580] train loss: 1.3466, train acc: 0.4403, test acc: 0.4558, val loss: 1.3254, val acc: 0.4610  (best train acc: 0.4516, best val acc: 0.4661, best test acc: 0.4669)
# [Epoch: 1600] train loss: 1.3471, train acc: 0.4455, test acc: 0.4568, val loss: 1.3246, val acc: 0.4627  (best train acc: 0.4519, best val acc: 0.4661, best test acc: 0.4669)
# [Epoch: 1620] train loss: 1.3483, train acc: 0.4456, test acc: 0.4578, val loss: 1.3240, val acc: 0.4658  (best train acc: 0.4540, best val acc: 0.4661, best test acc: 0.4669)
# [Epoch: 1640] train loss: 1.3413, train acc: 0.4517, test acc: 0.4582, val loss: 1.3243, val acc: 0.4600  (best train acc: 0.4540, best val acc: 0.4668, best test acc: 0.4669)
# [Epoch: 1660] train loss: 1.3439, train acc: 0.4511, test acc: 0.4599, val loss: 1.3243, val acc: 0.4641  (best train acc: 0.4540, best val acc: 0.4668, best test acc: 0.4669)
# [Epoch: 1680] train loss: 1.3351, train acc: 0.4448, test acc: 0.4551, val loss: 1.3224, val acc: 0.4621  (best train acc: 0.4540, best val acc: 0.4668, best test acc: 0.4669)
# [Epoch: 1700] train loss: 1.3405, train acc: 0.4540, test acc: 0.4555, val loss: 1.3230, val acc: 0.4637  (best train acc: 0.4547, best val acc: 0.4671, best test acc: 0.4669)
# [Epoch: 1720] train loss: 1.3417, train acc: 0.4507, test acc: 0.4585, val loss: 1.3226, val acc: 0.4654  (best train acc: 0.4547, best val acc: 0.4671, best test acc: 0.4669)
# [Epoch: 1740] train loss: 1.3433, train acc: 0.4426, test acc: 0.4561, val loss: 1.3219, val acc: 0.4641  (best train acc: 0.4547, best val acc: 0.4671, best test acc: 0.4669)
# [Epoch: 1760] train loss: 1.3403, train acc: 0.4481, test acc: 0.4592, val loss: 1.3210, val acc: 0.4648  (best train acc: 0.4547, best val acc: 0.4671, best test acc: 0.4669)
# [Epoch: 1780] train loss: 1.3379, train acc: 0.4501, test acc: 0.4575, val loss: 1.3206, val acc: 0.4648  (best train acc: 0.4556, best val acc: 0.4678, best test acc: 0.4669)
# [Epoch: 1800] train loss: 1.3382, train acc: 0.4492, test acc: 0.4612, val loss: 1.3210, val acc: 0.4658  (best train acc: 0.4556, best val acc: 0.4678, best test acc: 0.4669)
# [Epoch: 1820] train loss: 1.3396, train acc: 0.4508, test acc: 0.4639, val loss: 1.3196, val acc: 0.4661  (best train acc: 0.4556, best val acc: 0.4678, best test acc: 0.4669)
# [Epoch: 1840] train loss: 1.3330, train acc: 0.4513, test acc: 0.4656, val loss: 1.3210, val acc: 0.4641  (best train acc: 0.4562, best val acc: 0.4678, best test acc: 0.4686)
# [Epoch: 1860] train loss: 1.3331, train acc: 0.4516, test acc: 0.4632, val loss: 1.3193, val acc: 0.4671  (best train acc: 0.4562, best val acc: 0.4678, best test acc: 0.4686)
# [Epoch: 1880] train loss: 1.3349, train acc: 0.4537, test acc: 0.4619, val loss: 1.3174, val acc: 0.4631  (best train acc: 0.4562, best val acc: 0.4678, best test acc: 0.4686)
# [Epoch: 1900] train loss: 1.3350, train acc: 0.4513, test acc: 0.4673, val loss: 1.3176, val acc: 0.4671  (best train acc: 0.4569, best val acc: 0.4685, best test acc: 0.4720)
# [Epoch: 1920] train loss: 1.3310, train acc: 0.4533, test acc: 0.4639, val loss: 1.3174, val acc: 0.4644  (best train acc: 0.4576, best val acc: 0.4698, best test acc: 0.4720)
# [Epoch: 1940] train loss: 1.3338, train acc: 0.4568, test acc: 0.4622, val loss: 1.3146, val acc: 0.4648  (best train acc: 0.4576, best val acc: 0.4698, best test acc: 0.4723)
# [Epoch: 1960] train loss: 1.3310, train acc: 0.4570, test acc: 0.4639, val loss: 1.3141, val acc: 0.4661  (best train acc: 0.4576, best val acc: 0.4698, best test acc: 0.4723)
# [Epoch: 1980] train loss: 1.3326, train acc: 0.4513, test acc: 0.4636, val loss: 1.3152, val acc: 0.4661  (best train acc: 0.4614, best val acc: 0.4698, best test acc: 0.4723)
# [Epoch: 2000] train loss: 1.3311, train acc: 0.4524, test acc: 0.4609, val loss: 1.3142, val acc: 0.4668  (best train acc: 0.4614, best val acc: 0.4698, best test acc: 0.4723)
# [Epoch: 2020] train loss: 1.3257, train acc: 0.4500, test acc: 0.4642, val loss: 1.3145, val acc: 0.4668  (best train acc: 0.4614, best val acc: 0.4702, best test acc: 0.4730)
# [Epoch: 2040] train loss: 1.3318, train acc: 0.4572, test acc: 0.4646, val loss: 1.3135, val acc: 0.4668  (best train acc: 0.4614, best val acc: 0.4702, best test acc: 0.4730)
# [Epoch: 2060] train loss: 1.3338, train acc: 0.4556, test acc: 0.4659, val loss: 1.3130, val acc: 0.4668  (best train acc: 0.4614, best val acc: 0.4702, best test acc: 0.4730)
# [Epoch: 2080] train loss: 1.3278, train acc: 0.4561, test acc: 0.4656, val loss: 1.3136, val acc: 0.4671  (best train acc: 0.4614, best val acc: 0.4702, best test acc: 0.4744)
# [Epoch: 2100] train loss: 1.3279, train acc: 0.4551, test acc: 0.4666, val loss: 1.3123, val acc: 0.4658  (best train acc: 0.4614, best val acc: 0.4702, best test acc: 0.4771)
# [Epoch: 2120] train loss: 1.3307, train acc: 0.4568, test acc: 0.4632, val loss: 1.3105, val acc: 0.4685  (best train acc: 0.4622, best val acc: 0.4702, best test acc: 0.4771)
# [Epoch: 2140] train loss: 1.3285, train acc: 0.4563, test acc: 0.4585, val loss: 1.3102, val acc: 0.4661  (best train acc: 0.4622, best val acc: 0.4702, best test acc: 0.4771)
# [Epoch: 2160] train loss: 1.3263, train acc: 0.4503, test acc: 0.4676, val loss: 1.3087, val acc: 0.4648  (best train acc: 0.4622, best val acc: 0.4702, best test acc: 0.4771)
# [Epoch: 2180] train loss: 1.3280, train acc: 0.4554, test acc: 0.4649, val loss: 1.3111, val acc: 0.4664  (best train acc: 0.4622, best val acc: 0.4702, best test acc: 0.4771)
# [Epoch: 2200] train loss: 1.3296, train acc: 0.4556, test acc: 0.4632, val loss: 1.3081, val acc: 0.4695  (best train acc: 0.4624, best val acc: 0.4702, best test acc: 0.4771)
# [Epoch: 2220] train loss: 1.3260, train acc: 0.4562, test acc: 0.4696, val loss: 1.3075, val acc: 0.4702  (best train acc: 0.4624, best val acc: 0.4718, best test acc: 0.4771)
# [Epoch: 2240] train loss: 1.3247, train acc: 0.4606, test acc: 0.4693, val loss: 1.3084, val acc: 0.4678  (best train acc: 0.4624, best val acc: 0.4718, best test acc: 0.4777)
# [Epoch: 2260] train loss: 1.3261, train acc: 0.4558, test acc: 0.4615, val loss: 1.3067, val acc: 0.4695  (best train acc: 0.4624, best val acc: 0.4718, best test acc: 0.4777)
# [Epoch: 2280] train loss: 1.3241, train acc: 0.4594, test acc: 0.4629, val loss: 1.3048, val acc: 0.4715  (best train acc: 0.4624, best val acc: 0.4722, best test acc: 0.4777)
# [Epoch: 2300] train loss: 1.3218, train acc: 0.4568, test acc: 0.4673, val loss: 1.3050, val acc: 0.4675  (best train acc: 0.4624, best val acc: 0.4722, best test acc: 0.4784)
# [Epoch: 2320] train loss: 1.3284, train acc: 0.4552, test acc: 0.4622, val loss: 1.3053, val acc: 0.4718  (best train acc: 0.4624, best val acc: 0.4725, best test acc: 0.4784)
# [Epoch: 2340] train loss: 1.3251, train acc: 0.4564, test acc: 0.4568, val loss: 1.3040, val acc: 0.4681  (best train acc: 0.4624, best val acc: 0.4725, best test acc: 0.4784)
# [Epoch: 2360] train loss: 1.3280, train acc: 0.4592, test acc: 0.4602, val loss: 1.3032, val acc: 0.4715  (best train acc: 0.4626, best val acc: 0.4725, best test acc: 0.4784)
# [Epoch: 2380] train loss: 1.3238, train acc: 0.4607, test acc: 0.4690, val loss: 1.3037, val acc: 0.4718  (best train acc: 0.4626, best val acc: 0.4728, best test acc: 0.4784)
# [Epoch: 2400] train loss: 1.3198, train acc: 0.4605, test acc: 0.4673, val loss: 1.3025, val acc: 0.4671  (best train acc: 0.4626, best val acc: 0.4728, best test acc: 0.4784)
# [Epoch: 2420] train loss: 1.3208, train acc: 0.4576, test acc: 0.4740, val loss: 1.3069, val acc: 0.4708  (best train acc: 0.4626, best val acc: 0.4739, best test acc: 0.4784)
# [Epoch: 2440] train loss: 1.3165, train acc: 0.4581, test acc: 0.4717, val loss: 1.3038, val acc: 0.4702  (best train acc: 0.4626, best val acc: 0.4745, best test acc: 0.4784)
# [Epoch: 2460] train loss: 1.3251, train acc: 0.4591, test acc: 0.4717, val loss: 1.3032, val acc: 0.4705  (best train acc: 0.4627, best val acc: 0.4745, best test acc: 0.4784)
# [Epoch: 2480] train loss: 1.3169, train acc: 0.4587, test acc: 0.4767, val loss: 1.3061, val acc: 0.4695  (best train acc: 0.4627, best val acc: 0.4745, best test acc: 0.4784)
# c:\Users\pmaur\miniconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\pmaur\miniconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\pmaur\miniconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       154
#            1       0.42      0.78      0.54       703
#            2       0.32      0.10      0.16       702
#            3       0.42      0.46      0.44       703
#            4       0.68      0.63      0.65       702
#
#     accuracy                           0.47      2964
#    macro avg       0.37      0.39      0.36      2964
# weighted avg       0.43      0.47      0.42      2964

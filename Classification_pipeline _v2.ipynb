# %% [markdown]
# ## Packets

# %%
from GraphSageModel import GNN7L_Sage
from GNNTrain import predict_from_saved_model
from CreateDataset import get_dataset_from_graph
from Paths import PATH_TO_GRAPHS, PATH_TO_MODELS

import heapq
import torch
import networkx as nx
import torch_geometric
from tqdm.notebook import tqdm
from torch_geometric.nn.models import GNNExplainer

torch.manual_seed(42)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(torch.__version__)
print(device)
# Out:
# 1.11.0
# cuda

# %% [markdown]
# ## Prediction

# %%
disease_Id = 'C0023893'
graph_path = PATH_TO_GRAPHS + 'grafo_nedbit_' + disease_Id + '.gml'

dataset = get_dataset_from_graph(graph_path, disease_Id).to(device)
# Out:
# [+] Reading graph...ok
# [+] Creating dataset...ok
# [i] Elapsed time: 36.971

# %%
model_name  = 'GraphSAGE_' + disease_Id + '_40000_0_0005'
classes     = ['P', 'LP', 'WN', 'LN', 'RN']

sage_pred_multi, sage_prob_multi, sage_model = predict_from_saved_model(model_name, dataset, classes, save_to_file=False)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       112
#            1       0.92      0.96      0.94       713
#            2       0.90      0.81      0.85       713
#            3       0.82      0.75      0.78       713
#            4       0.82      0.93      0.87       713
#
#     accuracy                           0.87      2964
#    macro avg       0.88      0.89      0.88      2964
# weighted avg       0.87      0.87      0.87      2964

# %% [markdown]
# # Explainabilty

# %%
G = nx.read_gml(graph_path)

# %%
# Predicted P(ositive) genes in the test mask
# dictionaries with {gene: prob}
test_P      = {}
overall_LP  = {}

test_mask = dataset.test_mask
test_preds = sage_pred_multi[test_mask]
test_probs = sage_prob_multi[test_mask]

test_nodes = []
i = 0
for node in G.nodes:
    if test_mask[i]:
        test_nodes.append(node)
    if sage_pred_multi[i] == 1 and node not in overall_LP:
        overall_LP[node] = sage_prob_multi[i][1].item() # take probability of class 1 (LP)
    i += 1

i = 0
for node in test_nodes:
    if test_preds[i] == 0 and node not in test_P: #P
        test_P[node] = test_probs[i][0].item() # take probability of class 0 (p)
    i += 1

print('# of predicted positive genes in test mask:', len(test_P))
print('# of predicted overall likely positive genes:', len(overall_LP))
# Out:
# # of predicted positive genes in test mask: 117
# # of predicted overall likely positive genes: 4950

# %%
k_test_positive_genes   = 16
k_explanation_nodes     = 0.25
k_candidates_for_seed   = 10

top_k_test_P = heapq.nlargest(k_test_positive_genes, test_P, key=test_P.get)

# list of positive genes indexes in test_mask
top_k_test_P_idx = []

for node in top_k_test_P:
    i = 0
    for n in G.nodes:
        if node == n:
            top_k_test_P_idx.append(i)
            break
        i += 1

edge_index = dataset.edge_index

# dict to store for each index the number of nodes (pos 0)
# and edges (pos 1) in the subgraph
subg_numnodes_d = {}

for i in top_k_test_P_idx:
    subg_nodes, subg_edge_index, subg_mapping, subg_edge_mask = torch_geometric.utils.k_hop_subgraph(i, 1, edge_index)
    if i not in subg_numnodes_d:
        subg_numnodes_d[i] = [len(subg_nodes), subg_edge_index.shape[1]]

# %% [markdown]
# ### 1 Hop

# %%
x = dataset.x
y = dataset.y
edge_index = dataset.edge_index

candidates = {}

for i in tqdm(range(len(top_k_test_P_idx))):
    nodes_names = list(G.nodes)

    idx = top_k_test_P_idx[i]
    idx_name = nodes_names[idx]
    candidates[idx_name] = {}

    mean_mask = torch.zeros(edge_index.shape[1]).to('cpu')

    for i in tqdm(range(10)):
        explainer = GNNExplainer(sage_model, epochs=200, return_type='log_prob', num_hops=1, log=False)
        node_feat_mask, edge_mask = explainer.explain_node(idx, x, edge_index)
        mean_mask += edge_mask.to('cpu')

    mean_mask = torch.div(mean_mask, 10)

    num_nodes = int(round(subg_numnodes_d[idx][0]*k_explanation_nodes))

    values, indices = torch.topk(mean_mask, subg_numnodes_d[idx][1]) #take ordered list of all edges

    seen_genes = set()

    for i in range(len(indices)):
        src = edge_index[0][indices[i]]
        trgt = edge_index[1][indices[i]]

        src_name = nodes_names[src]
        trgt_name = nodes_names[trgt]

        src_pred = sage_pred_multi[src]
        trgt_pred = sage_pred_multi[trgt]

        # if gene has not been seen and it is not the explained node
        # we add it to the seen genes set
        if src_name != idx_name:
            seen_genes.add(src_name)
        if trgt_name != idx_name:
            seen_genes.add(trgt_name)

        if src_pred == 1: # LP
            if src_name not in candidates[idx_name]:
                candidates[idx_name][src_name] = values[i]
            else:
                candidates[idx_name][src_name] += values[i]

        if trgt_pred == 1: # LP
            if trgt_name not in candidates[idx_name]:
                candidates[idx_name][trgt_name] = values[i]
            else:
                candidates[idx_name][trgt_name] += values[i]
        
        # when the seen geens set reaches the num_nodes threshold
        # break the loop
        if len(seen_genes) >= num_nodes:
            break

all_top_LP = []
for seed in candidates:
    all_top_LP += heapq.nlargest(k_candidates_for_seed, candidates[seed], key=candidates[seed].get)

all_top_LP = list(set(all_top_LP))
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
len(all_top_LP)
# Out:
# 133

# %%
candidates
# Out:
# {'JAK2': {'STAM2': tensor(0.3062),
#   'STAM': tensor(0.3062),
#   'PTK2': tensor(0.3062),
#   'CXCR4': tensor(0.3062),
#   'HSP90AB1': tensor(0.1544),
#   'CSK': tensor(0.1544),
#   'CSF2RB': tensor(0.1537),
#   'JAK1': tensor(0.3037),
#   'CUL4B': tensor(0.3034),
#   'PPIA': tensor(0.3034),
#   'SOCS3': tensor(0.4541),
#   'IGF1R': tensor(0.4541),
#   'NAP1L1': tensor(0.1519),
#   'STAT1': tensor(0.1514),
#   'CALM1': tensor(0.6033),
#   'HSP90AA1': tensor(0.6033),
#   'JAK3': tensor(0.1511),
#   'ALK': tensor(0.1510),
#   'PIK3R1': tensor(0.3016),
#   'BRCA1': tensor(0.1508),
#   'STAT5A': tensor(0.1508),
#   'FGFR1': tensor(0.1507),
#   'ASB2': tensor(0.1506),
#   'CBL': tensor(0.1505),
#   'EGFR': tensor(0.1505),
#   'STAT5B': tensor(0.1505),
#   'HDAC6': tensor(0.1504)},
#  'KRT8': {'LZTS2': tensor(0.4627),
#   'UBR4': tensor(0.1549),
#   'DPP4': tensor(0.1549),
#   'HSPA5': tensor(0.1547),
#   'POU2F1': tensor(0.1547),
#   'KIAA1429': tensor(0.7680),
#   'HSPA2': tensor(0.3084),
#   'FAF1': tensor(0.3084),
#   'KPNA2': tensor(0.3077),
#   'FN1': tensor(0.3077),
#   'TRIM37': tensor(0.4609),
#   'OGT': tensor(0.1542),
#   'ARIH2': tensor(0.1542),
#   'CCDC14': tensor(0.1541),
#   'CYLD': tensor(0.3068),
#   'GFAP': tensor(0.3070),
#   'NUP107': tensor(0.1538),
#   'WDR5': tensor(0.3071),
#   'BYSL': tensor(0.3071),
#   'SOGA1': tensor(0.1536),
#   'TFIP11': tensor(0.3066),
#   'PRPF8': tensor(0.3066),
#   'MEPCE': tensor(0.1536),
#   'KRT1': tensor(0.3066),
#   'KRT17': tensor(0.3066),
#   'PLEKHG1': tensor(0.1536),
#   'NIN': tensor(0.1536),
#   'TJP1': tensor(0.1535),
#   'PIH1D1': tensor(0.1535),
#   'STXBP4': tensor(0.1534),
#   'PLK1': tensor(0.1534),
#   'NAV1': tensor(0.1534),
#   'TNIP1': tensor(0.1534),
#   'TBC1D2B': tensor(0.1534),
#   'KIF14': tensor(0.4598),
#   'IKBKAP': tensor(0.4598),
#   'USP9X': tensor(0.1533),
#   'APC': tensor(0.1533),
#   'ARFGEF1': tensor(0.1533),
#   'EGFR': tensor(0.1533),
#   'ALMS1': tensor(0.1533),
#   'ARHGAP21': tensor(0.1532),
#   'FGD5': tensor(0.1532),
#   'CCSER2': tensor(0.1532),
#   'INA': tensor(0.1532),
#   'KIAA1671': tensor(0.1532),
#   'KIF7': tensor(0.1532),
#   'CAD': tensor(0.1532),
#   'TNRC6B': tensor(0.1531),
#   'XPOT': tensor(0.1531),
#   'IQCB1': tensor(0.1531),
#   'TUBB2A': tensor(0.1530),
#   'AGR2': tensor(0.1530),
#   'WDR76': tensor(0.1529),
#   'HIST1H2AB': tensor(0.1529),
#   'HSPA4L': tensor(0.1529),
#   'TP53': tensor(0.1529)},
#  'PFN1': {'CDK2': tensor(0.3090),
#   'TKT': tensor(0.3090),
#   'UPF1': tensor(0.1554),
#   'DIAPH1': tensor(0.1554),
#   'OBSL1': tensor(0.3083),
#   'ACTC1': tensor(0.3083),
#   'KIAA1429': tensor(0.1548),
#   'PIH1D1': tensor(0.3085),
#   'CALM1': tensor(0.4615),
#   'SYNE2': tensor(0.4615),
#   'ELAVL1': tensor(0.4611),
#   'ESR1': tensor(0.4611),
#   'FASN': tensor(0.6154),
#   'NR2C2': tensor(0.6154),
#   'SET': tensor(0.3076),
#   'PTEN': tensor(0.3076),
#   'DDX39B': tensor(0.1545),
#   'WNK1': tensor(0.4606),
#   'RANBP9': tensor(0.4606),
#   'KIAA1217': tensor(0.1543),
#   'SEC16A': tensor(0.1543),
#   'PARK7': tensor(0.1541),
#   'TLE1': tensor(0.1540),
#   'SPTBN1': tensor(0.1538),
#   'AGR2': tensor(0.3069),
#   'QARS': tensor(0.3069),
#   'SRPRB': tensor(0.1537),
#   'GJD3': tensor(0.1536),
#   'PGK1': tensor(0.1536),
#   'ACAA2': tensor(0.1536),
#   'ACTB': tensor(0.3066),
#   'LARP7': tensor(0.4599),
#   'DLD': tensor(0.4599),
#   'HNRNPA1': tensor(0.3069),
#   'AAR2': tensor(0.3069),
#   'PEBP1': tensor(0.3066),
#   'TNIP2': tensor(0.1534),
#   'NTRK1': tensor(0.3068),
#   'KRT17': tensor(0.1534),
#   'GSK3B': tensor(0.1534),
#   'ATG7': tensor(0.1534),
#   'CYFIP1': tensor(0.1533),
#   'TRIM37': tensor(0.3064),
#   'TANC1': tensor(0.1533),
#   'PARK2': tensor(0.4595),
#   'PDIA4': tensor(0.4595),
#   'MPRIP': tensor(0.1533),
#   'CALR': tensor(0.3063),
#   'LPP': tensor(0.3063),
#   'ISG15': tensor(0.1532),
#   'UBE2M': tensor(0.1532),
#   'YWHAQ': tensor(0.1532),
#   'CHMP4C': tensor(0.1531),
#   'ESR2': tensor(0.1531),
#   'KIAA1671': tensor(0.1531),
#   'BAG3': tensor(0.3062),
#   'TJP1': tensor(0.3062),
#   'NCK1': tensor(0.1531),
#   'CDH1': tensor(0.1531),
#   'CFTR': tensor(0.1531),
#   'RECQL4': tensor(0.1531),
#   'IKBKAP': tensor(0.1531),
#   'SIRPA': tensor(0.1531),
#   'ARHGAP21': tensor(0.1530),
#   'KIF14': tensor(0.1530),
#   'PALM2': tensor(0.1530),
#   'HECTD1': tensor(0.1530),
#   'AAK1': tensor(0.1530),
#   'TRAF6': tensor(0.1530),
#   'PGAM1': tensor(0.1530),
#   'DNM1L': tensor(0.1530)},
#  'MVP': {'TFCP2': tensor(0.1536),
#   'FLOT2': tensor(0.1536),
#   'FXR2': tensor(0.1522),
#   'CAMK2B': tensor(0.1522),
#   'TOLLIP': tensor(0.1514),
#   'GIT2': tensor(0.1513),
#   'SIRT7': tensor(0.1513),
#   'NNT': tensor(0.1513),
#   'TRIM37': tensor(0.1511),
#   'HSPA8': tensor(0.1511),
#   'CKAP4': tensor(0.1509),
#   'MEOX1': tensor(0.1506),
#   'KIF23': tensor(0.1505),
#   'TRIP13': tensor(0.1505),
#   'XIAP': tensor(0.1504),
#   'GSK3B': tensor(0.1504),
#   'CYLD': tensor(0.1501),
#   'FBXW7': tensor(0.1501),
#   'GOLGA2': tensor(0.1500),
#   'AES': tensor(0.1500),
#   'HSP90AB1': tensor(0.1499),
#   'ANLN': tensor(0.1499),
#   'BRCA1': tensor(0.1499),
#   'UBC': tensor(0.1497),
#   'PTEN': tensor(0.1497),
#   'SNW1': tensor(0.1497),
#   'RCOR3': tensor(0.1496)},
#  'YWHAG': {'OAZ1': tensor(0.1549),
#   'CDC25C': tensor(0.1542),
#   'SSX2IP': tensor(0.4589),
#   'LATS2': tensor(0.4589),
#   'YWHAB': tensor(0.4598),
#   'ANLN': tensor(0.1538),
#   'ARHGEF17': tensor(0.1538),
#   'TSC1': tensor(0.3074),
#   'RICTOR': tensor(0.3074),
#   'CDK16': tensor(0.6126),
#   'PPARG': tensor(0.1537),
#   'KAT5': tensor(0.1537),
#   'KIF23': tensor(0.3063),
#   'PRC1': tensor(0.3063),
#   'ANKRD55': tensor(0.1536),
#   'ZNF638': tensor(0.3063),
#   'CDC5L': tensor(0.3063),
#   'PPP1CA': tensor(0.9172),
#   'KIAA1429': tensor(0.9172),
#   'HSPA1A': tensor(0.3060),
#   'YWHAE': tensor(0.7642),
#   'FBXO6': tensor(0.7642),
#   'LRRK2': tensor(0.1536),
#   'SMTNL2': tensor(0.1536),
#   'NBR1': tensor(0.1535),
#   'GSK3A': tensor(0.1535),
#   'ESR2': tensor(0.4592),
#   'NCKIPSD': tensor(0.4592),
#   'PLEKHA5': tensor(0.1534),
#   'FBXW11': tensor(0.1534),
#   'YWHAH': tensor(1.0717),
#   'C1QBP': tensor(0.3059),
#   'FN1': tensor(0.3059),
#   'LZTS2': tensor(0.1533),
#   'MAP1LC3B': tensor(0.3058),
#   'TRIM21': tensor(0.3058),
#   'HNRNPH1': tensor(0.3060),
#   'DENND4A': tensor(0.1533),
#   'UACA': tensor(0.4587),
#   'YWHAQ': tensor(0.4587),
#   'HDAC4': tensor(0.1532),
#   'PHLDB2': tensor(0.1532),
#   'GEM': tensor(0.1532),
#   'KRT31': tensor(0.1532),
#   'PEAK1': tensor(0.1532),
#   'CSK': tensor(0.1532),
#   'VCP': tensor(0.1532),
#   'ATG16L1': tensor(0.6110),
#   'CUL3': tensor(0.1532),
#   'ITGA4': tensor(0.1532),
#   'PABPC1': tensor(0.1532),
#   'HDAC5': tensor(0.1531),
#   'UBC': tensor(0.7634),
#   'PIK3R1': tensor(0.7634),
#   'PAK6': tensor(0.1531),
#   'ESR1': tensor(0.1531),
#   'KLC4': tensor(0.1531),
#   'FOXO4': tensor(0.1531),
#   'POT1': tensor(0.1530),
#   'MAP7': tensor(0.1530),
#   'LUC7L2': tensor(0.1530),
#   'SRSF1': tensor(0.1530),
#   'CHMP4C': tensor(0.1529),
#   'EFTUD2': tensor(0.1529),
#   'PFKFB2': tensor(0.1529),
#   'FBXW7': tensor(0.3055),
#   'SRRM1': tensor(0.3055),
#   'KIF14': tensor(0.1528),
#   'MYH10': tensor(0.1528),
#   'CFTR': tensor(0.1528),
#   'SRGAP2': tensor(0.3055),
#   'MAPKAP1': tensor(0.3055),
#   'HMGB2': tensor(0.1528),
#   'CLK3': tensor(0.3053),
#   'SYDE2': tensor(0.1528),
#   'ARAF': tensor(0.3053),
#   'USP54': tensor(0.3054),
#   'SRRM2': tensor(0.4574),
#   'NOLC1': tensor(0.3050),
#   'XPO1': tensor(0.1527),
#   'UNK': tensor(0.1527),
#   'ARHGEF6': tensor(0.1527),
#   'TNIP2': tensor(0.1526),
#   'NTRK1': tensor(0.3051),
#   'RC3H2': tensor(0.3050),
#   'DHX15': tensor(0.3050),
#   'MPRIP': tensor(0.3049),
#   'FANCD2': tensor(0.3049),
#   'EEF1G': tensor(0.3049),
#   'IRS4': tensor(0.1526),
#   'CCDC8': tensor(0.1526),
#   'UBE3A': tensor(0.3050),
#   'CDC42BPA': tensor(0.1526),
#   'RAB11A': tensor(0.1526),
#   'REEP4': tensor(0.1525),
#   'CKB': tensor(0.1525),
#   'HIST1H3A': tensor(0.1525),
#   'PINK1': tensor(0.1525),
#   'SF3B3': tensor(0.4574),
#   'FAF1': tensor(0.3049),
#   'TRIM32': tensor(0.1525),
#   'PDIA4': tensor(0.1525),
#   'ZAK': tensor(0.1525),
#   'PPP2R1A': tensor(0.1525),
#   'APBB1': tensor(0.1524),
#   'CYLD': tensor(0.1524),
#   'AKT1': tensor(0.1524),
#   'TIAM1': tensor(0.1524),
#   'SH3RF1': tensor(0.1524),
#   'ALDH7A1': tensor(0.1524),
#   'G6PD': tensor(0.1524),
#   'NEFL': tensor(0.1524),
#   'PRKCG': tensor(0.1524),
#   'ATXN1': tensor(0.1524),
#   'WNK1': tensor(0.1524),
#   'MLLT4': tensor(0.1524),
#   'SHB': tensor(0.1524),
#   'DDX39B': tensor(0.4569),
#   'CEP89': tensor(0.1523),
#   'SSBP1': tensor(0.1523),
#   'TGM2': tensor(0.1523),
#   'BCL2L14': tensor(0.1523),
#   'IARS2': tensor(0.1523)},
#  'DOCK10': {'SUCLG1': tensor(0.3482),
#   'FDX1L': tensor(0.3482),
#   'SUCLG2': tensor(0.3477),
#   'GSTO1': tensor(0.3477)},
#  'NFKBIA': {'PSMA4': tensor(0.1543),
#   'TNIP2': tensor(0.1543),
#   'HDAC2': tensor(0.1533),
#   'EP300': tensor(0.1533),
#   'CUL1': tensor(0.1530),
#   'TGM2': tensor(0.1530),
#   'MAP3K7': tensor(0.1530),
#   'ATXN3': tensor(0.3044),
#   'HNRNPU': tensor(0.3044),
#   'PSMA2': tensor(0.1529),
#   'SMARCA4': tensor(0.1527),
#   'IKBKB': tensor(0.1527),
#   'UBE2I': tensor(0.3041),
#   'ZBTB7A': tensor(0.3041),
#   'POLR2A': tensor(0.1524),
#   'IRAK1': tensor(0.1523),
#   'BCL10': tensor(0.1523),
#   'EGLN3': tensor(0.3043),
#   'MCM3': tensor(0.3043),
#   'PLS1': tensor(0.1522),
#   'CDC34': tensor(0.3041),
#   'SMC4': tensor(0.3041),
#   'RHOA': tensor(0.1522),
#   'VCP': tensor(0.1522),
#   'CSNK2B': tensor(0.3036),
#   'HDAC1': tensor(0.3036),
#   'NCOR1': tensor(0.1521),
#   'FBXW7': tensor(0.1521),
#   'TBC1D4': tensor(0.4546),
#   'FBXW11': tensor(0.4546),
#   'AKT1': tensor(0.1517),
#   'TBK1': tensor(0.1517),
#   'NFKB1': tensor(0.1516),
#   'HDAC4': tensor(0.1516),
#   'AURKA': tensor(0.1515),
#   'NFKBIB': tensor(0.1514),
#   'RANBP2': tensor(0.1514)},
#  'PLAU': {'SERPINB2': tensor(0.1050),
#   'CA6': tensor(0.1050),
#   'SDF2L1': tensor(0.1050),
#   'PLAUR': tensor(0.1050),
#   'MOCOS': tensor(0.1049),
#   'SERPINE2': tensor(0.1047),
#   'BTK': tensor(0.1047),
#   'HRAS': tensor(0.1047),
#   'MAP2K1': tensor(0.1047),
#   'CEBPG': tensor(0.1046),
#   'ELAVL1': tensor(0.1046)},
#  'LGALS1': {'HADHA': tensor(0.3046),
#   'STOM': tensor(0.4555),
#   'FN1': tensor(0.4555),
#   'IGBP1': tensor(0.1531),
#   'ITGA1': tensor(0.1527),
#   'MYH9': tensor(0.1526),
#   'RAC1': tensor(0.1526),
#   'RNF4': tensor(0.4543),
#   'LAMA5': tensor(0.1524),
#   'DAG1': tensor(0.1524),
#   'HRAS': tensor(0.1522),
#   'SNRPB': tensor(0.3033),
#   'MCM2': tensor(0.4538),
#   'HSPA5': tensor(0.4538),
#   'RAB5C': tensor(0.6058),
#   'ANLN': tensor(0.6058),
#   'NPM1': tensor(0.3032),
#   'TRIM37': tensor(0.3032),
#   'ITGA4': tensor(0.1518),
#   'NLRP7': tensor(0.1517),
#   'CIT': tensor(0.1517),
#   'CD44': tensor(0.1516),
#   'PRC1': tensor(0.1515),
#   'U2AF2': tensor(0.1515),
#   'ROCK2': tensor(0.1515),
#   'SLC39A10': tensor(0.1515),
#   'VANGL1': tensor(0.1514),
#   'NBR1': tensor(0.1514),
#   'ALCAM': tensor(0.1513),
#   'CHMP4B': tensor(0.1513),
#   'WWP2': tensor(0.1512),
#   'CD109': tensor(0.1512),
#   'IGSF3': tensor(0.1512),
#   'ESR2': tensor(0.3018),
#   'RAB10': tensor(0.1511),
#   'OSBPL8': tensor(0.1510),
#   'KIF20A': tensor(0.1509),
#   'KIF23': tensor(0.1509),
#   'NUDCD2': tensor(0.1509),
#   'ITGA6': tensor(0.1509),
#   'GTF2I': tensor(0.1507),
#   'PIH1D1': tensor(0.1507),
#   'SMN1': tensor(0.1506),
#   'FUBP1': tensor(0.1506),
#   'BRD4': tensor(0.1506),
#   'BTF3': tensor(0.1506),
#   'LASP1': tensor(0.1506),
#   'EFTUD2': tensor(0.1506),
#   'CSPG4': tensor(0.1506)},
#  'CASP4': {'SGIP1': tensor(0.1089),
#   'VDAC3': tensor(0.2155),
#   'SMC1A': tensor(0.1071),
#   'UFL1': tensor(0.1071),
#   'PSMB1': tensor(0.1070),
#   'NME2P1': tensor(0.1068)},
#  'HCK': {'PTK2': tensor(0.6072),
#   'SRC': tensor(0.6072),
#   'INCA1': tensor(0.1530),
#   'USP14': tensor(0.1526),
#   'HSPB1': tensor(0.1526),
#   'ERBB3': tensor(0.1525),
#   'IL6ST': tensor(0.1525),
#   'CHD4': tensor(0.1522),
#   'KRTAP10_7': tensor(0.3032),
#   'STAT3': tensor(0.3032),
#   'FXR1': tensor(0.1520),
#   'ERBB2': tensor(0.1514),
#   'EGFR': tensor(0.4527),
#   'HSP90AB1': tensor(0.4527),
#   'LYN': tensor(0.3023),
#   'TRIP6': tensor(0.1512),
#   'AR': tensor(0.1511),
#   'CDC37': tensor(0.1511),
#   'CRKL': tensor(0.1509),
#   'LMNA': tensor(0.1509),
#   'PAK2': tensor(0.1508),
#   'HSPA5': tensor(0.1508),
#   'HSP90AB2P': tensor(0.1507),
#   'HSP90AA1': tensor(0.1507),
#   'CREBBP': tensor(0.1505),
#   'HSF2BP': tensor(0.1504),
#   'CYSRT1': tensor(0.3004)},
#  'INS': {'GNB2L1': tensor(0.4613),
#   'RPS27': tensor(0.4613),
#   'RPL24': tensor(0.4594),
#   'UBXN1': tensor(0.1541),
#   'UBR2': tensor(0.1541),
#   'MARCKS': tensor(0.4600),
#   'PTEN': tensor(0.4600),
#   'ELAVL1': tensor(0.3065),
#   'RPL7': tensor(0.6126),
#   'RPL30': tensor(0.6126),
#   'HNRNPL': tensor(0.7633),
#   'GTF2I': tensor(0.7633),
#   'RPL27A': tensor(0.3058),
#   'MYO18A': tensor(0.1534),
#   'VCP': tensor(0.7626),
#   'YWHAE': tensor(0.7626),
#   'EIF2AK2': tensor(0.3057),
#   'RPL38': tensor(0.6109),
#   'RPL8': tensor(0.1532),
#   'VTA1': tensor(0.1532),
#   'C1QBP': tensor(0.4582),
#   'IQGAP2': tensor(0.1531),
#   'RPS9': tensor(0.7625),
#   'SEC61B': tensor(0.7625),
#   'NOTCH2NL': tensor(0.1530),
#   'ADAMTSL4': tensor(0.1530),
#   'RPS5': tensor(0.4576),
#   'P4HB': tensor(0.3055),
#   'HSP90B1': tensor(0.3055),
#   'HSPA9': tensor(0.3052),
#   'NDUFS7': tensor(0.3052),
#   'RPS12': tensor(0.3058),
#   'RPS13': tensor(0.3058),
#   'RPL11': tensor(0.3051),
#   'LARP4': tensor(0.1529),
#   'SRSF3': tensor(0.1529),
#   'RPL31': tensor(0.4576),
#   'RPS2': tensor(0.4576),
#   'RPL23A': tensor(0.3057),
#   'CDH1': tensor(0.6096),
#   'WDR37': tensor(0.1528),
#   'MRPS9': tensor(0.1528),
#   'HNRNPC': tensor(0.1528),
#   'RPL4': tensor(0.1528),
#   'CIRBP': tensor(0.1527),
#   'IDH2': tensor(0.1527),
#   'RPL15': tensor(0.3050),
#   'EIF2S2': tensor(0.3050),
#   'RPS14': tensor(0.1526),
#   'HSPA5': tensor(0.1526),
#   'RPS3': tensor(0.3051),
#   'MAPK6': tensor(0.4569),
#   'RPS23': tensor(0.3051),
#   'RPL3': tensor(0.4572),
#   'CDKN2AIP': tensor(0.1525),
#   'MAGED2': tensor(0.1525),
#   'RPS3A': tensor(0.1525),
#   'LARP1': tensor(0.3048),
#   'HMGB1': tensor(0.3048),
#   'RPL27': tensor(0.3048),
#   'SLC25A3': tensor(0.3048),
#   'NDUFA4': tensor(0.1524),
#   'ATP5C1': tensor(0.1524),
#   'DNAJC19': tensor(0.3047),
#   'NDUFV2': tensor(0.3047),
#   'RPS15': tensor(0.3047),
#   'RPS26': tensor(0.3047),
#   'GRAMD4': tensor(0.1524),
#   'HLA_C': tensor(0.1524),
#   'UBA52': tensor(0.1524),
#   'RPL36': tensor(0.1524),
#   'XRN2': tensor(0.1524),
#   'MAPK1': tensor(0.1524),
#   'RPS11': tensor(0.1524),
#   'ATP1A1': tensor(0.1523),
#   'RPS21': tensor(0.1523),
#   'RPS8': tensor(0.1523),
#   'TOP1': tensor(0.1523),
#   'RBM14': tensor(0.1523),
#   'DNAJC11': tensor(0.3044),
#   'HSPA8': tensor(0.3044),
#   'NDUFA9': tensor(0.3044),
#   'NDUFA12': tensor(0.3044),
#   'UBR1': tensor(0.1523),
#   'CDC42': tensor(0.1523),
#   'TXNL1': tensor(0.1523),
#   'SFXN1': tensor(0.3045),
#   'HNRNPU': tensor(0.1522),
#   'RPL17': tensor(0.1522),
#   'RPL7A': tensor(0.1522),
#   'DHX30': tensor(0.1522),
#   'RPL23': tensor(0.1522),
#   'RPS18': tensor(0.1522),
#   'SDHA': tensor(0.1522),
#   'NDUFS6': tensor(0.1522),
#   'RPL5': tensor(0.1522),
#   'PIN1': tensor(0.1522),
#   'AAK1': tensor(0.1521),
#   'RPL6': tensor(0.1521),
#   'DNAJB11': tensor(0.1521),
#   'RPLP2': tensor(0.1521),
#   'MYO1B': tensor(0.1521),
#   'CTSB': tensor(0.1521)},
#  'MMP9': {'COL18A1': tensor(0.2644),
#   'FN1': tensor(0.2639),
#   'THBS1': tensor(0.2639),
#   'ITGA5': tensor(0.1804),
#   'COL2A1': tensor(0.1800)},
#  'IGF2R': {'CA9': tensor(0.4651),
#   'RPN1': tensor(0.4651),
#   'RAB5C': tensor(0.1552),
#   'FN1': tensor(0.1552),
#   'STX7': tensor(0.1550),
#   'CKAP4': tensor(0.1547),
#   'TMPRSS11B': tensor(0.1547),
#   'RAB4A': tensor(0.1547),
#   'RAB1A': tensor(0.1547),
#   'GTSE1': tensor(0.1544),
#   'CLEC4E': tensor(0.1543),
#   'STIM1': tensor(0.4620),
#   'LRRC59': tensor(0.4620),
#   'MARCKS': tensor(0.1541),
#   'PRKACA': tensor(0.1541),
#   'GJD3': tensor(0.4607),
#   'RAB35': tensor(0.1539),
#   'METTL7A': tensor(0.4605),
#   'NOP9': tensor(0.1538),
#   'TMEM216': tensor(0.1537),
#   'ZFPL1': tensor(0.1537),
#   'RAB2A': tensor(0.3072),
#   'SEC24C': tensor(0.3072),
#   'SQSTM1': tensor(0.1536),
#   'EGLN3': tensor(0.1536),
#   'SEC23IP': tensor(0.3069),
#   'FBXO6': tensor(0.3071),
#   'STAU1': tensor(0.3066),
#   'SIRT7': tensor(0.3066),
#   'CANX': tensor(0.3070),
#   'ELAVL1': tensor(0.1536),
#   'RAB9A': tensor(0.1535),
#   'TEX101': tensor(0.1534),
#   'EP300': tensor(0.3064),
#   'AP2B1': tensor(0.3064),
#   'DDX58': tensor(0.1533),
#   'BCAP31': tensor(0.1533),
#   'SEC31A': tensor(0.1532),
#   'ARF6': tensor(0.1531),
#   'OCLN': tensor(0.1531),
#   'EMD': tensor(0.3062),
#   'KIAA1715': tensor(0.3062),
#   'CCDC8': tensor(0.1531),
#   'NUP155': tensor(0.1531),
#   'IGF2BP1': tensor(0.1531),
#   'MOGS': tensor(0.1531),
#   'XRCC5': tensor(0.1530),
#   'DNAJC1': tensor(0.1530),
#   'SEC24B': tensor(0.1530),
#   'LAMP3': tensor(0.1530)},
#  'GHR': {'IGF1R': tensor(0.2579),
#   'TYK2': tensor(0.1294),
#   'STAT5B': tensor(0.1289),
#   'STAT3': tensor(0.1289),
#   'SKP1': tensor(0.1286),
#   'FBXW11': tensor(0.1286),
#   'RBX1': tensor(0.1283),
#   'BTRC': tensor(0.1283),
#   'PTPN2': tensor(0.1279)},
#  'SIRT1': {'LRPPRC': tensor(0.3105),
#   'RPS2': tensor(0.3091),
#   'H2AFZ': tensor(0.3078),
#   'LMNA': tensor(0.3078),
#   'NPM1': tensor(0.3071),
#   'RPL6': tensor(0.3071),
#   'RCHY1': tensor(0.1542),
#   'BRD4': tensor(0.1542),
#   'EED': tensor(0.3074),
#   'ATP2A2': tensor(0.1542),
#   'HNRNPK': tensor(0.1541),
#   'APEX1': tensor(0.1541),
#   'HDAC2': tensor(0.3074),
#   'KAT5': tensor(0.1541),
#   'UBE2N': tensor(0.1540),
#   'SUZ12': tensor(0.1540),
#   'CBX3': tensor(0.3067),
#   'HMGB1': tensor(0.1538),
#   'UBE2I': tensor(0.1538),
#   'DYNC1H1': tensor(0.1538),
#   'BMI1': tensor(0.1538),
#   'HSP90AA1': tensor(0.1537),
#   'AGO4': tensor(0.1537),
#   'PPARG': tensor(0.4595),
#   'RPL9': tensor(0.4595),
#   'NOC4L': tensor(0.1536),
#   'CAP1': tensor(0.1534),
#   'TAF2': tensor(0.1534),
#   'JUN': tensor(0.1534),
#   'CTTN': tensor(0.1534),
#   'POP1': tensor(0.1534),
#   'WWP2': tensor(0.1533),
#   'KPNA3': tensor(0.1533),
#   'DNMT1': tensor(0.3059),
#   'CCNB1': tensor(0.3059),
#   'EGLN3': tensor(0.1532),
#   'IQCB1': tensor(0.1532),
#   'TP53': tensor(0.3059),
#   'STK11': tensor(0.3059),
#   'SNW1': tensor(0.1531),
#   'BRD1': tensor(0.1531),
#   'NUDT21': tensor(0.1531),
#   'ESR1': tensor(0.1531),
#   'NAT10': tensor(0.1531),
#   'EP300': tensor(0.6121),
#   'RARA': tensor(0.6121),
#   'TRIM28': tensor(0.1530),
#   'BAZ1B': tensor(0.1529),
#   'CTNNB1': tensor(0.1529),
#   'HIST1H3A': tensor(0.1529),
#   'STAT3': tensor(0.1529),
#   'ELAVL1': tensor(0.1529),
#   'HDAC4': tensor(0.1529),
#   'FGF11': tensor(0.1529),
#   'MDM2': tensor(0.1529),
#   'HIST2H2AB': tensor(0.1529),
#   'EZH2': tensor(0.3056),
#   'PSME3': tensor(0.1528),
#   'SPDL1': tensor(0.1528),
#   'DOT1L': tensor(0.1528),
#   'PARP1': tensor(0.1528),
#   'MTA1': tensor(0.1527),
#   'SMURF2': tensor(0.1527)}}

# %%
extended_genes = pd.read_csv('Datasets/all_gene_disease_associations.tsv', sep='\t')
extended_genes = extended_genes[extended_genes['diseaseId'] == 'C0006142']
extended_genes_names = set(extended_genes['geneSymbol'].tolist())

genes_in_extended       = []
genes_not_in_extended   = []

for gene in all_top_LP:
    if gene in extended_genes_names:
        genes_in_extended.append(gene)
    else:
        genes_not_in_extended.append(gene)

print('# of genes found in the extended dataset:', len(genes_in_extended))

print('\n----')
for g in genes_in_extended:
    print(g, end=' ')
print('\n----')

for g in genes_not_in_extended:
    print(g, end=' ')
print()
# Out:
# # of genes found in the extended dataset: 67
#
# ----
# SLC9A3R2 CDK9 MCM7 PLD1 XPO1 HSPA1A SLC9A3R1 ITPR1 CSNK2B GNL3 SP1 MAPK14 WDR5 HSPA5 ELAVL1 CBL BRD4 UBC ARRB1 RPS6KA1 LYN CSNK1E IKBKG PML NTRK1 ORC4 KIF14 HSPA8 TPT1 TRIM28 LAMP1 SLC5A6 RPA2 HSPB1 CFTR CSNK2A1 APP PIK3R1 HDAC3 PHB2 ARF6 SQSTM1 MYC ATAD3A KIF23 SMURF1 HDAC2 USP1 RACGAP1 TRIM25 STUB1 TERF2IP LMNA PLCG1 PSMD7 TGFBR1 RAB2A PNO1 RECQL4 BTRC MAP2K1 BAG3 NPM1 NRAS BCL2L1 APEX1 ABCE1
# ----
# IARS2 PPP1CC CDC37 CDC14B UQCRC1 FAM83H TCEB2 PKP4 TCEB3 FBXW11 GNB2L1 TEAD2 PSMC5 SPTA1 NDUFV3 PCF11 CCDC96 FARP2 PSMD6 TNIP2 DECR2 SPTBN1 PEX5 PLEKHA4 DPM1 ERC1 PSMD11 HIST1H4A KIAA1429 EFTUD2 RBBP4 ALMS1 PSMD12

# %% [markdown]
# ### 2 hops

# %%
edge_index = multiclass_data.edge_index

# dict to store for each index the number of nodes (pos 0)
# and edges (pos 1) in the subgraph
subg_numnodes_d_2hop = {}

for i in top_k_test_P_idx:
    subg_nodes, subg_edge_index, subg_mapping, subg_edge_mask = torch_geometric.utils.k_hop_subgraph(i, 2, edge_index)
    if i not in subg_numnodes_d_2hop:
        subg_numnodes_d_2hop[i] = [len(subg_nodes), subg_edge_index.shape[1]]

subg_numnodes_d_2hop

# %%
x = multiclass_data.x
y = multiclass_data.y

edge_index  = multiclass_data.edge_index
nodes_names = list(G.nodes)

candidates_2hop = {}

for i in tqdm(range(len(top_k_test_P_idx))):
    
    idx = top_k_test_P_idx[i]
    idx_name = nodes_names[idx]

    # START of explainability
    # Compute the mean mask as the mean of the masks returned by
    # 10 explanations

    mean_mask = torch.zeros(edge_index.shape[1]).to('cpu')

    for i in tqdm(range(10)):
        explainer = GNNExplainer(sage_model, epochs=200, return_type='log_prob', num_hops=2, log=False)
        node_feat_mask, edge_mask = explainer.explain_node(idx, x, edge_index)
        mean_mask += edge_mask.to('cpu')

    mean_mask = torch.div(mean_mask, 10)

    # END of explanaibility

    # number of LP nodes to take from the seed gene
    num_nodes = int(round(subg_numnodes_d_2hop[idx][0]*k_explanation_nodes))

    values, indices = torch.topk(mean_mask, subg_numnodes_d_2hop[idx][1]) #take ordered list of all edges

    seen_genes = set()

    for i in range(len(indices)):
        src = edge_index[0][indices[i]]
        trgt = edge_index[1][indices[i]]

        src_name = nodes_names[src]
        trgt_name = nodes_names[trgt]

        src_pred = sage_pred_multi[src]
        trgt_pred = sage_pred_multi[trgt]

        src_trgt_genes = {src_name: src_pred, trgt_name: trgt_pred}

        for g in src_trgt_genes:
            # if pred == LP and the gene has not been seen multiple times for the same seed gene
            if src_trgt_genes[g] == 1 and g not in seen_genes:
                seen_genes.add(g)
                if g not in candidates_2hop:
                    candidates_2hop[g] = {'counter': 1, 'score': values[i]}
                else:
                    candidates_2hop[g]['counter'] += 1
                    candidates_2hop[g]['score'] += values[i]
        
        # when the seen geens set reaches the num_nodes threshold
        # break the loop
        if len(seen_genes) >= num_nodes:
            break
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
all_top_LP_2hop = sorted(candidates_2hop.items(), key=lambda x: (x[1]['counter'], x[1]['score'].item()), reverse=True)
len(all_top_LP_2hop)
# Out:
# 911

# %%
all_top_k_2hop = [item[0] for item in all_top_LP_2hop][:100]

# %%
extended_genes = pd.read_csv('Datasets/all_gene_disease_associations.tsv', sep='\t')
extended_genes = extended_genes[extended_genes['diseaseId'] == 'C0006142']
extended_genes_names = set(extended_genes['geneSymbol'].tolist())

genes_in_extended       = []
genes_not_in_extended   = []

for gene in all_top_k_2hop:
    if gene in extended_genes_names:
        genes_in_extended.append(gene)
    else:
        genes_not_in_extended.append(gene)

print('# of genes found in the extended dataset:', len(genes_in_extended))

print('\n----')
for g in genes_in_extended:
    print(g, end=' ')
print('\n----')

for g in genes_not_in_extended:
    print(g, end=' ')
print()
# Out:
# # of genes found in the extended dataset: 68
#
# ----
# HSPA8 MYC FZR1 AURKB KIF14 NTRK1 NPM1 HSP90AB1 CFTR ELAVL1 SQSTM1 KIF23 LMNA CIT CYLD TMPO LRRK2 PSMC3 CUL3 ARNT ATAD3A APEX1 APP HSPB1 HEXIM1 JUP PPP1R9B EMD CTBP1 TRAF6 UBE2I EGLN3 HSPA5 RBM39 YWHAE PLCG1 PPP2R1A TRIM28 NR2C2 NRAS PSMD4 UBC ILK GAPDH CCND2 ACTB STUB1 CCNF BRD4 CDK2 PPP1R13B LMNB1 LYN CRK PRKDC RPL13 MAP1LC3B MYH10 CUL4A MAPK1 TTN ARF6 USP9X BLM TRIM25 XRCC5 FAM83B PRKCZ
# ----
# KIAA1429 PLEKHA4 EFTUD2 CDC37 YWHAQ HIST1H4A TNIP2 TCEB3 OBSL1 METTL14 WWP2 CAND1 RPS5 AP2M1 LMO7 ARHGAP21 PCBP2 FAM83H ATP5A1 TTLL5 SPTBN1 RPS24 RPS11 PLEC NUP107 NOP56 KIAA1671 NUP93 YWHAH ESYT2 PPP1CC ERH
